# %%
import pandas as pd
import requests
import json
import pubchempy as pcp
from safety import get_hazard_codes
data = pd.read_csv('/Users/Jaime/Downloads/HBA_list.csv') #change file path if necessary
scoring_table = pd.read_csv('hazard_score.csv')

# %% [markdown]
# ### Recap from the previous work in the other notebooks, we were able to take a list of chemicals and determine if ghs data was available, and if so, if the chemical was hazardous or nonhazardous. If hazardous, the specific hazard codes were returned. We also took a table of all possible hazard codes from GHS, and used a paper (Verslycke et al, "the Chemistry Scoring Index")  that ranked these hazards based on how detrimental they are, to assign scores to all these values.

# %% [markdown]
# ### Below, the get_hazard_code function is demonstrated which is contained in the safety.py file.

# %%
hazard_codes = []
for i, row in data.iterrows():
    cid = row['HBA_cid']
    values = get_hazard_codes(cid)
    hazard_codes.append(values)
data['GHS_info'] = hazard_codes

# %%
data
# Out:
#                                                 HBA   HBA_cid                                           GHS_info
# 0                                  choline chloride      6209                                 [H315, H319, H335]
# 1                                   choline acetate       187                              No GHS data available
# 2                                   choline bromide     74724                                 [H315, H319, H335]
# 3                                  choline fluoride  22134097                              No GHS data available
# 4                                   choline nitrate  13646546                              No GHS data available
# 5         (2-chloroethyl)trimethylammonium chloride     13836                                     [H302:, H312:]
# 6    ethyl(2-hydroxyethyl)dimethylammonium chloride     87940                              No GHS data available
# 7   benzyl(2-hydroxyethyl)dimethylammonium chloride   3014549                                 [H315, H319, H335]
# 8                            acetylcholine chloride      6060                                 [H315, H319, H335]
# 9                      tetramethylammonium chloride      6379  [H300, H301, H311, H315, H319, H335, H370, H41...
# 10                           ethylammonium chloride     11198                                 [H315, H319, H335]
# 11                            ethylammonium bromide     68974                                       [H315, H319]
# 12   beta-(Diethylamino)ethyl alcohol hydrochloride    517011                              No GHS data available
# 13                  triethylmethylammonium chloride     82326                                 [H315, H319, H335]
# 14                      tetraethylammonium chloride      5946                           [H302, H315, H319, H335]
# 15                       tetraethylammonium bromide      6285                           [H302, H315, H319, H335]
# 16                           propylammonium bromide  12203661                                       [H315, H319]
# 17                     tetrapropylammonium chloride     79880                                 [H315, H319, H335]
# 18                      tetrapropylammonium bromide     74745            Not classified as a hazardous substance
# 19                            butylammonium bromide  12199058                                       [H315, H319]
# 20                   decyltrimethylammonium bromide     16388                                 [H315, H319, H335]
# 21                 dodecyltrimethylammonium bromide     14249   [H301, H302, H315, H317, H319, H335, H400, H410]
# 22              tetradecyltrimethylammonium bromide     14250         [H302, H314, H315, H318, H335, H373, H400]
# 23                      tetrabutylammonium chloride     70681                                 [H315, H319, H335]
# 24                       tetrabutylammonium bromide     74236               [H302, H315, H319, H335, H411, H412]
# 25                       tetrahexylammonium bromide     78026                                 [H315, H319, H335]
# 26                     tetraheptylammonium chloride     82489                                 [H315, H319, H335]
# 27                  methyltrioctylammonium chloride     21218               [H301, H315, H318, H319, H400, H410]
# 28                      tetraoctylammonium chloride  11996614                                 [H315, H319, H335]
# 29                       tetraoctylammonium bromide   2734117                                 [H315, H319, H335]
# 30                 benzyltrimethylammonium chloride      5963   [H301, H302, H311, H315, H319, H332, H341, H412]
# 31                  benzyltriethylammonium chloride     66133               [H302, H315, H317, H319, H335, H412]
# 32                 benzyltripropylammonium chloride   6097067                                 [H315, H319, H335]
# 33                    tetrabutylphosphonium bromide     76564   [H302, H310, H311, H315, H318, H319, H335, H411]
# 34               methyltriphenylphosphonium bromide     74505  [H300, H301, H302+H312+H332, H302, H312, H315,...
# 35                 ethyltriphenylphosphonium iodide     78474         [H300, H301, H312, H315, H318, H319, H335]
# 36                allyltriphenylphosphonium bromide    197740                                 [H315, H319, H335]
# 37              benzyltriphenylphosphonium chloride     70671  [H300, H301, H311, H315, H318, H319, H330, H33...
# 38                             guanidinium chloride      5742                              [H302:, H315:, H319:]

# %% [markdown]
# ### And here is what the scoring table looks like

# %%
scoring_table
# Out:
#                Code  Hazard Score
# 0              H200           100
# 1              H201           100
# 2              H202           100
# 3              H203           100
# 4              H204           100
# 5              H205           100
# 6              H206           100
# 7              H207           100
# 8              H207           100
# 9              H208           100
# 10             H220            75
# 11             H221            75
# 12             H221            75
# 13             H222            75
# 14             H223            75
# 15             H224            75
# 16             H225            50
# 17             H226            25
# 18             H227            10
# 19             H228            75
# 20             H228            75
# 21             H229            75
# 22             H229            75
# 23             H229            75
# 24             H230            75
# 25             H231            75
# 26             H232            75
# 27             H240           100
# 28             H241           100
# 29             H242           100
# ..              ...           ...
# 86             H362            50
# 87             H370            50
# 88             H371            50
# 89             H372            50
# 90             H373            50
# 91             H400           100
# 92             H401            75
# 93             H402            50
# 94             H410           100
# 95             H411            75
# 96             H412            50
# 97             H413            25
# 98             H420            50
# 99        H300+H310           200
# 100       H300+H330           200
# 101       H310+H330           200
# 102  H300+H310+H330           300
# 103       H301+H311           150
# 104       H301+H331           150
# 105       H311+H331           150
# 106  H301+H311+H331           225
# 107       H302+H312           100
# 108       H302+H332           100
# 109       H312+H332           100
# 110  H302+H312+H332           150
# 111       H303+H313            20
# 112       H303+H333            20
# 113       H313+H333            20
# 114  H303+H313+H333            20
# 115       H315+H320            20
#
# [116 rows x 2 columns]

# %% [markdown]
# ### Now the objective is to assign final hazard scores to the chemicals in the data table as a sum of all their hazard codes. Ideally, this could be split into a health and environmental score, since all hazard codes for these start with a 3 and 4, respectively. We also will rank health scores higher than environmental scores in the final chemical ranking against with all other properties (melting point, cost, etc.).

# %% [markdown]
# ### There could be a few ways to do this, but it might be beneficial to have this process work outside the dataframe and then append back to it. The reason is, the hazard codes are contained inside lists in the dataframe, extarcting that column as another list would make the hazrad codes for each chemical easily iteratted through a list of lists. For the hazard scoring table, we could keep as a dataframe or convert into dictionary instead.

# %%
#Converting the GHS_info column in the data table as a list for testing our fucntions.
GHS_list = data['GHS_info'].tolist()

# %%
def hazard_check():
    """This function will check the ghs info and determine to give it the max or min safety penalty
    or calculate a total hazard score"""

    if item == 'Not classified as a hazardous substance':
        return 'Minimum Penalty'

    if item == 'No GHS data available':
        return 'Maximum Penalty'

    else:
        return 'Calculate Score'

# %%
check_list = []
for item in GHS_list:
    checks = hazard_check()
    check_list.append(checks)

# %%
check_list
# Out:
# ['Calculate Score',
#  'Maximum Penalty',
#  'Calculate Score',
#  'Maximum Penalty',
#  'Maximum Penalty',
#  'Calculate Score',
#  'Maximum Penalty',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Maximum Penalty',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Minimum Penalty',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score',
#  'Calculate Score']
