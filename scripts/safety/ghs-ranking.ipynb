# %%
import pandas as pd
import numpy
import requests

# %%
data = pd.read_html("https://pubchem.ncbi.nlm.nih.gov/ghs/")

# %%
ghs_class = data[1]

# %%
ghs_class
# Out:
#                  Code                                  Hazard Statements  \
#                  Code                                  Hazard Statements
# 0                H200                                 Unstable Explosive
# 1                H201                   Explosive; mass explosion hazard
# 2                H202                Explosive; severe projection hazard
# 3                H203        Explosive; fire, blast or projection hazard
# 4                H204                          Fire or projection hazard
# 5                H205                           May mass explode in fire
# 6                 NaN                                                NaN
# 7                H206  Fire, blast or projection hazard; increased ri...
# 8                H207  Fire or projection hazard; increased risk of e...
# 9                H207  Fire or projection hazard; increased risk of e...
# 10               H208  Fire hazard; increased risk of explosion if de...
# ...

# %%
ghs_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
# (Code, Code)                                      117 non-null object
# (Hazard Statements, Hazard Statements)            117 non-null object
# (Hazard Class, Hazard Class)                      118 non-null object
# (Category, Category)                              118 non-null object
# (Pictogram, Pictogram)                            18 non-null object
# (Signal Word, Signal Word)                        107 non-null object
# (Precautionary Statements P-Codes, Prevention)    92 non-null object
# (Precautionary Statements P-Codes, Response)      83 non-null object
# (Precautionary Statements P-Codes, Storage)       67 non-null object
# (Precautionary Statements P-Codes, Disposal)      66 non-null object
# dtypes: object(10)
# memory usage: 9.5+ KB
