# %%
#bring imports here
import json
import requests
import numpy as np
import pandas as pd
import os
import sys
from time import sleep

# %% [markdown]
# ## Scraping the data

# %% [markdown]
# #### A big shoutout to Wesley Beckner for developing his package "salty" from which the majority of this code shown here came from. He has done some really cool research with ionic liquids, check out his github at https://github.com/wesleybeckner/salty to see his original code, and other cool features of his package.

# %% [markdown]
# While the NIST database is specifically directed towards ionic liquids, there is actually a lot of deep eutectic sovlent (DES) data as well. We can basically employ the same methods Wesley did to get this very useful data.

# %% [markdown]
# When you search for data on NIST, there are specific 4 letter tags for each property. You can find these tags and get the url for the data page by inspecting the webpage and going to the network dection. Perform the search, and the full url with the 4 letter tag will be shown. ILThermo's 4-letter tag for density is KuiQ. I Performed a search for all density data with keyword as 'Deep Eutectic Solvents' and returned a decent amount of data.

# %% [markdown]
# URL for the data: https://ilthermo.boulder.nist.gov/ILT2/ilsearch?cmp=&ncmp=0&year=&auth=&keyw=deep%20eutectic%20solvent&prp=KuiQ

# %% [markdown]
# A note to save the json files outside of a github repo, preferably a local folder on your device. I ran into permission issues when trying to save the scraped data directly into my github repo

# %%
paper_url = "https://ilthermo.boulder.nist.gov/ILT2/ilsearch?cmp=&ncmp=0&year=&auth=&keyw=Deep%20eutectic%20solvent&prp=KuiQ"
 
r = requests.get(paper_url)
header = r.json()['header']
papers = r.json()['res']
i = 1 
data_url = 'http://ilthermo.boulder.nist.gov/ILT2/ilset?set={paper_id}'
for paper in papers[:]: 
    
    r = requests.get(data_url.format(paper_id=paper[0]))
    data = r.json()['data']
    with open("/Users/jaime/Desktop/nist_data/density/%s.json" % i, "w") as outfile: #set destination path for files
        json.dump(r.json(), outfile)
    #then do whatever you want to data like writing to a file
    sleep(0.5) #import step to avoid getting banned by server
    i += 1

# %% [markdown]
# ## Cleaning up the data and adding to a pandas dataframe

# %% [markdown]
# The data has been scraped as 42 seperate json files. We can now use this code below to parse each file, extract the desired columns, and sort into a dataframe. A lot of the cleaning uses boolean logic because the data in the files are not all organized identically. I had to go in and see how they were organized to come up with some conditions that would parse accordingly based on the organization of the file. I frist developed this for one dataset (conductivity) and found it can be used with most of the others as well. There could be a little thing or two that may need adjusting based on what data is being scrapped, but in general it is mostly unviersal for the DES data on NIST

# %%
outer_old = pd.DataFrame()
outer_new = pd.DataFrame()

for i in range(42): #edit the number based on how many files were scraped
    with open("/Users/jaime/Desktop/nist_data/density/%s.json" % str(i+1)) as json_file:

        #grab data, data headers (names), the salt name
        json_full = json.load(json_file)                    
        json_data = pd.DataFrame(json_full['data'])
        json_datanames = np.array(json_full['dhead'])        # make names into array to add as columns headers for df
        json_data.columns =  json_datanames
        json_saltname = pd.DataFrame(json_full['components'])#components section contains names of DES components
        #print(json_saltname['name'])                #grabbing the HBD and HBA 

        inner_old = pd.DataFrame()
        inner_new = pd.DataFrame()

        #loop through the columns of the data, note that some of the 
        #json files are missing pressure data. 
        for indexer in range(len(json_data.columns)):        
            grab=json_data.columns[indexer]
            list = json_data[grab]
            my_list = [l[0] for l in list]
            dfmy_list = pd.DataFrame(my_list)
            dfmy_list.columns = [json_datanames[indexer][0]]
            inner_new = pd.concat([dfmy_list, inner_old], axis=1)
            inner_old = inner_new

        #print(inner_old.columns)


        #add the MW for HBD and HBA
        for i in range(len(json_saltname['name'])):
            if 'chloride' in json_saltname['name'][i] or 'bromide' in json_saltname['name'][i]:
                inner_old['HBA_MW']=json_saltname['mw'][i]
            else:
                inner_old['HBD_MW']=json_saltname['mw'][i]
                

        #add the DES components, i.e. HBA and HBD
        # they are not always listed in the same order on nist data, i.e., HBA always first. Will figure out later.
        for i in range(len(json_saltname['name'])):
            if 'chloride' in json_saltname['name'][i] or 'bromide' in json_saltname['name'][i]:
                inner_old['HBA']=json_saltname['name'][i]
            else:
                inner_old['HBD']=json_saltname['name'][i]
                
        #loop through the column names of the dataframe
        for j in range(len(inner_old.columns)):
            #if the words Mole fraction and a halogen are contained, values are correct and no value editing 
            #necessary and column is simply renamed to HBA mole fraction.
            if 'Mole fraction' in inner_old.columns[j] and 'chloride' in inner_old.columns[j] or 'Mole fraction' in inner_old.columns[j] and 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
            #if the words Mole Ratio and a halogen are contained, dataset was mislabeled but values are correct.
            #only need to rename column to HBA mole fraction.
            elif 'Mole ratio' in inner_old.columns[j] and 'chloride' in inner_old.columns[j] or 'Mole ratio' in inner_old.columns[j] and 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
            #if the words mole ratio are present, but no halogens, the ratio of the HBD is displayed and needs
            #to be changed to HBA mole fraction. First relabel the colum as HBA mole fraction.
            elif 'Mole ratio' in inner_old.columns[j] and not 'chloride' in inner_old.columns[j] or 'Mole ratio' in inner_old.columns[j] and not 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
                #apparently the numbers are strings so change to integer. May need to do this for every other column
                inner_old['HBA Mole Fraction'] = inner_old['HBA Mole Fraction'].astype(int)
                #next make an empty list that will hold all the new HBA mole fractions
                mole_fractions_list = []
                #loop through every HBD ratio in the column
                for k in range(len(inner_old['HBA Mole Fraction'])):
                    #Calculate the HBA mole fraction from every HBD ratio and append to the list
                    mole_fractions_list.append(1/(1+inner_old['HBA Mole Fraction'][k]))
                #finally make the list the new mole fraction column in the dataframe
                inner_old['HBA Mole Fraction'] = mole_fractions_list
            #in the last case, if the word mole fraction is present but not a halogen, HBD mole fraction is displayed.
            #Follow simialr process as before
            elif 'Mole fraction' in inner_old.columns[j] and not 'chloride' in inner_old.columns[j] or 'Mole fraction' in inner_old.columns[j] and not 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
                #convert to float instead since it is a decimal
                inner_old['HBA Mole Fraction'] = inner_old['HBA Mole Fraction'].astype(float)
                #empty list
                mole_fractions_list = []
                #loop through column
                for k in range(len(inner_old['HBA Mole Fraction'])):
                    #subtract 1 from HBD mole fraction to get HBA mole fraction and append to list
                    mole_fractions_list.append(1 - inner_old['HBA Mole Fraction'][k])
                #replace column   
                inner_old['HBA Mole Fraction'] = mole_fractions_list


        #add to the growing dataframe
        outer_new = pd.concat([inner_old, outer_old], axis = 0, ignore_index = True)
        outer_old = outer_new
    
outer_old.head(50)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:89: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                    HBA HBA Mole Fraction  HBA_MW  \
# 0          tetrapropylammonium bromide             0.333  266.27
# 1   methyltriphenylphosphonium bromide              0.16  357.23
# 2   methyltriphenylphosphonium bromide               0.2  357.23
# 3   methyltriphenylphosphonium bromide              0.25  357.23
# 4          tetraethylammonium chloride              0.25  165.71
# 5          tetraethylammonium chloride              0.25  165.71
# 6          tetraethylammonium chloride              0.25  165.71
# 7          tetraethylammonium chloride              0.25  165.71
# 8          tetrabutylammonium chloride              0.25  277.92
# 9          tetrabutylammonium chloride              0.25  277.92
# 10         tetrabutylammonium chloride              0.25  277.92
# 11         tetrabutylammonium chloride              0.25  277.92
# 12                                 NaN               0.5     NaN
# 13                                 NaN               0.5     NaN
# 14                                 NaN               0.5     NaN
# 15                                 NaN               0.5     NaN
# 16                                 NaN               0.5     NaN
# 17  methyltriphenylphosphonium bromide              0.25  357.23
# 18  methyltriphenylphosphonium bromide              0.25  357.23
# 19  methyltriphenylphosphonium bromide              0.25  357.23
# 20  methyltriphenylphosphonium bromide              0.25  357.23
# 21  methyltriphenylphosphonium bromide              0.25  357.23
# 22  methyltriphenylphosphonium bromide              0.25  357.23
# 23  methyltriphenylphosphonium bromide              0.25  357.23
# 24  methyltriphenylphosphonium bromide              0.25  357.23
# 25  methyltriphenylphosphonium bromide              0.25  357.23
# 26  methyltriphenylphosphonium bromide              0.25  357.23
# 27  methyltriphenylphosphonium bromide              0.25  357.23
# 28  methyltriphenylphosphonium bromide              0.25  357.23
# 29  methyltriphenylphosphonium bromide             0.111  357.23
# 30  methyltriphenylphosphonium bromide             0.111  357.23
# 31  methyltriphenylphosphonium bromide             0.111  357.23
# 32  methyltriphenylphosphonium bromide             0.111  357.23
# 33  methyltriphenylphosphonium bromide             0.111  357.23
# 34  methyltriphenylphosphonium bromide             0.111  357.23
# 35  methyltriphenylphosphonium bromide             0.111  357.23
# 36  methyltriphenylphosphonium bromide               0.2  357.23
# 37  methyltriphenylphosphonium bromide               0.2  357.23
# 38  methyltriphenylphosphonium bromide               0.2  357.23
# 39  methyltriphenylphosphonium bromide               0.2  357.23
# 40  methyltriphenylphosphonium bromide               0.2  357.23
# 41  methyltriphenylphosphonium bromide               0.2  357.23
# 42  methyltriphenylphosphonium bromide               0.2  357.23
# 43  methyltriphenylphosphonium bromide            0.3636  357.23
# 44  methyltriphenylphosphonium bromide            0.3636  357.23
# 45  methyltriphenylphosphonium bromide            0.3636  357.23
# 46  methyltriphenylphosphonium bromide            0.3636  357.23
# 47  methyltriphenylphosphonium bromide            0.3636  357.23
# 48  methyltriphenylphosphonium bromide            0.3636  357.23
# 49  methyltriphenylphosphonium bromide            0.3636  357.23
#
#                          HBD  HBD_MW Pressure, kPa  \
# 0             1,6-hexanediol  118.18         101.3
# 1         triethylene glycol  150.17           101
# 2         triethylene glycol  150.17           101
# 3         triethylene glycol  150.17           101
# 4        4-oxopentanoic acid  116.12         101.3
# 5        4-oxopentanoic acid  116.12         101.3
# 6        4-oxopentanoic acid  116.12         101.3
# 7        4-oxopentanoic acid  116.12         101.3
# 8        4-oxopentanoic acid  116.12         101.3
# 9        4-oxopentanoic acid  116.12         101.3
# 10       4-oxopentanoic acid  116.12         101.3
# 11       4-oxopentanoic acid  116.12         101.3
# 12                      urea   60.06          99.6
# 13                      urea   60.06          99.6
# 14                      urea   60.06          99.6
# 15                      urea   60.06          99.6
# 16                      urea   60.06          99.6
# 17            1,2-ethanediol   62.07           101
# 18            1,2-ethanediol   62.07           101
# 19            1,2-ethanediol   62.07           101
# 20            1,2-ethanediol   62.07           101
# 21            1,2-ethanediol   62.07           101
# 22            1,2-ethanediol   62.07           101
# 23                  glycerol   92.09           101
# 24                  glycerol   92.09           101
# 25                  glycerol   92.09           101
# 26                  glycerol   92.09           101
# 27                  glycerol   92.09           101
# 28                  glycerol   92.09           101
# 29  2,2,2-trifluoroacetamide  113.04           101
# 30  2,2,2-trifluoroacetamide  113.04           101
# 31  2,2,2-trifluoroacetamide  113.04           101
# 32  2,2,2-trifluoroacetamide  113.04           101
# 33  2,2,2-trifluoroacetamide  113.04           101
# 34  2,2,2-trifluoroacetamide  113.04           101
# 35  2,2,2-trifluoroacetamide  113.04           101
# 36            1,2-ethanediol   62.07           101
# 37            1,2-ethanediol   62.07           101
# 38            1,2-ethanediol   62.07           101
# 39            1,2-ethanediol   62.07           101
# 40            1,2-ethanediol   62.07           101
# 41            1,2-ethanediol   62.07           101
# 42            1,2-ethanediol   62.07           101
# 43                  glycerol   92.09           101
# 44                  glycerol   92.09           101
# 45                  glycerol   92.09           101
# 46                  glycerol   92.09           101
# 47                  glycerol   92.09           101
# 48                  glycerol   92.09           101
# 49                  glycerol   92.09           101
#
#    Specific density, kg/m<SUP>3</SUP> Temperature, K
# 0                              1042.2         313.15
# 1                                1186         298.15
# 2                                1199         298.15
# 3                                1216         298.15
# 4                              1090.3         303.15
# 5                              1083.3         313.15
# 6                              1076.1         323.15
# 7                              1069.2         333.15
# 8                              1027.3         303.15
# 9                              1020.3         313.15
# 10                             1013.1         323.15
# 11                               1006         333.15
# 12                             1202.2         293.15
# 13                             1195.6         303.15
# 14                             1189.2         313.15
# 15                             1182.7         323.15
# 16                             1176.3         333.15
# 17                             1249.1         298.15
# 18                             1245.7         303.15
# 19                             1242.2         308.15
# 20                             1238.8         313.15
# 21                             1235.4         318.15
# 22                             1231.9         323.15
# 23                             1295.8         298.15
# 24                             1292.4         303.15
# 25                             1288.9         308.15
# 26                             1285.3         313.15
# 27                             1281.7         318.15
# 28                             1278.1         323.15
# 29                             1394.7         298.15
# 30                             1383.7         308.15
# 31                             1372.7         318.15
# 32                             1361.6         328.15
# 33                             1350.4         338.15
# 34                             1339.3         348.15
# 35                             1328.2         358.15
# 36                             1232.6         298.15
# 37                             1225.6         308.15
# 38                             1218.5         318.15
# 39                             1211.4         328.15
# 40                             1204.3         338.15
# 41                             1197.2         348.15
# 42                               1190         358.15
# 43                             1289.9         298.15
# 44                               1283         308.15
# 45                             1275.9         318.15
# 46                             1268.8         328.15
# 47                             1261.9         338.15
# 48                               1255         348.15
# 49                               1248         358.15

# %% [markdown]
# It appears there are some Nan's for the HBA column. I looked at the original data files and this was a weird ionic liquid that used urea, so technically not a DES which is why the parsing in my code didn't pick it up and name it accordingly. Just going to drop those rows and the rest should be fine, also will save this dataframe as a csv.

# %%
outer_old.dropna(inplace = True)

# %%
pd.DataFrame.to_csv(outer_old, path_or_buf='density.csv', index=False)

# %%
pd.read_csv('density.csv')
# Out:
#                                     HBA  HBA Mole Fraction  HBA_MW  \
# 0           tetrapropylammonium bromide              0.333  266.27
# 1    methyltriphenylphosphonium bromide              0.160  357.23
# 2    methyltriphenylphosphonium bromide              0.200  357.23
# 3    methyltriphenylphosphonium bromide              0.250  357.23
# 4           tetraethylammonium chloride              0.250  165.71
# 5           tetraethylammonium chloride              0.250  165.71
# 6           tetraethylammonium chloride              0.250  165.71
# 7           tetraethylammonium chloride              0.250  165.71
# 8           tetrabutylammonium chloride              0.250  277.92
# 9           tetrabutylammonium chloride              0.250  277.92
# 10          tetrabutylammonium chloride              0.250  277.92
# 11          tetrabutylammonium chloride              0.250  277.92
# 12   methyltriphenylphosphonium bromide              0.250  357.23
# 13   methyltriphenylphosphonium bromide              0.250  357.23
# 14   methyltriphenylphosphonium bromide              0.250  357.23
# 15   methyltriphenylphosphonium bromide              0.250  357.23
# 16   methyltriphenylphosphonium bromide              0.250  357.23
# 17   methyltriphenylphosphonium bromide              0.250  357.23
# 18   methyltriphenylphosphonium bromide              0.250  357.23
# 19   methyltriphenylphosphonium bromide              0.250  357.23
# 20   methyltriphenylphosphonium bromide              0.250  357.23
# 21   methyltriphenylphosphonium bromide              0.250  357.23
# 22   methyltriphenylphosphonium bromide              0.250  357.23
# 23   methyltriphenylphosphonium bromide              0.250  357.23
# 24   methyltriphenylphosphonium bromide              0.111  357.23
# 25   methyltriphenylphosphonium bromide              0.111  357.23
# 26   methyltriphenylphosphonium bromide              0.111  357.23
# 27   methyltriphenylphosphonium bromide              0.111  357.23
# 28   methyltriphenylphosphonium bromide              0.111  357.23
# 29   methyltriphenylphosphonium bromide              0.111  357.23
# ..                                  ...                ...     ...
# 524  methyltriphenylphosphonium bromide              0.200  357.23
# 525  methyltriphenylphosphonium bromide              0.200  357.23
# 526  methyltriphenylphosphonium bromide              0.200  357.23
# 527  methyltriphenylphosphonium bromide              0.200  357.23
# 528  methyltriphenylphosphonium bromide              0.200  357.23
# 529  methyltriphenylphosphonium bromide              0.200  357.23
# 530  methyltriphenylphosphonium bromide              0.200  357.23
# 531  methyltriphenylphosphonium bromide              0.200  357.23
# 532  methyltriphenylphosphonium bromide              0.250  357.23
# 533  methyltriphenylphosphonium bromide              0.250  357.23
# 534  methyltriphenylphosphonium bromide              0.250  357.23
# 535  methyltriphenylphosphonium bromide              0.250  357.23
# 536  methyltriphenylphosphonium bromide              0.250  357.23
# 537  methyltriphenylphosphonium bromide              0.250  357.23
# 538  methyltriphenylphosphonium bromide              0.250  357.23
# 539  methyltriphenylphosphonium bromide              0.250  357.23
# 540  methyltriphenylphosphonium bromide              0.250  357.23
# 541  methyltriphenylphosphonium bromide              0.250  357.23
# 542  methyltriphenylphosphonium bromide              0.250  357.23
# 543  methyltriphenylphosphonium bromide              0.250  357.23
# 544  methyltriphenylphosphonium bromide              0.250  357.23
# 545  methyltriphenylphosphonium bromide              0.250  357.23
# 546  methyltriphenylphosphonium bromide              0.250  357.23
# 547  methyltriphenylphosphonium bromide              0.330  357.23
# 548  methyltriphenylphosphonium bromide              0.330  357.23
# 549  methyltriphenylphosphonium bromide              0.330  357.23
# 550  methyltriphenylphosphonium bromide              0.330  357.23
# 551  methyltriphenylphosphonium bromide              0.330  357.23
# 552  methyltriphenylphosphonium bromide              0.330  357.23
# 553  methyltriphenylphosphonium bromide              0.330  357.23
#
#                           HBD  HBD_MW  Pressure, kPa  \
# 0              1,6-hexanediol  118.18          101.3
# 1          triethylene glycol  150.17          101.0
# 2          triethylene glycol  150.17          101.0
# 3          triethylene glycol  150.17          101.0
# 4         4-oxopentanoic acid  116.12          101.3
# 5         4-oxopentanoic acid  116.12          101.3
# 6         4-oxopentanoic acid  116.12          101.3
# 7         4-oxopentanoic acid  116.12          101.3
# 8         4-oxopentanoic acid  116.12          101.3
# 9         4-oxopentanoic acid  116.12          101.3
# 10        4-oxopentanoic acid  116.12          101.3
# 11        4-oxopentanoic acid  116.12          101.3
# 12             1,2-ethanediol   62.07          101.0
# 13             1,2-ethanediol   62.07          101.0
# 14             1,2-ethanediol   62.07          101.0
# 15             1,2-ethanediol   62.07          101.0
# 16             1,2-ethanediol   62.07          101.0
# 17             1,2-ethanediol   62.07          101.0
# 18                   glycerol   92.09          101.0
# 19                   glycerol   92.09          101.0
# 20                   glycerol   92.09          101.0
# 21                   glycerol   92.09          101.0
# 22                   glycerol   92.09          101.0
# 23                   glycerol   92.09          101.0
# 24   2,2,2-trifluoroacetamide  113.04          101.0
# 25   2,2,2-trifluoroacetamide  113.04          101.0
# 26   2,2,2-trifluoroacetamide  113.04          101.0
# 27   2,2,2-trifluoroacetamide  113.04          101.0
# 28   2,2,2-trifluoroacetamide  113.04          101.0
# 29   2,2,2-trifluoroacetamide  113.04          101.0
# ..                        ...     ...            ...
# 524                  glycerol   92.09          101.0
# 525                  glycerol   92.09          101.0
# 526                  glycerol   92.09          101.0
# 527                  glycerol   92.09          101.0
# 528                  glycerol   92.09          101.0
# 529                  glycerol   92.09          101.0
# 530                  glycerol   92.09          101.0
# 531                  glycerol   92.09          101.0
# 532                  glycerol   92.09          101.0
# 533                  glycerol   92.09          101.0
# 534                  glycerol   92.09          101.0
# 535                  glycerol   92.09          101.0
# 536                  glycerol   92.09          101.0
# 537                  glycerol   92.09          101.0
# 538                  glycerol   92.09          101.0
# 539                  glycerol   92.09          101.0
# 540                  glycerol   92.09          101.0
# 541                  glycerol   92.09          101.0
# 542                  glycerol   92.09          101.0
# 543                  glycerol   92.09          101.0
# 544                  glycerol   92.09          101.0
# 545                  glycerol   92.09          101.0
# 546                  glycerol   92.09          101.0
# 547                  glycerol   92.09          101.0
# 548                  glycerol   92.09          101.0
# 549                  glycerol   92.09          101.0
# 550                  glycerol   92.09          101.0
# 551                  glycerol   92.09          101.0
# 552                  glycerol   92.09          101.0
# 553                  glycerol   92.09          101.0
#
#      Specific density, kg/m<SUP>3</SUP>  Temperature, K
# 0                                1042.2          313.15
# 1                                1186.0          298.15
# 2                                1199.0          298.15
# 3                                1216.0          298.15
# 4                                1090.3          303.15
# 5                                1083.3          313.15
# 6                                1076.1          323.15
# 7                                1069.2          333.15
# 8                                1027.3          303.15
# 9                                1020.3          313.15
# 10                               1013.1          323.15
# 11                               1006.0          333.15
# 12                               1249.1          298.15
# 13                               1245.7          303.15
# 14                               1242.2          308.15
# 15                               1238.8          313.15
# 16                               1235.4          318.15
# 17                               1231.9          323.15
# 18                               1295.8          298.15
# 19                               1292.4          303.15
# 20                               1288.9          308.15
# 21                               1285.3          313.15
# 22                               1281.7          318.15
# 23                               1278.1          323.15
# 24                               1394.7          298.15
# 25                               1383.7          308.15
# 26                               1372.7          318.15
# 27                               1361.6          328.15
# 28                               1350.4          338.15
# 29                               1339.3          348.15
# ..                                  ...             ...
# 524                              1263.0          333.15
# 525                              1260.0          338.15
# 526                              1257.0          343.15
# 527                              1253.0          348.15
# 528                              1250.0          353.15
# 529                              1246.0          358.15
# 530                              1242.0          363.15
# 531                              1238.0          368.15
# 532                              1298.0          298.15
# 533                              1294.0          303.15
# 534                              1291.0          308.15
# 535                              1287.0          313.15
# 536                              1284.0          318.15
# 537                              1281.0          323.15
# 538                              1277.0          328.15
# 539                              1274.0          333.15
# 540                              1270.0          338.15
# 541                              1266.0          343.15
# 542                              1263.0          348.15
# 543                              1259.0          353.15
# 544                              1256.0          358.15
# 545                              1252.0          363.15
# 546                              1249.0          368.15
# 547                              1303.0          303.15
# 548                              1295.0          313.15
# 549                              1289.0          323.15
# 550                              1282.0          333.15
# 551                              1275.0          343.15
# 552                              1268.0          353.15
# 553                              1262.0          363.15
#
# [554 rows x 8 columns]
