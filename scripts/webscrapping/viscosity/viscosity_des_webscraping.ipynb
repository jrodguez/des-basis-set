# %%
#bring imports here
import json
import requests
import numpy as np
import pandas as pd
import os
import sys
from time import sleep

# %% [markdown]
# ## Scraping the data

# %% [markdown]
# #### A big shoutout to Wesley Beckner for developing his package "salty" from which the majority of this code shown here came from. He has done some really cool research with ionic liquids, check out his github at https://github.com/wesleybeckner/salty to see his original code, and other cool features of his package.

# %% [markdown]
# While the NIST database is specifically directed towards ionic liquids, there is actually a lot of deep eutectic sovlent (DES) data as well. We can basically employ the same methods Wesley did to get this very sueful data.

# %% [markdown]
# When you search for data on NIST, there are specific 4 letter tags for each property. You can find these tags and get the url for the data page by inspecting the webpage and going to the network dection. Perform the search, and the full url with the 4 letter tag will be shown. ILThermo's 4-letter tag for viscosity is lWoo. I Performed a search for all viscosity data with keyword as 'Deep Eutectic Solvents' and returned a decent amount of data.

# %% [markdown]
# URL for the data: https://ilthermo.boulder.nist.gov/ILT2/ilsearch?cmp=&ncmp=0&year=&auth=&keyw=deep%20eutectic%20solvent&prp=lWoo

# %% [markdown]
# A note to save the json files outside of a github repo, preferably a local folder on your device. I ran into permission issues when trying to save the scraped data directly into my github repo

# %%
paper_url = "https://ilthermo.boulder.nist.gov/ILT2/ilsearch?cmp=&ncmp=0&year=&auth=&keyw=Deep%20eutectic%20solvent&prp=lWoo"
 
r = requests.get(paper_url)
header = r.json()['header']
papers = r.json()['res']
i = 1 
data_url = 'http://ilthermo.boulder.nist.gov/ILT2/ilset?set={paper_id}'
for paper in papers[:]: 
    
    r = requests.get(data_url.format(paper_id=paper[0]))
    data = r.json()['data']
    with open("/Users/jaime/Desktop/nist_data/viscosity/%s.json" % i, "w") as outfile: #set destination path for files
        json.dump(r.json(), outfile)
    #then do whatever you want to data like writing to a file
    sleep(0.5) #import step to avoid getting banned by server
    i += 1

# %% [markdown]
# ## Cleaning up the data and adding to a pandas dataframe

# %% [markdown]
# The data has been scraped as 35 seperate json files. We can now use this code below to parse each file, extract the desired columns, and sort into a dataframe. A lot of the cleaning uses boolean logic because the data in the files are not all organized identically. I had to go in and see how they were organized to come up with some conditions that would parse accordingly based on the organization of the file. I frist developed this for one dataset (conductivity) and found it can be used with most of the others as well. There could be a little thing or two that may need adjusting based on what data is being scrapped, but in general it is mostly unviersal for the DES data on NIST

# %%
outer_old = pd.DataFrame()
outer_new = pd.DataFrame()

for i in range(35): #edit the number based on how many files were scraped
    with open("/Users/jaime/Desktop/nist_data/viscosity/%s.json" % str(i+1)) as json_file:

        #grab data, data headers (names), the salt name
        json_full = json.load(json_file)                    
        json_data = pd.DataFrame(json_full['data'])
        json_datanames = np.array(json_full['dhead'])        # make names into array to add as columns headers for df
        json_data.columns =  json_datanames
        json_saltname = pd.DataFrame(json_full['components'])#components section contains names of DES components
        #print(json_saltname['name'])                #grabbing the HBD and HBA 

        inner_old = pd.DataFrame()
        inner_new = pd.DataFrame()

        #loop through the columns of the data, note that some of the 
        #json files are missing pressure data. 
        for indexer in range(len(json_data.columns)):        
            grab=json_data.columns[indexer]
            list = json_data[grab]
            my_list = [l[0] for l in list]
            dfmy_list = pd.DataFrame(my_list)
            dfmy_list.columns = [json_datanames[indexer][0]]
            inner_new = pd.concat([dfmy_list, inner_old], axis=1)
            inner_old = inner_new

        #print(inner_old.columns)
        
        
        #add the MW for HBD and HBA
        for i in range(len(json_saltname['name'])):
            if 'chloride' in json_saltname['name'][i] or 'bromide' in json_saltname['name'][i]:
                inner_old['HBA_MW']=json_saltname['mw'][i]
            else:
                inner_old['HBD_MW']=json_saltname['mw'][i]
                

        #add the DES components, i.e. HBA and HBD
        # they are not always listed in the same order on nist data, i.e., HBA always first. Will figure out later.
        for i in range(len(json_saltname['name'])):
            if 'chloride' in json_saltname['name'][i] or 'bromide' in json_saltname['name'][i]:
                inner_old['HBA']=json_saltname['name'][i]
            else:
                inner_old['HBD']=json_saltname['name'][i]
                
        #loop through the column names of the dataframe
        for j in range(len(inner_old.columns)):
            #if the words Mole fraction and a halogen are contained, values are correct and no value editing 
            #necessary and column is simply renamed to HBA mole fraction.
            if 'Mole fraction' in inner_old.columns[j] and 'chloride' in inner_old.columns[j] or 'Mole fraction' in inner_old.columns[j] and 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
            #if the words Mole Ratio and a halogen are contained, dataset was mislabeled but values are correct.
            #only need to rename column to HBA mole fraction.
            elif 'Mole ratio' in inner_old.columns[j] and 'chloride' in inner_old.columns[j] or 'Mole ratio' in inner_old.columns[j] and 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
            #if the words mole ratio are present, but no halogens, the ratio of the HBD is displayed and needs
            #to be changed to HBA mole fraction. First relabel the colum as HBA mole fraction.
            elif 'Mole ratio' in inner_old.columns[j] and not 'chloride' in inner_old.columns[j] or 'Mole ratio' in inner_old.columns[j] and not 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
                #apparently the numbers are strings so change to integer. May need to do this for every other column
                inner_old['HBA Mole Fraction'] = inner_old['HBA Mole Fraction'].astype(int)
                #next make an empty list that will hold all the new HBA mole fractions
                mole_fractions_list = []
                #loop through every HBD ratio in the column
                for k in range(len(inner_old['HBA Mole Fraction'])):
                    #Calculate the HBA mole fraction from every HBD ratio and append to the list
                    mole_fractions_list.append(1/(1+inner_old['HBA Mole Fraction'][k]))
                #finally make the list the new mole fraction column in the dataframe
                inner_old['HBA Mole Fraction'] = mole_fractions_list
            #in the last case, if the word mole fraction is present but not a halogen, HBD mole fraction is displayed.
            #Follow simialr process as before
            elif 'Mole fraction' in inner_old.columns[j] and not 'chloride' in inner_old.columns[j] or 'Mole fraction' in inner_old.columns[j] and not 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
                #convert to float instead since it is a decimal
                inner_old['HBA Mole Fraction'] = inner_old['HBA Mole Fraction'].astype(float)
                #empty list
                mole_fractions_list = []
                #loop through column
                for k in range(len(inner_old['HBA Mole Fraction'])):
                    #subtract 1 from HBD mole fraction to get HBA mole fraction and append to list
                    mole_fractions_list.append(1 - inner_old['HBA Mole Fraction'][k])
                #replace column   
                inner_old['HBA Mole Fraction'] = mole_fractions_list


        #add to the growing dataframe
        outer_new = pd.concat([inner_old, outer_old], axis = 0, ignore_index = True)
        outer_old = outer_new
    
outer_old.head(50)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:89: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                     HBA HBA Mole Fraction  HBA_MW  \
# 0           tetraethylammonium chloride          0.333333  165.71
# 1           tetraethylammonium chloride          0.333333  165.71
# 2           tetraethylammonium chloride          0.333333  165.71
# 3            tetraoctylammonium bromide          0.333333  546.81
# 4            tetraoctylammonium bromide          0.333333  546.81
# 5            tetraoctylammonium bromide          0.333333  546.81
# 6      trimethylbenzylammonium chloride               0.5  185.69
# 7      trimethylbenzylammonium chloride               0.5  185.69
# 8      trimethylbenzylammonium chloride               0.5  185.69
# 9      trimethylbenzylammonium chloride               0.5  185.69
# 10     trimethylbenzylammonium chloride               0.5  185.69
# 11          tetrabutylammonium chloride              0.25  277.92
# 12          tetrabutylammonium chloride              0.25  277.92
# 13          tetrabutylammonium chloride              0.25  277.92
# 14          tetrabutylammonium chloride              0.25  277.92
# 15          tetrabutylammonium chloride              0.25  277.92
# 16          tetraethylammonium chloride              0.25  165.71
# 17          tetraethylammonium chloride              0.25  165.71
# 18          tetraethylammonium chloride              0.25  165.71
# 19          tetraethylammonium chloride              0.25  165.71
# 20          tetraethylammonium chloride              0.25  165.71
# 21  benzyltriphenylphosphonium chloride              0.25  388.87
# 22  benzyltriphenylphosphonium chloride              0.25  388.87
# 23  benzyltriphenylphosphonium chloride              0.25  388.87
# 24  benzyltriphenylphosphonium chloride              0.25  388.87
# 25  benzyltriphenylphosphonium chloride              0.25  388.87
# 26  benzyltriphenylphosphonium chloride             0.167  388.87
# 27  benzyltriphenylphosphonium chloride             0.167  388.87
# 28  benzyltriphenylphosphonium chloride             0.167  388.87
# 29  benzyltriphenylphosphonium chloride             0.167  388.87
# 30  benzyltriphenylphosphonium chloride             0.167  388.87
# 31                                  NaN               0.5     NaN
# 32                                  NaN               0.5     NaN
# 33                                  NaN               0.5     NaN
# 34                                  NaN               0.5     NaN
# 35                                  NaN               0.5     NaN
# 36   methyltriphenylphosphonium bromide            0.3636  357.23
# 37   methyltriphenylphosphonium bromide            0.3636  357.23
# 38   methyltriphenylphosphonium bromide            0.3636  357.23
# 39   methyltriphenylphosphonium bromide            0.3636  357.23
# 40   methyltriphenylphosphonium bromide            0.3636  357.23
# 41   methyltriphenylphosphonium bromide            0.3636  357.23
# 42   methyltriphenylphosphonium bromide               0.2  357.23
# 43   methyltriphenylphosphonium bromide               0.2  357.23
# 44   methyltriphenylphosphonium bromide               0.2  357.23
# 45   methyltriphenylphosphonium bromide               0.2  357.23
# 46   methyltriphenylphosphonium bromide               0.2  357.23
# 47   methyltriphenylphosphonium bromide               0.2  357.23
# 48   methyltriphenylphosphonium bromide               0.2  357.23
# 49   methyltriphenylphosphonium bromide               0.2  357.23
#
#                        HBD  HBD_MW Pressure, kPa Temperature, K  \
# 0   2-hydroxyethanoic acid   76.05           101         303.15
# 1   2-hydroxyethanoic acid   76.05           101         323.15
# 2   2-hydroxyethanoic acid   76.05           101         353.15
# 3            decanoic acid  172.27           101         303.15
# 4            decanoic acid  172.27           101         323.15
# 5            decanoic acid  172.27           101         353.15
# 6              citric acid  192.12           101         312.91
# 7              citric acid  192.12           101         317.97
# 8              citric acid  192.12           101          323.1
# 9              citric acid  192.12           101         327.86
# 10             citric acid  192.12           101         332.88
# 11     4-oxopentanoic acid  116.12           101         293.15
# 12     4-oxopentanoic acid  116.12           101         303.15
# 13     4-oxopentanoic acid  116.12           101         313.15
# 14     4-oxopentanoic acid  116.12           101         323.15
# 15     4-oxopentanoic acid  116.12           101         333.15
# 16     4-oxopentanoic acid  116.12           101         293.15
# 17     4-oxopentanoic acid  116.12           101         303.15
# 18     4-oxopentanoic acid  116.12           101         313.15
# 19     4-oxopentanoic acid  116.12           101         323.15
# 20     4-oxopentanoic acid  116.12           101         333.15
# 21          1,2-ethanediol   62.07         101.3         328.15
# 22          1,2-ethanediol   62.07         101.3         338.15
# 23          1,2-ethanediol   62.07         101.3         348.15
# 24          1,2-ethanediol   62.07         101.3         358.15
# 25          1,2-ethanediol   62.07         101.3         368.15
# 26                glycerol   92.09         101.3         328.15
# 27                glycerol   92.09         101.3         338.15
# 28                glycerol   92.09         101.3         348.15
# 29                glycerol   92.09         101.3         358.15
# 30                glycerol   92.09         101.3         368.15
# 31                    urea   60.06          99.6         293.15
# 32                    urea   60.06          99.6         303.15
# 33                    urea   60.06          99.6         313.15
# 34                    urea   60.06          99.6         323.15
# 35                    urea   60.06          99.6         333.15
# 36                glycerol   92.09         101.3         318.15
# 37                glycerol   92.09         101.3         328.15
# 38                glycerol   92.09         101.3         338.15
# 39                glycerol   92.09         101.3         348.15
# 40                glycerol   92.09         101.3         358.15
# 41                glycerol   92.09         101.3         368.15
# 42          1,2-ethanediol   62.07         101.3          278.1
# 43          1,2-ethanediol   62.07         101.3         288.15
# 44          1,2-ethanediol   62.07         101.3         298.15
# 45          1,2-ethanediol   62.07         101.3         308.15
# 46          1,2-ethanediol   62.07         101.3         318.15
# 47          1,2-ethanediol   62.07         101.3         328.15
# 48          1,2-ethanediol   62.07         101.3         338.15
# 49          1,2-ethanediol   62.07         101.3         348.15
#
#    Viscosity, Pa&#8226;s
# 0                  0.268
# 1                  0.087
# 2                  0.027
# 3                  0.469
# 4                  0.174
# 5                  0.056
# 6                    237
# 7                    152
# 8                     89
# 9                   52.1
# 10                  28.1
# 11                0.1217
# 12                0.0656
# 13                0.0367
# 14                0.0255
# 15               0.01747
# 16                0.1301
# 17                0.0698
# 18                0.0391
# 19                0.0271
# 20               0.01871
# 21                   0.2
# 22                 0.086
# 23                0.0593
# 24                0.0505
# 25                0.0359
# 26                  0.55
# 27                  0.34
# 28                 0.119
# 29                0.0755
# 30                0.0387
# 31                1.8929
# 32                 0.687
# 33                0.2957
# 34                0.1459
# 35               0.08041
# 36                  0.89
# 37                  0.41
# 38                 0.206
# 39                 0.105
# 40                 0.077
# 41                0.0369
# 42                  0.34
# 43                 0.186
# 44                  0.11
# 45                0.0686
# 46                0.0395
# 47                0.0197
# 48                0.0054
# 49                0.0018

# %% [markdown]
# It appears there are some Nan's for the HBA column. I looked at the original data files and this was a weird ionic liquid that used urea, so technically not a DES which is why the parsing in my code didn't pick it up and name it accordingly. Just going to drop those rows and the rest should be fine, also will save this dataframe as a csv.

# %%
outer_old.dropna(inplace = True)

# %%
pd.DataFrame.to_csv(outer_old, path_or_buf='viscosity.csv', index=False)

# %%
pd.read_csv('viscosity.csv')
# Out:
#                                      HBA  HBA Mole Fraction  HBA_MW  \
# 0            tetraethylammonium chloride           0.333333  165.71
# 1            tetraethylammonium chloride           0.333333  165.71
# 2            tetraethylammonium chloride           0.333333  165.71
# 3             tetraoctylammonium bromide           0.333333  546.81
# 4             tetraoctylammonium bromide           0.333333  546.81
# 5             tetraoctylammonium bromide           0.333333  546.81
# 6       trimethylbenzylammonium chloride           0.500000  185.69
# 7       trimethylbenzylammonium chloride           0.500000  185.69
# 8       trimethylbenzylammonium chloride           0.500000  185.69
# 9       trimethylbenzylammonium chloride           0.500000  185.69
# 10      trimethylbenzylammonium chloride           0.500000  185.69
# 11           tetrabutylammonium chloride           0.250000  277.92
# 12           tetrabutylammonium chloride           0.250000  277.92
# 13           tetrabutylammonium chloride           0.250000  277.92
# 14           tetrabutylammonium chloride           0.250000  277.92
# 15           tetrabutylammonium chloride           0.250000  277.92
# 16           tetraethylammonium chloride           0.250000  165.71
# 17           tetraethylammonium chloride           0.250000  165.71
# 18           tetraethylammonium chloride           0.250000  165.71
# 19           tetraethylammonium chloride           0.250000  165.71
# 20           tetraethylammonium chloride           0.250000  165.71
# 21   benzyltriphenylphosphonium chloride           0.250000  388.87
# 22   benzyltriphenylphosphonium chloride           0.250000  388.87
# 23   benzyltriphenylphosphonium chloride           0.250000  388.87
# 24   benzyltriphenylphosphonium chloride           0.250000  388.87
# 25   benzyltriphenylphosphonium chloride           0.250000  388.87
# 26   benzyltriphenylphosphonium chloride           0.167000  388.87
# 27   benzyltriphenylphosphonium chloride           0.167000  388.87
# 28   benzyltriphenylphosphonium chloride           0.167000  388.87
# 29   benzyltriphenylphosphonium chloride           0.167000  388.87
# ..                                   ...                ...     ...
# 357          tetrapropylammonium bromide           0.500000  266.27
# 358          tetrapropylammonium bromide           0.500000  266.27
# 359          tetrapropylammonium bromide           0.500000  266.27
# 360          tetrapropylammonium bromide           0.500000  266.27
# 361          tetrapropylammonium bromide           0.500000  266.27
# 362          tetrapropylammonium bromide           0.500000  266.27
# 363          tetrabutylammonium chloride           0.500000  277.92
# 364          tetrabutylammonium chloride           0.500000  277.92
# 365          tetrabutylammonium chloride           0.667000  277.92
# 366          tetrabutylammonium chloride           0.800000  277.92
# 367          tetrabutylammonium chloride           0.500000  277.92
# 368          tetrabutylammonium chloride           0.667000  277.92
# 369          tetrabutylammonium chloride           0.750000  277.92
# 370          tetrabutylammonium chloride           0.800000  277.92
# 371          tetrabutylammonium chloride           0.500000  277.92
# 372          tetrabutylammonium chloride           0.667000  277.92
# 373          tetrabutylammonium chloride           0.750000  277.92
# 374          tetrabutylammonium chloride           0.800000  277.92
# 375          tetrabutylammonium chloride           0.500000  277.92
# 376          tetrabutylammonium chloride           0.667000  277.92
# 377          tetrabutylammonium chloride           0.750000  277.92
# 378          tetrabutylammonium chloride           0.800000  277.92
# 379          tetrabutylammonium chloride           0.500000  277.92
# 380          tetrabutylammonium chloride           0.667000  277.92
# 381          tetrabutylammonium chloride           0.750000  277.92
# 382          tetrabutylammonium chloride           0.800000  277.92
# 383          tetrabutylammonium chloride           0.500000  277.92
# 384          tetrabutylammonium chloride           0.667000  277.92
# 385          tetrabutylammonium chloride           0.750000  277.92
# 386          tetrabutylammonium chloride           0.800000  277.92
#
#                         HBD  HBD_MW  Pressure, kPa  Temperature, K  \
# 0    2-hydroxyethanoic acid   76.05          101.0          303.15
# 1    2-hydroxyethanoic acid   76.05          101.0          323.15
# 2    2-hydroxyethanoic acid   76.05          101.0          353.15
# 3             decanoic acid  172.27          101.0          303.15
# 4             decanoic acid  172.27          101.0          323.15
# 5             decanoic acid  172.27          101.0          353.15
# 6               citric acid  192.12          101.0          312.91
# 7               citric acid  192.12          101.0          317.97
# 8               citric acid  192.12          101.0          323.10
# 9               citric acid  192.12          101.0          327.86
# 10              citric acid  192.12          101.0          332.88
# 11      4-oxopentanoic acid  116.12          101.0          293.15
# 12      4-oxopentanoic acid  116.12          101.0          303.15
# 13      4-oxopentanoic acid  116.12          101.0          313.15
# 14      4-oxopentanoic acid  116.12          101.0          323.15
# 15      4-oxopentanoic acid  116.12          101.0          333.15
# 16      4-oxopentanoic acid  116.12          101.0          293.15
# 17      4-oxopentanoic acid  116.12          101.0          303.15
# 18      4-oxopentanoic acid  116.12          101.0          313.15
# 19      4-oxopentanoic acid  116.12          101.0          323.15
# 20      4-oxopentanoic acid  116.12          101.0          333.15
# 21           1,2-ethanediol   62.07          101.3          328.15
# 22           1,2-ethanediol   62.07          101.3          338.15
# 23           1,2-ethanediol   62.07          101.3          348.15
# 24           1,2-ethanediol   62.07          101.3          358.15
# 25           1,2-ethanediol   62.07          101.3          368.15
# 26                 glycerol   92.09          101.3          328.15
# 27                 glycerol   92.09          101.3          338.15
# 28                 glycerol   92.09          101.3          348.15
# 29                 glycerol   92.09          101.3          358.15
# ..                      ...     ...            ...             ...
# 357                glycerol   92.09          101.0          303.80
# 358                glycerol   92.09          101.0          313.70
# 359                glycerol   92.09          101.0          324.10
# 360                glycerol   92.09          101.0          333.90
# 361                glycerol   92.09          101.0          344.00
# 362                glycerol   92.09          101.0          354.00
# 363      triethylene glycol  150.17          101.0          293.15
# 364      triethylene glycol  150.17          101.0          303.15
# 365      triethylene glycol  150.17          101.0          303.15
# 366      triethylene glycol  150.17          101.0          303.15
# 367      triethylene glycol  150.17          101.0          313.15
# 368      triethylene glycol  150.17          101.0          313.15
# 369      triethylene glycol  150.17          101.0          313.15
# 370      triethylene glycol  150.17          101.0          313.15
# 371      triethylene glycol  150.17          101.0          323.15
# 372      triethylene glycol  150.17          101.0          323.15
# 373      triethylene glycol  150.17          101.0          323.15
# 374      triethylene glycol  150.17          101.0          323.15
# 375      triethylene glycol  150.17          101.0          333.15
# 376      triethylene glycol  150.17          101.0          333.15
# 377      triethylene glycol  150.17          101.0          333.15
# 378      triethylene glycol  150.17          101.0          333.15
# 379      triethylene glycol  150.17          101.0          343.15
# 380      triethylene glycol  150.17          101.0          343.15
# 381      triethylene glycol  150.17          101.0          343.15
# 382      triethylene glycol  150.17          101.0          343.15
# 383      triethylene glycol  150.17          101.0          353.15
# 384      triethylene glycol  150.17          101.0          353.15
# 385      triethylene glycol  150.17          101.0          353.15
# 386      triethylene glycol  150.17          101.0          353.15
#
#      Viscosity, Pa&#8226;s
# 0                  0.26800
# 1                  0.08700
# 2                  0.02700
# 3                  0.46900
# 4                  0.17400
# 5                  0.05600
# 6                237.00000
# 7                152.00000
# 8                 89.00000
# 9                 52.10000
# 10                28.10000
# 11                 0.12170
# 12                 0.06560
# 13                 0.03670
# 14                 0.02550
# 15                 0.01747
# 16                 0.13010
# 17                 0.06980
# 18                 0.03910
# 19                 0.02710
# 20                 0.01871
# 21                 0.20000
# 22                 0.08600
# 23                 0.05930
# 24                 0.05050
# 25                 0.03590
# 26                 0.55000
# 27                 0.34000
# 28                 0.11900
# 29                 0.07550
# ..                     ...
# 357                0.05900
# 358                0.03500
# 359                0.02330
# 360                0.01590
# 361                0.01100
# 362                0.00860
# 363                0.87000
# 364                0.54400
# 365                1.39900
# 366                3.26500
# 367                0.28900
# 368                0.95000
# 369                7.03200
# 370                1.90000
# 371                0.16600
# 372                0.49300
# 373                0.91000
# 374                0.86300
# 375                0.10100
# 376                0.26400
# 377                0.45200
# 378                0.41100
# 379                0.06810
# 380                0.15400
# 381                0.24500
# 382                0.20400
# 383                0.04470
# 384                0.09130
# 385                0.15600
# 386                0.10000
#
# [387 rows x 8 columns]
