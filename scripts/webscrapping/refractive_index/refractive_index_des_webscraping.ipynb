# %%
#bring imports here
import json
import requests
import numpy as np
import pandas as pd
import os
import sys
from time import sleep

# %% [markdown]
# ## Scraping the Data

# %% [markdown]
# #### A big shoutout to Wesley Beckner for developing his package "salty" from which the majority of this code shown here came from. He has done some really cool research with ionic liquids, check out his github at https://github.com/wesleybeckner/salty to see his original code, and other cool features of his package.

# %% [markdown]
# While the NIST database is specifically directed towards ionic liquids, there is actually a lot of deep eutectic sovlent (DES) data as well. We can basically employ the same methods Wesley did to get this very useful data.

# %% [markdown]
# When you search for data on NIST, there are specific 4 letter tags for each property. You can find these tags and get the url for the data page by inspecting the webpage and going to the network dection. Perform the search, and the full url with the 4 letter tag will be shown. ILThermo's 4-letter tag for refractive index is bByM. I Performed a search for all refractive index data with keyword as 'Deep Eutectic Solvents' and returned a decent amount of data.

# %% [markdown]
# URL for the data: https://ilthermo.boulder.nist.gov/ILT2/ilsearch?cmp=&ncmp=0&year=&auth=&keyw=deep%20eutectic%20solvent&prp=bByM

# %% [markdown]
# A note to save the json files outside of a github repo, preferably a local folder on your device. I ran into permission issues when trying to save the scraped data directly into my github repo

# %%
paper_url = "https://ilthermo.boulder.nist.gov/ILT2/ilsearch?cmp=&ncmp=0&year=&auth=&keyw=Deep%20eutectic%20solvent&prp=bByM"
 
r = requests.get(paper_url)
header = r.json()['header']
papers = r.json()['res']
i = 1 
data_url = 'http://ilthermo.boulder.nist.gov/ILT2/ilset?set={paper_id}'
for paper in papers[:]: 
    
    r = requests.get(data_url.format(paper_id=paper[0]))
    data = r.json()['data']
    with open("/Users/jaime/Desktop/nist_data/refractive_index/%s.json" % i, "w") as outfile: #set destination path for files
        json.dump(r.json(), outfile)
    #then do whatever you want to data like writing to a file
    sleep(0.5) #import step to avoid getting banned by server
    i += 1

# %% [markdown]
# ## Cleaning up the data and adding to a pandas dataframe

# %% [markdown]
# The data has been scraped as 34 seperate json files. We can now use this code below to parse each file, extract the desired columns, and sort into a dataframe. A lot of the cleaning uses boolean logic because the data in the files are not all organized identically. I had to go in and see how they were organized to come up with some conditions that would parse accordingly based on the organization of the file. I frist developed this for one dataset (conductivity) and found it can be used with most of the others as well. There could be a little thing or two that may need adjusting based on what data is being scrapped, but in general it is mostly unviersal for the DES data on NIST

# %%
outer_old = pd.DataFrame()
outer_new = pd.DataFrame()

for i in range(34): #edit the number based on how many files were scraped
    with open("/Users/jaime/Desktop/nist_data/refractive_index/%s.json" % str(i+1)) as json_file:

        #grab data, data headers (names), the salt name
        json_full = json.load(json_file)                    
        json_data = pd.DataFrame(json_full['data'])
        json_datanames = np.array(json_full['dhead'])        # make names into array to add as columns headers for df
        json_data.columns =  json_datanames
        json_saltname = pd.DataFrame(json_full['components'])#components section contains names of DES components
        #print(json_saltname['name'])                #grabbing the HBD and HBA 

        inner_old = pd.DataFrame()
        inner_new = pd.DataFrame()

        #loop through the columns of the data, note that some of the 
        #json files are missing pressure data. 
        for indexer in range(len(json_data.columns)):        
            grab=json_data.columns[indexer]
            list = json_data[grab]
            my_list = [l[0] for l in list]
            dfmy_list = pd.DataFrame(my_list)
            dfmy_list.columns = [json_datanames[indexer][0]]
            inner_new = pd.concat([dfmy_list, inner_old], axis=1)
            inner_old = inner_new

        #print(inner_old.columns)


        #add the MW for HBD and HBA
        for i in range(len(json_saltname['name'])):
            if 'chloride' in json_saltname['name'][i] or 'bromide' in json_saltname['name'][i]:
                inner_old['HBA_MW']=json_saltname['mw'][i]
            else:
                inner_old['HBD_MW']=json_saltname['mw'][i]
                

        #add the DES components, i.e. HBA and HBD
        # they are not always listed in the same order on nist data, i.e., HBA always first. Will figure out later.
        for i in range(len(json_saltname['name'])):
            if 'chloride' in json_saltname['name'][i] or 'bromide' in json_saltname['name'][i]:
                inner_old['HBA']=json_saltname['name'][i]
            else:
                inner_old['HBD']=json_saltname['name'][i]
                
        #loop through the column names of the dataframe
        for j in range(len(inner_old.columns)):
            #if the words Mole fraction and a halogen are contained, values are correct and no value editing 
            #necessary and column is simply renamed to HBA mole fraction.
            if 'Mole fraction' in inner_old.columns[j] and 'chloride' in inner_old.columns[j] or 'Mole fraction' in inner_old.columns[j] and 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
            #if the words Mole Ratio and a halogen are contained, dataset was mislabeled but values are correct.
            #only need to rename column to HBA mole fraction.
            elif 'Mole ratio' in inner_old.columns[j] and 'chloride' in inner_old.columns[j] or 'Mole ratio' in inner_old.columns[j] and 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
            #if the words mole ratio are present, but no halogens, the ratio of the HBD is displayed and needs
            #to be changed to HBA mole fraction. First relabel the colum as HBA mole fraction.
            elif 'Mole ratio' in inner_old.columns[j] and not 'chloride' in inner_old.columns[j] or 'Mole ratio' in inner_old.columns[j] and not 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
                #apparently the numbers are strings so change to integer. May need to do this for every other column
                inner_old['HBA Mole Fraction'] = inner_old['HBA Mole Fraction'].astype(int)
                #next make an empty list that will hold all the new HBA mole fractions
                mole_fractions_list = []
                #loop through every HBD ratio in the column
                for k in range(len(inner_old['HBA Mole Fraction'])):
                    #Calculate the HBA mole fraction from every HBD ratio and append to the list
                    mole_fractions_list.append(1/(1+inner_old['HBA Mole Fraction'][k]))
                #finally make the list the new mole fraction column in the dataframe
                inner_old['HBA Mole Fraction'] = mole_fractions_list
            #in the last case, if the word mole fraction is present but not a halogen, HBD mole fraction is displayed.
            #Follow simialr process as before
            elif 'Mole fraction' in inner_old.columns[j] and not 'chloride' in inner_old.columns[j] or 'Mole fraction' in inner_old.columns[j] and not 'bromide' in inner_old.columns[j]:
                inner_old = inner_old.rename(columns={inner_old.columns[j]:'HBA Mole Fraction'})
                #convert to float instead since it is a decimal
                inner_old['HBA Mole Fraction'] = inner_old['HBA Mole Fraction'].astype(float)
                #empty list
                mole_fractions_list = []
                #loop through column
                for k in range(len(inner_old['HBA Mole Fraction'])):
                    #subtract 1 from HBD mole fraction to get HBA mole fraction and append to list
                    mole_fractions_list.append(1 - inner_old['HBA Mole Fraction'][k])
                #replace column   
                inner_old['HBA Mole Fraction'] = mole_fractions_list


        #add to the growing dataframe
        outer_new = pd.concat([inner_old, outer_old], axis = 0, ignore_index = True)
        outer_old = outer_new
    
outer_old.head(50)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:89: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                                     HBA HBA Mole Fraction  HBA_MW  \
# 0           tetrapropylammonium bromide             0.333  266.27
# 1                                   NaN               0.5     NaN
# 2   benzyltriphenylphosphonium chloride             0.833  388.87
# 3   benzyltriphenylphosphonium chloride             0.833  388.87
# 4   benzyltriphenylphosphonium chloride              0.75  388.87
# 5   benzyltriphenylphosphonium chloride              0.75  388.87
# 6    methyltriphenylphosphonium bromide              0.16  357.23
# 7    methyltriphenylphosphonium bromide               0.2  357.23
# 8    methyltriphenylphosphonium bromide              0.25  357.23
# 9    methyltriphenylphosphonium bromide               0.2  357.23
# 10   methyltriphenylphosphonium bromide              0.25  357.23
# 11   methyltriphenylphosphonium bromide              0.34  357.23
# 12   methyltriphenylphosphonium bromide              0.16  357.23
# 13   methyltriphenylphosphonium bromide               0.2  357.23
# 14   methyltriphenylphosphonium bromide              0.25  357.23
# 15   methyltriphenylphosphonium bromide               0.8  357.23
# 16   methyltriphenylphosphonium bromide               0.8  357.23
# 17   methyltriphenylphosphonium bromide               0.8  357.23
# 18   methyltriphenylphosphonium bromide               0.8  357.23
# 19   methyltriphenylphosphonium bromide             0.889  357.23
# 20   methyltriphenylphosphonium bromide             0.889  357.23
# 21   methyltriphenylphosphonium bromide             0.889  357.23
# 22   methyltriphenylphosphonium bromide             0.889  357.23
# 23   methyltriphenylphosphonium bromide             0.889  357.23
# 24   methyltriphenylphosphonium bromide             0.889  357.23
# 25   methyltriphenylphosphonium bromide            0.6364  357.23
# 26   methyltriphenylphosphonium bromide            0.6364  357.23
# 27   methyltriphenylphosphonium bromide            0.6364  357.23
# 28   methyltriphenylphosphonium bromide            0.6364  357.23
# 29   methyltriphenylphosphonium bromide            0.6364  357.23
# 30   methyltriphenylphosphonium bromide            0.6364  357.23
# 31     trimethylbenzylammonium chloride               0.5  185.69
# 32     trimethylbenzylammonium chloride               0.5  185.69
# 33     trimethylbenzylammonium chloride               0.5  185.69
# 34     trimethylbenzylammonium chloride               0.5  185.69
# 35     trimethylbenzylammonium chloride               0.5  185.69
# 36     trimethylbenzylammonium chloride               0.5  185.69
# 37     trimethylbenzylammonium chloride               0.5  185.69
# 38     trimethylbenzylammonium chloride               0.5  185.69
# 39     trimethylbenzylammonium chloride               0.5  185.69
# 40     trimethylbenzylammonium chloride               0.5  185.69
# 41     trimethylbenzylammonium chloride               0.5  185.69
# 42     trimethylbenzylammonium chloride               0.5  185.69
# 43     trimethylbenzylammonium chloride               0.5  185.69
# 44     trimethylbenzylammonium chloride               0.5  185.69
# 45     trimethylbenzylammonium chloride               0.5  185.69
# 46     trimethylbenzylammonium chloride               0.5  185.69
# 47     trimethylbenzylammonium chloride               0.5  185.69
# 48     trimethylbenzylammonium chloride               0.3  185.69
# 49     trimethylbenzylammonium chloride               0.3  185.69
#
#                              HBD  HBD_MW Pressure, kPa  \
# 0                 1,6-hexanediol  118.18         101.3
# 1                           urea   60.06          99.6
# 2                       glycerol   92.09         101.3
# 3                       glycerol   92.09         101.3
# 4                 1,2-ethanediol   62.07         101.3
# 5                 1,2-ethanediol   62.07         101.3
# 6                 1,2-ethanediol   62.07           101
# 7                 1,2-ethanediol   62.07           101
# 8                 1,2-ethanediol   62.07           101
# 9                       glycerol   92.09           101
# 10                      glycerol   92.09           101
# 11                      glycerol   92.09           101
# 12            triethylene glycol  150.17           101
# 13            triethylene glycol  150.17           101
# 14            triethylene glycol  150.17           101
# 15                1,2-ethanediol   62.07         101.3
# 16                1,2-ethanediol   62.07         101.3
# 17                1,2-ethanediol   62.07         101.3
# 18                1,2-ethanediol   62.07         101.3
# 19      2,2,2-trifluoroacetamide  113.04         101.3
# 20      2,2,2-trifluoroacetamide  113.04         101.3
# 21      2,2,2-trifluoroacetamide  113.04         101.3
# 22      2,2,2-trifluoroacetamide  113.04         101.3
# 23      2,2,2-trifluoroacetamide  113.04         101.3
# 24      2,2,2-trifluoroacetamide  113.04         101.3
# 25                      glycerol   92.09         101.3
# 26                      glycerol   92.09         101.3
# 27                      glycerol   92.09         101.3
# 28                      glycerol   92.09         101.3
# 29                      glycerol   92.09         101.3
# 30                      glycerol   92.09         101.3
# 31              ethanedioic acid   90.03           101
# 32              ethanedioic acid   90.03           101
# 33              ethanedioic acid   90.03           101
# 34              ethanedioic acid   90.03           101
# 35              ethanedioic acid   90.03           101
# 36              ethanedioic acid   90.03           101
# 37              ethanedioic acid   90.03           101
# 38              ethanedioic acid   90.03           101
# 39                   citric acid  192.12           101
# 40                   citric acid  192.12           101
# 41                   citric acid  192.12           101
# 42                   citric acid  192.12           101
# 43                   citric acid  192.12           101
# 44                   citric acid  192.12           101
# 45                   citric acid  192.12           101
# 46                   citric acid  192.12           101
# 47                   citric acid  192.12           101
# 48  4-methylbenzenesulfonic acid  172.20           101
# 49  4-methylbenzenesulfonic acid  172.20           101
#
#    Refractive index (Na D-line) Temperature, K
# 0                       1.47923         313.15
# 1                         1.493         293.15
# 2                        1.5502         328.15
# 3                        1.5168         338.15
# 4                        1.5258         328.15
# 5                        1.5309         338.15
# 6                        1.5398         298.15
# 7                         1.553         298.15
# 8                        1.5678         298.15
# 9                        1.5597         298.15
# 10                       1.5715         298.15
# 11                       1.5917         298.15
# 12                       1.5178         298.15
# 13                       1.5263         298.15
# 14                       1.5417         298.15
# 15                       1.5622         288.15
# 16                       1.5542         308.15
# 17                       1.5483         328.15
# 18                       1.5446         338.15
# 19                       1.4913         288.15
# 20                       1.4849         298.15
# 21                       1.4824         308.15
# 22                       1.4782         318.15
# 23                       1.4745         328.15
# 24                       1.4737         338.15
# 25                       1.5708         288.15
# 26                       1.5666         298.15
# 27                       1.5656         308.15
# 28                       1.5627         318.15
# 29                       1.5607         328.15
# 30                       1.5578         338.15
# 31                      1.51967         293.08
# 32                      1.51775         298.05
# 33                      1.51583         303.02
# 34                       1.5143         308.15
# 35                       1.5129         313.04
# 36                      1.51189         318.17
# 37                      1.51049         323.06
# 38                      1.50896         328.11
# 39                      1.52674         293.15
# 40                      1.52546         298.12
# 41                      1.52432         303.09
# 42                      1.52266         308.22
# 43                      1.52126         313.03
# 44                       1.5196         318.08
# 45                      1.51807         323.05
# 46                      1.51641         328.18
# 47                      1.51514         333.07
# 48                      1.54846         293.13
# 49                      1.54642         298.02

# %% [markdown]
# It appears there are some Nan's for the HBA column. I looked at the original data files and this was a weird ionic liquid that used urea, so technically not a DES which is why the parsing in my code didn't pick it up and name it accordingly. Just going to drop those rows and the rest should be fine, also will save this dataframe as a csv.

# %%
outer_old.dropna(inplace = True)

# %%
pd.DataFrame.to_csv(outer_old, path_or_buf='ref_index.csv', index=False)

# %%
pd.read_csv('ref_index.csv')
# Out:
#                                      HBA  HBA Mole Fraction  HBA_MW  \
# 0            tetrapropylammonium bromide             0.3330  266.27
# 1    benzyltriphenylphosphonium chloride             0.8330  388.87
# 2    benzyltriphenylphosphonium chloride             0.8330  388.87
# 3    benzyltriphenylphosphonium chloride             0.7500  388.87
# 4    benzyltriphenylphosphonium chloride             0.7500  388.87
# 5     methyltriphenylphosphonium bromide             0.1600  357.23
# 6     methyltriphenylphosphonium bromide             0.2000  357.23
# 7     methyltriphenylphosphonium bromide             0.2500  357.23
# 8     methyltriphenylphosphonium bromide             0.2000  357.23
# 9     methyltriphenylphosphonium bromide             0.2500  357.23
# 10    methyltriphenylphosphonium bromide             0.3400  357.23
# 11    methyltriphenylphosphonium bromide             0.1600  357.23
# 12    methyltriphenylphosphonium bromide             0.2000  357.23
# 13    methyltriphenylphosphonium bromide             0.2500  357.23
# 14    methyltriphenylphosphonium bromide             0.8000  357.23
# 15    methyltriphenylphosphonium bromide             0.8000  357.23
# 16    methyltriphenylphosphonium bromide             0.8000  357.23
# 17    methyltriphenylphosphonium bromide             0.8000  357.23
# 18    methyltriphenylphosphonium bromide             0.8890  357.23
# 19    methyltriphenylphosphonium bromide             0.8890  357.23
# 20    methyltriphenylphosphonium bromide             0.8890  357.23
# 21    methyltriphenylphosphonium bromide             0.8890  357.23
# 22    methyltriphenylphosphonium bromide             0.8890  357.23
# 23    methyltriphenylphosphonium bromide             0.8890  357.23
# 24    methyltriphenylphosphonium bromide             0.6364  357.23
# 25    methyltriphenylphosphonium bromide             0.6364  357.23
# 26    methyltriphenylphosphonium bromide             0.6364  357.23
# 27    methyltriphenylphosphonium bromide             0.6364  357.23
# 28    methyltriphenylphosphonium bromide             0.6364  357.23
# 29    methyltriphenylphosphonium bromide             0.6364  357.23
# ..                                   ...                ...     ...
# 350          tetrapropylammonium bromide             0.4000  266.27
# 351          tetrapropylammonium bromide             0.4000  266.27
# 352          tetrabutylammonium chloride             0.5000  277.92
# 353          tetrabutylammonium chloride             0.6670  277.92
# 354          tetrabutylammonium chloride             0.7500  277.92
# 355          tetrabutylammonium chloride             0.8000  277.92
# 356          tetrabutylammonium chloride             0.5000  277.92
# 357          tetrabutylammonium chloride             0.6670  277.92
# 358          tetrabutylammonium chloride             0.7500  277.92
# 359          tetrabutylammonium chloride             0.8000  277.92
# 360          tetrabutylammonium chloride             0.5000  277.92
# 361          tetrabutylammonium chloride             0.6670  277.92
# 362          tetrabutylammonium chloride             0.7500  277.92
# 363          tetrabutylammonium chloride             0.8000  277.92
# 364          tetrabutylammonium chloride             0.5000  277.92
# 365          tetrabutylammonium chloride             0.6670  277.92
# 366          tetrabutylammonium chloride             0.7500  277.92
# 367          tetrabutylammonium chloride             0.8000  277.92
# 368          tetrabutylammonium chloride             0.5000  277.92
# 369          tetrabutylammonium chloride             0.6670  277.92
# 370          tetrabutylammonium chloride             0.7500  277.92
# 371          tetrabutylammonium chloride             0.8000  277.92
# 372          tetrabutylammonium chloride             0.5000  277.92
# 373          tetrabutylammonium chloride             0.6670  277.92
# 374          tetrabutylammonium chloride             0.7500  277.92
# 375          tetrabutylammonium chloride             0.8000  277.92
# 376          tetrabutylammonium chloride             0.5000  277.92
# 377          tetrabutylammonium chloride             0.6670  277.92
# 378          tetrabutylammonium chloride             0.7500  277.92
# 379          tetrabutylammonium chloride             0.8000  277.92
#
#                           HBD  HBD_MW  Pressure, kPa  \
# 0              1,6-hexanediol  118.18          101.3
# 1                    glycerol   92.09          101.3
# 2                    glycerol   92.09          101.3
# 3              1,2-ethanediol   62.07          101.3
# 4              1,2-ethanediol   62.07          101.3
# 5              1,2-ethanediol   62.07          101.0
# 6              1,2-ethanediol   62.07          101.0
# 7              1,2-ethanediol   62.07          101.0
# 8                    glycerol   92.09          101.0
# 9                    glycerol   92.09          101.0
# 10                   glycerol   92.09          101.0
# 11         triethylene glycol  150.17          101.0
# 12         triethylene glycol  150.17          101.0
# 13         triethylene glycol  150.17          101.0
# 14             1,2-ethanediol   62.07          101.3
# 15             1,2-ethanediol   62.07          101.3
# 16             1,2-ethanediol   62.07          101.3
# 17             1,2-ethanediol   62.07          101.3
# 18   2,2,2-trifluoroacetamide  113.04          101.3
# 19   2,2,2-trifluoroacetamide  113.04          101.3
# 20   2,2,2-trifluoroacetamide  113.04          101.3
# 21   2,2,2-trifluoroacetamide  113.04          101.3
# 22   2,2,2-trifluoroacetamide  113.04          101.3
# 23   2,2,2-trifluoroacetamide  113.04          101.3
# 24                   glycerol   92.09          101.3
# 25                   glycerol   92.09          101.3
# 26                   glycerol   92.09          101.3
# 27                   glycerol   92.09          101.3
# 28                   glycerol   92.09          101.3
# 29                   glycerol   92.09          101.3
# ..                        ...     ...            ...
# 350        triethylene glycol  150.17          100.0
# 351        triethylene glycol  150.17          100.0
# 352        triethylene glycol  150.17          101.0
# 353        triethylene glycol  150.17          101.0
# 354        triethylene glycol  150.17          101.0
# 355        triethylene glycol  150.17          101.0
# 356        triethylene glycol  150.17          101.0
# 357        triethylene glycol  150.17          101.0
# 358        triethylene glycol  150.17          101.0
# 359        triethylene glycol  150.17          101.0
# 360        triethylene glycol  150.17          101.0
# 361        triethylene glycol  150.17          101.0
# 362        triethylene glycol  150.17          101.0
# 363        triethylene glycol  150.17          101.0
# 364        triethylene glycol  150.17          101.0
# 365        triethylene glycol  150.17          101.0
# 366        triethylene glycol  150.17          101.0
# 367        triethylene glycol  150.17          101.0
# 368        triethylene glycol  150.17          101.0
# 369        triethylene glycol  150.17          101.0
# 370        triethylene glycol  150.17          101.0
# 371        triethylene glycol  150.17          101.0
# 372        triethylene glycol  150.17          101.0
# 373        triethylene glycol  150.17          101.0
# 374        triethylene glycol  150.17          101.0
# 375        triethylene glycol  150.17          101.0
# 376        triethylene glycol  150.17          101.0
# 377        triethylene glycol  150.17          101.0
# 378        triethylene glycol  150.17          101.0
# 379        triethylene glycol  150.17          101.0
#
#      Refractive index (Na D-line)  Temperature, K
# 0                         1.47923          313.15
# 1                         1.55020          328.15
# 2                         1.51680          338.15
# 3                         1.52580          328.15
# 4                         1.53090          338.15
# 5                         1.53980          298.15
# 6                         1.55300          298.15
# 7                         1.56780          298.15
# 8                         1.55970          298.15
# 9                         1.57150          298.15
# 10                        1.59170          298.15
# 11                        1.51780          298.15
# 12                        1.52630          298.15
# 13                        1.54170          298.15
# 14                        1.56220          288.15
# 15                        1.55420          308.15
# 16                        1.54830          328.15
# 17                        1.54460          338.15
# 18                        1.49130          288.15
# 19                        1.48490          298.15
# 20                        1.48240          308.15
# 21                        1.47820          318.15
# 22                        1.47450          328.15
# 23                        1.47370          338.15
# 24                        1.57080          288.15
# 25                        1.56660          298.15
# 26                        1.56560          308.15
# 27                        1.56270          318.15
# 28                        1.56070          328.15
# 29                        1.55780          338.15
# ..                            ...             ...
# 350                       1.46080          343.10
# 351                       1.45740          353.30
# 352                       1.48000          293.15
# 353                       1.48510          293.15
# 354                       1.48580          293.15
# 355                       1.48710          293.15
# 356                       1.47720          303.15
# 357                       1.48210          303.15
# 358                       1.48360          303.15
# 359                       1.48410          303.15
# 360                       1.47420          313.15
# 361                       1.47900          313.15
# 362                       1.48060          313.15
# 363                       1.48110          313.15
# 364                       1.47110          323.15
# 365                       1.47600          323.15
# 366                       1.47770          323.15
# 367                       1.47810          323.15
# 368                       1.46780          333.15
# 369                       1.47310          333.15
# 370                       1.47470          333.15
# 371                       1.47520          333.15
# 372                       1.46460          343.15
# 373                       1.47010          343.15
# 374                       1.47170          343.15
# 375                       1.47220          343.15
# 376                       1.46140          353.15
# 377                       1.46730          353.15
# 378                       1.46860          353.15
# 379                       1.46920          353.15
#
# [380 rows x 8 columns]
