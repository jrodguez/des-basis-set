# %%
import pubchempy as pcp
import pandas as pd
import numpy as np
import requests
import json

# %% [markdown]
# ### The purpose of this notebook is to use pubchem's online data retreival resources, in this case PUG REST specifically, in order to expand material candidate datasets by searching for other materials/compounds with similar structure. I'm sure there are much better in depth and complex methods to achieve this, but this should be viewed as a rather straight forward and quick approach for basic material screening and discovery.

# %% [markdown]
# The pubchempy API can be viewed here: https://pubchempy.readthedocs.io/en/latest/api.html

# %% [markdown]
# The PUG REST documentation can be viewed here: https://pubchemdocs.ncbi.nlm.nih.gov/pug-rest

# %% [markdown]
# According to PUG REST, there are a few methods to do chemical searches based on structure. The most appropriate one seems to be a similarity search, which simply put, searches for similarities in compounds based on their 2D structure. You can sue a cid, smiles string, or InChl to search by. They also show a "standard" and "fast" method, in which the regular method requires two subsequent requests to retrieve the data, and the fast method just instantaneously gives you the results. After playing around with both, I didn't see any difference in the results I was getting, so i'm going to stick to the very convenient "fast" method.

# %% [markdown]
# We can initiate a request for the data below. We will be using our trusty friend choline chloride as an initial example, searching by it's smiles string. Note you also have the option to attach constraints to the end of the request, such a max number of results returned, and more useful, a minimum threshold for the Tanimoto score, which is basically an index or score of chemical similarity. Choosing a threshold value is a little arbitrary, too low of a threshold and the resulting compounds may not be as similar as you would like. Too high of a threshold yielded a much smaller quantity of results, but they were almost "too" similar, most were just radioactive compounds of choline chloride. The default threshold value is 90, I'm going to use 80 to get a few more variety in the returned structures.

# %%
request_url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/fastsimilarity_2d/smiles/C[N+](C)(C)CCO.[Cl-]/cids/JSON?Threshold=80"

request = requests.get(request_url)
request_json = request.json()

# %% [markdown]
# The result is returned as a very short dictionary, and we can parse it as such to get the list of similar compounds.

# %%
request_json['IdentifierList']['CID']
# Out:
# [6209,
#  7618,
#  7902,
#  7497,
#  305,
#  7767,
#  37511,
#  14074,
#  8769,
#  31255,
#  74724,
#  80057,
#  75171,
#  14989482,
#  449688,
#  198804,
#  162303,
#  118525,
#  101814,
#  87300,
#  85865,
#  84429,
#  76721,
#  62288,
#  60232,
#  42848,
#  16942,
#  6552,
#  18772452,
#  15419000,
#  14859573,
#  449689,
#  449673,
#  404592,
#  404591,
#  287929,
#  200674,
#  45414,
#  17916,
#  16941,
#  24799587,
#  6950248,
#  6395359,
#  6328237,
#  5249138,
#  2723762,
#  357051,
#  199656,
#  172277,
#  152431,
#  83283,
#  80058,
#  70682,
#  25781,
#  23437,
#  71310335,
#  23352174,
#  23066982,
#  16217619,
#  16213540,
#  16213539,
#  15029190,
#  15029175,
#  14943907,
#  14859571,
#  14859569,
#  13778189,
#  12249371,
#  12239068,
#  3063123,
#  3017041,
#  413857,
#  342520,
#  293482,
#  249874,
#  239819,
#  237041,
#  200221,
#  170746,
#  162304,
#  120823,
#  117618,
#  116739,
#  103983,
#  87940,
#  83239,
#  57052,
#  46081,
#  23438,
#  88729402,
#  87876898,
#  87573822,
#  87389474,
#  86759356,
#  86752887,
#  86106984,
#  71360639,
#  71309220,
#  71309123,
#  71308987,
#  57483587,
#  57266120,
#  55252930,
#  46209411,
#  45791167,
#  23680072,
#  23675624,
#  23459462,
#  22763438,
#  22663003,
#  22495101,
#  22218551,
#  22160862,
#  22134097,
#  21988085,
#  21149523,
#  21149385,
#  21116013,
#  20547070,
#  20480851,
#  20326578,
#  20056506,
#  19607192,
#  19030402,
#  18786766,
#  18520755,
#  18323499,
#  18004298,
#  18003851,
#  17885833,
#  15894840,
#  15029177,
#  14818435,
#  13778190,
#  13650816,
#  13635719,
#  13076199,
#  12388301,
#  12388300,
#  11743787,
#  11715488,
#  10410806,
#  10313070,
#  7057913,
#  6452936,
#  5102550,
#  3083623,
#  231181,
#  199607,
#  185204,
#  172363,
#  139167,
#  124318,
#  47153,
#  17383,
#  134694270,
#  134530558,
#  134519098,
#  131729809,
#  130126311,
#  129856292,
#  129810301,
#  129704045,
#  129676557,
#  129673118,
#  126959875,
#  123877633,
#  123607238,
#  123549545,
#  122674908,
#  122421178,
#  121418932,
#  121349010,
#  118588468,
#  118511692,
#  118511685,
#  118377787,
#  117810189,
#  117779754,
#  91148178,
#  91019404,
#  90302214,
#  90073837,
#  89571979,
#  89522529,
#  89206203,
#  88840783,
#  88811916,
#  88801749,
#  88801725,
#  88801661,
#  88790435,
#  88790431,
#  88758365,
#  88758024,
#  88757693,
#  88746345,
#  88746344,
#  88745191,
#  88731463,
#  88728525,
#  88709400,
#  88690620,
#  88689369,
#  88665746,
#  88641531,
#  88637628,
#  88620328,
#  88605277,
#  88603424,
#  88510998,
#  88510586,
#  88467480,
#  88461318,
#  88449429,
#  88449427,
#  88431239,
#  88431111,
#  88418050,
#  88416182,
#  88404928,
#  88401727,
#  88396688,
#  88389476,
#  88387731,
#  88365386,
#  88348581,
#  88339649,
#  88317620,
#  88290170,
#  88243883,
#  88223497,
#  88218666,
#  88205214,
#  88110721,
#  88104617,
#  88087318,
#  88084031,
#  87948380,
#  87948379,
#  87910475,
#  87906549,
#  87906535,
#  87906532,
#  87878564,
#  87878560,
#  87827883,
#  87633730,
#  87584963,
#  87574825,
#  87574742,
#  87573823,
#  87559075,
#  87522763,
#  87522762,
#  87507505,
#  87506840,
#  87506839,
#  87504301,
#  87478587,
#  87457088,
#  87442202,
#  87442201,
#  87440432,
#  87410002,
#  87359600,
#  87359599,
#  87349193,
#  87344258,
#  87344256,
#  87342832,
#  87328771,
#  87313723,
#  87313722,
#  87276333,
#  87243796,
#  87229148,
#  87229147,
#  87222642,
#  87220219,
#  87220218,
#  87201804,
#  87191000,
#  87185778,
#  87169779,
#  87151491,
#  87139315,
#  87134424,
#  87101438,
#  87091787,
#  87076506,
#  87074423,
#  87063851,
#  86747029,
#  86742466,
#  86630381,
#  86628599,
#  86591463,
#  86589564,
#  86150008,
#  86107154,
#  85990283,
#  85682556,
#  85544516,
#  77519168,
#  72666542,
#  60128857,
#  60113876,
#  60113875,
#  60098746,
#  60076646,
#  60059701,
#  60059700,
#  60059691,
#  60059690,
#  60059689,
#  59897350,
#  59824600,
#  59736176,
#  59736175,
#  59502008,
#  59502007,
#  59301712,
#  59270461,
#  59266770,
#  59143868,
#  59143861,
#  59099898,
#  59095200,
#  59087635,
#  59058074,
#  59057980,
#  59037477,
#  58943013,
#  58943008,
#  58942973,
#  58904293,
#  58881669,
#  58881662,
#  58807577,
#  58731643,
#  58636020,
#  58624109,
#  58623528,
#  58619806,
#  58612468,
#  58602918,
#  58490988,
#  58104770,
#  57880219,
#  57880218,
#  57775462,
#  57694920,
#  57694919,
#  57694918,
#  57694916,
#  57589366,
#  57589365,
#  57589364,
#  57589358,
#  57585372,
#  57585182,
#  57568725,
#  57541007,
#  57507875,
#  57464381,
#  57449728,
#  57300934,
#  57284186,
#  57250236,
#  57235008,
#  57200048,
#  57187374,
#  57084703,
#  57081400,
#  57031094,
#  57027492,
#  54759110,
#  54594038,
#  54540363,
#  54512402,
#  54503316,
#  54438112,
#  54342003,
#  54303922,
#  54268619,
#  54253422,
#  54167145,
#  54146804,
#  54130009,
#  54024516,
#  53906442,
#  53789197,
#  53704975,
#  53652043,
#  52918392,
#  45087581,
#  44151198,
#  44147997,
#  25217750,
#  25217749,
#  25217748,
#  25217746,
#  25217745,
#  25217431,
#  23700456,
#  23591815,
#  23378680,
#  22975403,
#  22947117,
#  22928238,
#  22898481,
#  22894427,
#  22731883,
#  22731847,
#  22713030,
#  22675985,
#  22642448,
#  22642445,
#  22642442,
#  22642438,
#  22642431,
#  22610626,
#  22495100,
#  22476691,
#  22436573,
#  22326192,
#  22319922,
#  22218487,
#  22179222,
#  22179221,
#  22179170,
#  22162397,
#  22160861,
#  22153990,
#  22138611,
#  22138602,
#  22104972,
#  22035081,
#  22030569,
#  22024138,
#  21928691,
#  21895766,
#  21884707,
#  21831782,
#  21733975,
#  21651684,
#  21584112,
#  21559489,
#  21559488,
#  21540773,
#  21431001,
#  21257979,
#  21192048,
#  21116090,
#  20977727,
#  20750796,
#  20741933,
#  20696631,
#  20593616,
#  20536855,
#  20480699,
#  20278489,
#  20195019,
#  20063188,
#  19934175,
#  19844489,
#  19844483,
#  19817460,
#  19708476,
#  19429958,
#  19076065,
#  19044127,
#  19031249,
#  18990765,
#  18941644,
#  18786263,
#  18715985,
#  18637976,
#  18637975,
#  18620316,
#  18515395,
#  18475202,
#  18469782,
#  18415679,
#  17983236,
#  16217620,
#  16213402,
#  16206407,
#  15894841,
#  15594924,
#  15560809,
#  14859576,
#  14859574,
#  14859572,
#  14859570,
#  14767686,
#  14767683,
#  14068066,
#  13561414,
#  13076198,
#  12935600,
#  11715487,
#  3495049,
#  3024029,
#  3021050,
#  533458,
#  449690,
#  449672,
#  437079,
#  341625,
#  231183,
#  169358,
#  57053,
#  46082,
#  145827108,
#  145704499,
#  145343686,
#  144952838,
#  144712467,
#  144712465,
#  144422886,
#  144420319,
#  144264435,
#  144164719,
#  143984626,
#  143928144,
#  143920238,
#  143831413,
#  143817148,
#  143745355,
#  143627570,
#  143545939,
#  143284641,
#  142906870,
#  142878322,
#  142839761,
#  142832552,
#  142808892,
#  142657647,
#  142330277,
#  142227112,
#  142187241,
#  142083676,
#  141921051,
#  141909879,
#  141710393,
#  141653220,
#  141557823,
#  141518389,
#  141513232,
#  141475901,
#  141438503,
#  141421006,
#  141408715,
#  141334456,
#  141334454,
#  141324998,
#  141306718,
#  141219477,
#  141147544,
#  141128723,
#  141111618,
#  141018119,
#  140891773,
#  140889054,
#  140791758,
#  140611654,
#  140611653,
#  140611652,
#  140608904,
#  140568452,
#  140534492,
#  140534486,
#  140471399,
#  140448732,
#  140326669,
#  140309563,
#  140301634,
#  140156275,
#  140091824,
#  140031939,
#  139833234,
#  139791198,
#  139790503,
#  139783383,
#  139783382,
#  139760971,
#  139712768,
#  139712767,
#  139611281,
#  139610701,
#  139509280,
#  139267709,
#  137501721,
#  135019738,
#  134564081,
#  134211469,
#  132168405,
#  130122212,
#  129891280,
#  129887588,
#  129801692,
#  129774845,
#  129762915,
#  129718487,
#  129715221,
#  129671161,
#  129655466,
#  129646313,
#  129216226,
#  123530291,
#  123228641,
#  122590168,
#  122583488,
#  122378022,
#  118882126,
#  118399074,
#  118174731,
#  118050406,
#  117951351,
#  101259933,
#  92043528,
#  91257082,
#  90713801,
#  90707867,
#  89678544,
#  89467522,
#  89354013,
#  89240754,
#  89239746,
#  89239745,
#  89078151,
#  89050114,
#  89024702,
#  89001860,
#  88786193,
#  88712059,
#  88711389,
#  88634860,
#  88363626,
#  88314424,
#  88314322,
#  88256137,
#  88236306,
#  88164568,
#  88087316,
#  88084032,
#  87853997,
#  87796396,
#  87755574,
#  87755573,
#  87722408,
#  87696212,
#  87696105,
#  87550070,
#  87550069,
#  87375844,
#  87261656,
#  87252024,
#  87251728,
#  87195970,
#  87171077,
#  86567707,
#  85808914,
#  78184571,
#  74764746,
#  73049788,
#  71379425,
#  71361175,
#  71348402,
#  71337751,
#  71316603,
#  59112422,
#  59092796,
#  56953094,
#  56947341,
#  56625880,
#  55221478,
#  54146806,
#  53431124,
#  50987136,
#  24833432,
#  24195977,
#  24186631,
#  23711245,
#  23617865,
#  22987540,
#  22340839,
#  22116670,
#  22024137,
#  21864254,
#  21617572,
#  20976112,
#  19086655,
#  19009862,
#  18784220,
#  18000428,
#  17914440,
#  17866995,
#  16736294,
#  15646780,
#  14842936,
#  12388299,
#  12234297,
#  12234295,
#  11953667,
#  11521067,
#  10654172,
#  10331483,
#  10130138,
#  6420899,
#  5490260,
#  522265,
#  31675,
#  103176,
#  546871,
#  588330,
#  3795141,
#  6365652,
#  6918501,
#  7568412,
#  7568414,
#  9877448,
#  9877449,
#  9920403,
#  10011870,
#  10388357,
#  10406765,
#  10410808,
#  10884620,
#  10889710,
#  11276335,
#  11535688,
#  11672661,
#  12234286,
#  12600551,
#  12845641,
#  13335704,
#  13335705,
#  13335706,
#  13335707,
#  14693726,
#  16213401,
#  16747911,
#  17799412,
#  18006679,
#  18406425,
#  18503025,
#  18620284,
#  18764596,
#  18913885,
#  18952570,
#  19021209,
#  19024390,
#  19429914,
#  19607191,
#  19747446,
#  20077284,
#  20078828,
#  20083758,
#  20227568,
#  20294357,
#  20294360,
#  20322675,
#  20325397,
#  20371883,
#  20496398,
#  20523476,
#  20562421,
#  20567980,
#  20975785,
#  20976111,
#  21026562,
#  21115702,
#  21119700,
#  21119701,
#  21120357,
#  21120667,
#  21126478,
#  21245438,
#  21321798,
#  21363168,
#  21363169,
#  21422585,
#  21977382,
#  21997723,
#  22179171,
#  22257321,
#  22447444,
#  22590735,
#  22595215,
#  22634755,
#  22642428,
#  22662522,
#  22688893,
#  22711551,
#  22763439,
#  23036016,
#  23048546,
#  23048564,
#  23363476,
#  23378681,
#  23545685,
#  23617866,
#  23620729,
#  23623489,
#  23629126,
#  23652544,
#  25199851,
#  25217430,
#  25217432,
#  25217434,
#  25217545,
#  25217549,
#  28064844,
#  28064846,
#  44179529,
#  44521768,
#  44614719,
#  49791626,
#  50908614,
#  50908615,
#  50915166,
#  50915167,
#  50931303,
#  50931392,
#  50932298,
#  50932380,
#  50932455,
#  51035564,
#  51035565,
#  51035566,
#  51035567,
#  51037634,
#  51037635,
#  51037636,
#  51037637,
#  51037638,
#  51038291,
#  51038292,
#  51038293,
#  51038294,
#  52921248,
#  53434843,
#  53434844,
#  53642932,
#  54694413,
#  56953093,
#  57171685,
#  57348093,
#  57408300,
#  57443989,
#  57454172,
#  57464204,
#  57494422,
#  57494438,
#  57511413,
#  59626620,
#  59910041,
#  59910045,
#  60153252,
#  60153253,
#  60155597,
#  60155598,
#  60155857,
#  60155858,
#  60162688,
#  60162689,
#  61287134,
#  61287345,
#  62020806,
#  62021588,
#  62310400,
#  63701482,
#  67723810,
#  71309026,
#  71309124,
#  71309645,
#  71309716,
#  71309755,
#  71309865,
#  71309887,
#  71310336,
#  71316604,
#  71316605,
#  71435019,
#  71438984,
#  71774904,
#  72458423,
#  73053758,
#  73334520,
#  75202633,
#  76973406,
#  80695635,
#  86000886,
#  86220062,
#  86583183,
#  86643782,
#  86758999,
#  87076599,
#  87079413,
#  87079414,
#  87080820,
#  87082394,
#  87084438,
#  87092735,
#  87092736,
#  87093754,
#  87093884,
#  87120384,
#  87120385,
#  87141481,
#  87156266,
#  87169986,
#  87187013,
#  87233591,
#  87248056,
#  87252020,
#  87282407,
#  87282442,
#  87307990,
#  87308142,
#  87309705,
#  87318838,
#  87320595,
#  87323940,
#  87327399,
#  87329039,
#  87329041,
#  87421572,
#  87467389,
#  87478495,
#  87501947,
#  87536434,
#  87574079,
#  87574081,
#  87574210,
#  87574336,
#  87574386,
#  87574400,
#  87574697,
#  87574738,
#  87574749,
#  87574913,
#  87575099,
#  87632946,
#  87682064,
#  87859014,
#  87859015,
#  87861724,
#  87872683,
#  87872684,
#  87906533,
#  87914410,
#  87961774,
#  88003098,
#  88011232,
#  88056016,
#  88056017,
#  88084415,
#  88091044,
#  88092209,
#  88092210,
#  88092211,
#  88092212,
#  88115660,
#  88119601,
#  88177378,
#  88243170,
#  88243171,
#  88258321,
#  88258322,
#  88295520,
#  88327258,
#  88337268,
#  88407704,
#  88409046,
#  88409047,
#  88419836,
#  88449373,
#  88454926,
#  88471756,
#  88510277,
#  88540465,
#  88602728,
#  88607318,
#  88607319,
#  88607430,
#  88607431,
#  88662936,
#  88662937,
#  88705093,
#  88719753,
#  88755741,
#  88757196,
#  88757579,
#  88794128,
#  88810941,
#  88810943,
#  ...]

# %%
len(request_json['IdentifierList']['CID'])
# Out:
# 1072

# %% [markdown]
# 1072 different compounds were returned, let's find out the names of those compounds.

# %%
similarity_list = request_json['IdentifierList']['CID']

# %%
name_list = [] #empty list to append compound names too

for cid in similarity_list:
    #general pubchempy request to obtain a json of the entire compound data
    names_request = "https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/%s/JSON" % str(cid) 
    request = requests.get(names_request)
    request_json = request.json()
    
    names = request_json['Record']['RecordTitle'] #the compound name is contained at the very top of the json, fairly easy.
    
    name_list.append(names)

# %%
name_list
# Out:
# ['Choline chloride',
#  'Triethanolamine',
#  'Deanol',
#  '2-Diethylaminoethanol',
#  'Choline',
#  'N-Methyldiethanolamine',
#  'Dimepranol',
#  '1-Aziridineethanol',
#  'N-Ethyldiethanolamine',
#  'Choline hydroxide',
#  'Choline Bromide',
#  '(2-Hydroxyethyl)triethylammonium iodide',
#  '2-((2-(Dimethylamino)ethyl)(methyl)amino)ethanol',
#  'Choline chloride C-11',
#  'Choline C-11',
#  'Triethylcholine chloride',
#  'Bis(2-hydroxyethyl)dimethylammonium chloride',
#  'Tris(2-hydroxyethyl)methylammonium hydroxide',
#  'Triethanolamine hydrochloride',
#  'Choline iodide',
#  '2-(Dimethylamino)propan-1-ol',
#  '2-(Diethylamino)ethanol hydrochloride',
#  '2-(Dipropylamino)ethanol',
#  'Copper triethanolamine complex',
#  '1-Ethyl-1-(2-hydroxyethyl)aziridinium chloride',
#  "Ethanol, 2,2'-(propylimino)bis-",
#  '2-Methylcholine',
#  'Choline bicarbonate',
#  'Copper triethanolamine',
#  'Ethanaminium, N,N,N-triethyl-2-hydroxy-, bromide',
#  '2-Hydroxyethyl-(iodomethyl)-dimethylazanium;iodide',
#  'Fluoroethylcholine ion F-18',
#  'Fluorocholine F-18',
#  'Ethanaminium, N-(fluoromethyl)-2-hydroxy-N,N-dimethyl-',
#  'Fluorocholine',
#  '2-[Methyl(prop-2-yn-1-yl)amino]ethan-1-ol',
#  'Ethanol, 2-dimethylamino-, hydrochloride',
#  'Ethylcholine aziridinium',
#  'Ethanol, 2-(ethylmethylamino)-',
#  '1-Propanaminium, 2-hydroxy-N,N,N-trimethyl-, chloride',
#  '2-(Dimethylamino)ethanol hydrochloride',
#  '(S)-(+)-1-Dimethylamino-2-propanol',
#  'Betaine aldehyde hydrate',
#  'K-Pool',
#  '2-Hydroxyethyl(dimethyl)azanium',
#  'Triethanolamine hydriodide',
#  'Ethanol, 2-[bis(hydroxymethyl)amino]-',
#  '2-((2-Chloroethyl)ethylamino)ethanol',
#  "Ethanol, 2,2',2''-nitrilotris-, homopolymer, reaction products with chloromethane",
#  '2-Propanaminium, 1-hydroxy-N,N,N-trimethyl-',
#  'Tetrakis(2-hydroxyethyl)ammonium chloride',
#  'Triethylcholine',
#  'Dimethylethylcholine iodide',
#  'Monoethylcholine',
#  'Ethanaminium, 2-hydroxy-N,N-bis(2-hydroxyethyl)-N-methyl-, chloride',
#  'Choline chloride-15N',
#  '2-Methoxyethyl(trimethyl)azanium;chloride',
#  'N,N-Diethyl-2-hydroxy-N-methylethan-1-aminium bromide',
#  'Choline-1,1,2,2-d4 bromide',
#  'Methyl-d9-choline',
#  'Methyl-D9-choline chloride',
#  'Propargylcholine',
#  'N-Ethyl-2-hydroxy-N,N-dimethylethan-1-aminium bromide',
#  'Triethylcholine hydroxide',
#  'Bromomethyl-(2-hydroxyethyl)-dimethylazanium;bromide',
#  'Chloromethyl-(2-hydroxyethyl)-dimethylazanium;iodide',
#  'N-(2-Hydroxyethyl)-N,N-dimethylpropan-1-aminium bromide',
#  "Ethanol, 2,2'-(chloroimino)bis-",
#  "2,2',2''-Nitrilotrisethanol hydrobromide",
#  '2-(Dibutylamino)ethanol hydrochloride',
#  'Ethanaminium, 2-hydroxy-N-(2-hydroxyethyl)-N,N-dimethyl-, hydroxide',
#  '4-(Dimethylamino)but-2-yn-1-ol',
#  '2-(2-Hydroxyethyl-(hydroxymethyl)amino)ethanol',
#  '2-[Methoxy(methyl)amino]ethanol',
#  '2-[Ethyl(prop-2-yn-1-yl)amino]ethanol',
#  '2-(Isopropyl(methyl)amino)ethanol',
#  '2-(N-Methyl-N-butylamino)ethanol',
#  'Diethyl(2-hydroxyethyl)methylammonium iodide',
#  'Ethanaminium, 2-hydroxy-N,N,N-trimethyl-, inner salt',
#  'Dimethyldiethanolammonium',
#  '2-Chloropropyl(diethyl)amine hydrochloride',
#  'Choline methyl ether',
#  'Propanol, (dimethylamino)-',
#  'N-Methyl-2-chloroethyl-2-hydroxyethylamine',
#  'Ethyl(2-hydroxyethyl)dimethylammonium chloride',
#  '(2-Hydroxyethyl)methyldiethylammonium',
#  '(2-Hydroxyethyl)tripropylammonium chloride',
#  'Ammonium, ethylbis(2-hydroxyethyl)methyl-, chloride',
#  'Ethanaminium, 2-hydroxy-N,N-bis(2-hydroxyethyl)-N-methyl-',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;dihydrate',
#  'Ethyl-(hydroxymethyl)-dimethylazanium;chloride',
#  'Cholinperchlorat',
#  '2-(Diethylamino)ethyl hypochlorite',
#  'Triethanolamine water',
#  '2-Hydroxyethyl-dimethyl-[(oxo-lambda5-phosphanylidyne)methyl]azanium;chloride',
#  'Cholinchloridhydrate',
#  '2-Hydroxy-N,N-bis(2-hydroxyethyl)-N-methylethan-1-aminium bromide',
#  '(1,1,2,2-Tetradeuterio-2-hydroxyethyl)-tris(trideuteriomethyl)azanium;bromide',
#  '2-Hydroxy(213C)ethyl(trimethyl)azanium;chloride',
#  'Choline bromide-trimethyl-d9',
#  'Bis(2-hydroxyethyl)-dimethylazanium;bromide',
#  '2-(2-Hydroxyethylperoxy)ethyl-trimethylazanium',
#  'Fluoroethylcholine chloride',
#  '2-[2-Fluoroethyl(methyl)amino]ethanol',
#  '2-[Ethyl(methyl)amino]-1-propanol',
#  'Sodium;2-(dimethylamino)ethanolate',
#  'Lithium;2-(dimethylamino)ethanolate',
#  '1-Propanol, 2-(dimethylamino)-, hydrochloride',
#  'N,N-Diethyl-2-hydroxy-N-(2-hydroxyethyl)ethan-1-aminium chloride',
#  'N,N-Diethylethanamine;ethanol',
#  '2-Chlorooxyethyl(trimethyl)azanium;chloride',
#  '2-[Ethyl(propyl)amino]ethanol',
#  'Bis(1-hydroxyethyl)dimethylaminium',
#  'Choline fluoride',
#  '1-Hydroxypropyl(trimethyl)azanium;chloride',
#  'Dibutyl(2-hydroxyethyl)methylammonium chloride',
#  'Diethyl(2-hydroxyethyl)methylammonium chloride',
#  '1-(Diethylamino)ethanol;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;cyanide',
#  'Cholinrhodanid',
#  '2-(Diisopropylamino)ethanol hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;dichloride',
#  '2-Bromooxyethyl(trimethyl)azanium',
#  'Ethanol, 2-(butylmethylamino)-, hydrochloride',
#  'Tris(1-hydroxyethyl)-methylazanium',
#  '2-Chlorooxyethyl(trimethyl)azanium',
#  '2-Hydroperoxyethyl(trimethyl)azanium',
#  '1-[Ethyl(1-hydroxyethyl)amino]ethanol',
#  '1-[1-Hydroxyethyl(methyl)amino]ethanol',
#  'Cholinchlorat',
#  '1-(Diethylamino)ethanol',
#  'N-(2-Hydroxyethyl)-N,N-dimethylpropan-2-aminium',
#  '2-Hydroxy-N-(2-hydroxyethyl)-N,N-dimethylethan-1-aminium iodide',
#  '2-Hydroxyethylpropyldimethylammonium',
#  'Ethanaminium, 2-hydroxy-N,N,N-trimethyl-, sulfite (1:1)',
#  '2-[2-Hydroxyethyl(2-methoxyethyl)amino]ethanol',
#  '2-Chloro-2-hydroxy-N,N,N-trimethylethan-1-aminium',
#  '(2R)-2-(Dimethylamino)propan-1-ol',
#  '(S)-2-(Dimethylamino)-1-propanol',
#  '1-Propanaminium, 2-hydroxy-N,N,N-trimethyl-, (R)-',
#  'Fluoroethylcholine ion',
#  'Ammonium, (2-hydroxypropyl)trimethyl-, (+)-',
#  'DI-Methylaminoethanol',
#  '(2R)-1-(Dimethylamino)propan-2-ol',
#  "2,2'-(Methylimino)bisethanol hydrochloride",
#  '2-Fluorooxyethyl(trimethyl)ammonium',
#  'Choline borate',
#  '1-[Ethyl(methyl)amino]propan-2-ol',
#  '2-(Dipropylamino)ethanol hydrochloride',
#  '2-(Bromo-methyl-amino)ethanol',
#  '2-(Dimethylamino)ethane-1,1-diol',
#  '2-(Dimethylamino)ethanol N-oxide',
#  'Cyclocholine',
#  'N,N-Bis(2-hydroxyethyl)aziridinium chloride',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol',
#  'Unii-7dkh3nej7F',
#  'Ethyl-(2-hydroxyethyl)-dipropylazanium',
#  '2-Hydroxyethyl-dimethyl-propan-2-ylazanium;chloride',
#  'Alumane;2-(dimethylamino)ethanol',
#  '1-[Ethyl(2-hydroxyethyl)amino]ethanol',
#  'Hydride;2-hydroxyethyl(trimethyl)azanium',
#  '1-(Dimethylamino)ethanol;hydrochloride',
#  '1-(Dimethylamino)ethanol;hydrate',
#  '2-Hydroxyethyl(trimethyl)azanium;trichloride',
#  'Phosphoryldimethylethanolamine',
#  '(2-Hydroxyethyl)-triethylammonium iodide',
#  'Bis(2-hydroxyethyl)-(hydroxymethyl)-methylazanium',
#  '(18F)Fluoranylmethyl-(2-hydroxyethyl)-methanidyl-methylazanium',
#  'CID 123549545',
#  '2-Hydroxyethyl-(2-methoxyethyl)-dimethylazanium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;hypochlorous acid',
#  '2-(Dimethylamino)ethanol;2-[ethyl(methyl)amino]ethanol',
#  '(1-Chloro-2-hydroxyethyl)-trimethylazanium',
#  'Acetonitrile;2-(dimethylamino)ethanol',
#  'Diethyl-(1-hydroxyethyl)-methylazanium',
#  'Ethyl-bis(1-hydroxyethyl)-methylazanium',
#  'Azane;2-[ethyl(2-hydroxyethyl)amino]ethanol',
#  '1-[2-Methoxyethyl(methyl)amino]ethanol',
#  '2-[2-Hydroxyethyl(methyl)amino]propan-2-ol',
#  'Ethyl-(2-hydroxyethyl)-dimethylazanium;methanol',
#  '2-(Dimethylamino)ethanol;ethane',
#  'Formaldehyde;2-[2-hydroxyethyl(methyl)amino]ethanol',
#  'Ethanol;triethyl(methyl)azanium',
#  'Ethanol;N-ethyl-N-methylethanamine',
#  'Ethyl-tris(2-hydroxyethyl)azanium;bromide',
#  'Bis(1-hydroxyethyl)-(2-hydroxyethyl)-methylazanium',
#  '2-Hydroxyethyl(trimethyl)azanium;hydroxy hypochlorite',
#  '2-(Dimethylamino)ethanol;ethoxyethane',
#  'Triethyl(1-hydroxyethyl)azanium;chloride',
#  'Ethyl-tris(hydroxymethyl)azanium;chloride',
#  'Diethyl-bis(1-hydroxyethyl)azanium;chloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;gold',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;gold',
#  'Sodium;2-(diethylamino)ethanol',
#  '(2R)-2-(Dimethylamino)propan-1-ol;hydrochloride',
#  '(2S)-2-(Dimethylamino)propan-1-ol;hydrochloride',
#  'Azanium;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Azane;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Calcium;[1-hydroxy-2-(trimethylazaniumyl)ethyl]phosphanide;chloride',
#  'Tris(2-hydroxyethyl)-sulfidoazanium',
#  '2-Hydroxyethyl(trimethyl)azanium;thiocyanic acid',
#  'Ethane-1,2-diol;2-hydroxyethyl(trimethyl)azanium',
#  'N,N-Diethylethanamine;2-[2-hydroxyethyl(methyl)amino]ethanol',
#  '1-[Methyl(trichloromethyl)amino]ethanol',
#  'N,N-Dimethylethanamine;ethanol;propane',
#  'Chloranium;2-hydroxyethyl(trimethyl)azanium',
#  '2-(Dimethylamino)ethanol;2-[2-hydroxyethyl(methyl)amino]ethanol',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;lithium',
#  '1-(Diethylamino)ethanol;lithium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;methanol',
#  'Tris(2-hydroxyethyl)-propylazanium;chloride',
#  '1-[Chloromethyl(1-hydroxyethyl)amino]ethanol',
#  '1-[1-Hydroxyethyl(methyl)amino]ethanol;hydrochloride',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium',
#  'Ethyl hypochlorite;2-[2-hydroxyethyl(methyl)amino]ethanol',
#  'Ethyl hypochlorite;1-[1-hydroxyethyl(methyl)amino]ethanol',
#  '2-[Bis(hydroxymethyl)amino]propan-1-ol;hydrochloride',
#  'CID 88431111',
#  'Chloromethyl-(1-hydroxyethyl)-dimethylazanium;chloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;methane',
#  '2-[Butyl(methyl)amino]ethanol;dihydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;dicarbonate',
#  '(2-Chloro-2-hydroxyethyl)-trimethylazanium;hydrochloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;potassium;sodium',
#  'Copper;2-hydroxyethyl(trimethyl)azanium',
#  '2-(Diethylamino)ethanol;lithium',
#  'Diethyl-(2-hydroxyethyl)-propylazanium;chloride',
#  'Sodium;1-[bis(1-hydroxyethyl)amino]ethanol;chloride',
#  '[1-Hydroxy-2-(trimethylazaniumyl)ethyl]-methylphosphanide',
#  'Ethanol;2-hydroxyethyl(trimethyl)azanium;hydroxide',
#  '2-Hydroxyethyl(trimethyl)azanium;molecular chlorine',
#  '2-(Dimethylamino)ethanol;N,N-dimethylmethanamine',
#  '2-(Dimethylamino)-1-[ethyl(methyl)amino]ethanol',
#  'Chloromethyl-(1-hydroxypropan-2-yl)-dimethylazanium',
#  '2-Hydroxyethyl(trimethyl)azanium;phosphoryl trichloride',
#  '2-Hydroxyethyl-tri(propan-2-yl)azanium;chloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;calcium',
#  'CID 88084031',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;silver',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;silver',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;N,N-dimethylmethanamine',
#  '2-[Bis(methoxymethyl)amino]ethanol',
#  '1-[1-Hydroxyethyl(methoxymethyl)amino]ethanol',
#  '2-[Methoxymethyl(methyl)amino]ethanol',
#  'Azanium;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Azane;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;methanamine',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;calcium;perchloric acid',
#  'Azane;2-(diethylamino)ethanol',
#  'Formaldehyde;2-hydroxyethyl(trimethyl)azanium',
#  '2-Chloryloxyethyl(trimethyl)azanium',
#  'Trimethyl(2-perchloryloxyethyl)azanium',
#  '2-Hydroxyethyl-(2-iodoethyl)-dimethylazanium',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;calcium;hydrochloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;calcium;hydrochloride',
#  'Ethyl-bis(2-hydroxyethyl)-methylazanium;hydroxide',
#  '2-(Diethylamino)ethanol;hydrogen',
#  '2-(Diethylamino)ethanol;hydron',
#  'Ethyl-(1-hydroxyethyl)-dimethylazanium',
#  '(2R)-1-(Dimethylamino)propan-2-ol;hydrochloride',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium;phosphoryl trichloride',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;potassium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;potassium',
#  '2,2-Dichloro-2-(diethylamino)ethanol',
#  '2-(Dimethylamino)ethanol;ethanol',
#  '1-(Diethylamino)ethane-1,2-diol;hydrochloride',
#  '2-(Diethylamino)ethane-1,1-diol;hydrochloride',
#  'Carbane;2-hydroxyethyl(trimethyl)azanium',
#  '1-Hydroxyethyl(trimethyl)azanium;perchloric acid',
#  '2-Hydroxyethyl(trimethyl)azanium;perchloric acid',
#  '1-[Ethyl(1-hydroxyethyl)amino]ethanol;hydrochloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;magnesium',
#  '2-(Hydroxymethylperoxy)ethyl-trimethylazanium',
#  '2-Hydroxyethyl(trimethyl)azanium;methanol;hydroxide',
#  '1-(Dimethylamino)-2-[ethyl(methyl)amino]ethanol',
#  '2-[Cyano(methyl)amino]ethan-1-OL',
#  '2-Hydroxy(113C)ethyl(trimethyl)azanium',
#  '2-Hydroxy(113C)ethyl(trimethyl)azanium;chloride',
#  '2-[2-Hydroxyethyl(methyl)amino]ethanol;hydrate',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;sodium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;sodium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;perchloric acid',
#  'Tris(1-hydroxyethyl)-methylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;hydroxymethanone',
#  '(3-Fluoro-2-hydroxypropyl)-trimethylazanium;chloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;ethanol',
#  '2-Hydroxyethyl(trimethyl)azanium;azide',
#  'Ethyl-[1-hydroxy-2-(trimethylazaniumyl)ethyl]phosphanide',
#  '2-Hydroxyethyl(trimethyl)azanium;hydroxide',
#  '2-Hydroxyethyl(trimethyl)azanium;dihydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;trimethyl(2-oxidooxyethyl)azanium',
#  '2-(Dimethylamino)-2-methoxyethanol',
#  'N-Cyano-2-[2-hydroxyethyl(methyl)amino]acetonitrilium',
#  '2-[2-(Dimethylamino)ethyl-methylamino]ethanol;dihydrochloride',
#  '(2S)-2-(Diethylamino)propan-1-ol;hydrochloride',
#  'Sodium;2-(dimethylamino)ethanol;hydride',
#  '2-Hydroxyethyl(trimethyl)azanium;hydroxylamine',
#  'Chromium(3+);2-hydroxyethyl(trimethyl)azanium;tetrachloride;hexahydrate',
#  'N,N-Dimethylmethanamine;ethanol',
#  'Butyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;dihydrate',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;hydrofluoride',
#  'Chloromethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  'Triethyl(2-hydroxyethyl)azanium;fluoride',
#  'Calcium;2-hydroxyethyl-dimethyl-[(oxo-lambda5-phosphanylidyne)methyl]azanium;chloride',
#  '2-[Ethyl(2-hydroxyethyl)amino]ethanol;hydrochloride',
#  '2-(Dimethylamino)ethan(17O)ol',
#  'Dimethyl-bis(2-oxonioethyl)azanium',
#  '2-Hydroxyethyl-dimethyl-(2-oxonioethyl)azanium',
#  '2-[Ethyl(methyl)amino]ethane-1,1-diol',
#  '2-[Ethynyl(2-hydroxyethyl)amino]ethanol',
#  'Actinium;2-[ethyl(2-hydroxyethyl)amino]ethanol',
#  'Actinium;2-[bis(2-hydroxyethyl)amino]ethanol',
#  'Actinium;2-[2-hydroxyethyl(methyl)amino]ethanol',
#  'Actinium;2-(dipropylamino)ethanol',
#  'Actinium;2-[2-hydroxyethyl(propyl)amino]ethanol',
#  '2-[Methyl(methyl)amino]ethane-1,1-diol',
#  '1,2-Dihydroxyethyl-diethyl-methylazanium',
#  'CID 59736176',
#  '2-[2-Hydroxyethyl(2-hydroxyethyl)amino]ethanol',
#  '2-[Di((113C)methyl)(15N)amino]ethanol',
#  '2-Hydroxyethyl-di((113C)methyl)(15N)azanium',
#  '1-(Dimethylamino)propan-2-ol;hafnium',
#  'CID 59270461',
#  '2-Hydroxypropyl(trimethyl)azanium',
#  '(2S)-1-[Ethyl(methyl)amino]propan-2-ol',
#  '(2R)-1-[Ethyl(methyl)amino]propan-2-ol',
#  '2-Hydroxyethyl(methyl)azanide;yttrium',
#  'Ethyl-(2-hydroxyethyl)-methyl-propylazanium',
#  '2-[Ethynyl(methyl)amino]ethanol',
#  '2-[Isocyanomethyl(methyl)amino]ethanol',
#  '1-(Dimethylamino)propan-2-ol;yttrium',
#  'N-Ethyl-2-hydroxy-N-(2-hydroxyethyl)ethanamine oxide',
#  '2-(Dimethylamino)ethanol;ethanol;niobium',
#  '2-(Dimethylamino)ethanol;titanium',
#  '2-(Dimethylamino)ethanol;ethanol;tantalum',
#  'Copper cento dimethylaminoethoxide',
#  '1-(Dimethylamino)propan-2-ol;titanium',
#  '1-(Dimethylamino)propan-2-ol;zirconium',
#  'Trimethyl(2-oxoniopropyl)azanium',
#  '2-[Methyl(methyl)amino]ethanol',
#  '2-Hydroxypropyl(trimethyl)azanium',
#  'N,N-Dimethyl-2-(trioxidanyl)ethanamine',
#  '2-Hydroxyethyl-methyl-methyl-propylazanium',
#  'Bis(2-hydroxyethyl)azanide;yttrium',
#  '2-Hydroxyethyl-dimethyl-tritioazanium',
#  '2-[Butyl(methyl)amino]ethanol',
#  '1-[1,2-Dihydroxyethyl(methyl)amino]ethane-1,2-diol',
#  '[Dihydroxymethyl(2-hydroxyethyl)amino]methanediol',
#  'Deuteriomethyl-(2-hydroxyethyl)-dimethylazanium',
#  '2-[Deuteriomethyl(dimethyl)azaniumyl]ethanolate',
#  '1,1,2,2-Tetradeuterio-2-[(1,1,2,2-tetradeuterio-2-hydroxyethyl)-(trideuteriomethyl)amino]ethanol',
#  '2-[Ethyl(fluoromethyl)amino]ethanol',
#  'Ethanol, 2-[ethyl(2-fluoroethyl)amino]-',
#  '2-[3-Fluoropropyl(methyl)amino]ethanol',
#  '2-[Fluoromethyl(methyl)amino]ethanol',
#  '2-[Ethyl(methyl)amino]ethanol;iron',
#  '2-(Dimethylamino)ethanol;iron',
#  '1-(Dimethylamino)propan-2-ol;iron',
#  '2-(Diethylamino)ethanol;iron',
#  '2-[Ethyl(ethyl)amino]ethanol',
#  'CID 57585182',
#  '2-(Dimethylamino)ethanol;hafnium',
#  'CID 57541007',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;copper',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;magnesium',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;hydrochloride',
#  '1-[1-Hydroxyethyl(oxiran-2-yl)amino]ethanol',
#  '1-[1-Hydroxyethyl(2-methoxyethyl)amino]ethanol',
#  '1-Chloro-2-(diethylamino)ethanol',
#  '(2-Hydroperoxy-2-hydroxyethyl)-trimethylazanium',
#  '2-Iodooxyethyl(trimethyl)azanium',
#  'Trimethyl-[2-(trioxidanyl)ethyl]azanium',
#  '1-(Diethylamino)ethane-1,2-diol',
#  '1-[Chloro(1-hydroxyethyl)amino]ethanol',
#  '2,2-Bis(dimethylamino)ethanol',
#  '[1-Hydroxy-2-(trimethylazaniumyl)ethyl]-trimethylazanium',
#  '2-(Trimethylazaniumyl)ethyl hypofluorite chloride',
#  '2-[Methyl(2,2,2-trifluoroethyl)amino]ethan-1-ol',
#  '1-[1-Hydroxyethyl(hydroxymethyl)amino]ethanol',
#  '2-[But-2-ynyl(ethyl)amino]ethanol',
#  '1-[Methyl(propyl)amino]ethanol',
#  '[2-(Dimethylamino)-1-hydroxyethyl]boron',
#  'Chloromethyl-(1-hydroxyethyl)-dimethylazanium',
#  'Fluoro-tris(2-hydroxyethyl)azanium',
#  '1-Chloro-2-(dimethylamino)ethanol',
#  'Ethanol;2-hydroxyethyl(trimethyl)azanium',
#  'N-(2-Hydroxyethyl)-N-methylmethanethioamide',
#  'Trimethyl(2-tritiooxyethyl)azanium',
#  '2-Hydroxyethyl-(hydroxymethyl)-dimethylazanium',
#  '2-Hydroxyethyl-tris(hydroxymethyl)azanium',
#  '1-(1-Hydroxyethyl)aziridin-2-ol',
#  '1,2-Dihydroxyethyl(trimethyl)azanium',
#  '2-[2-Hydroxyethyl(methyl)amino]ethanol;methoxyethane',
#  '1-Methylaziridin-2-ol',
#  '(18F)Fluoranylmethyl-dimethyl-(1,1,2,2-tetradeuterio-2-hydroxyethyl)azanium',
#  '2-[2-Aminooxyethyl(methyl)amino]ethanol',
#  "2,2',2''-Nitrilotrisethanol, sodium salt",
#  '2-Propanol,1-(dimethylamino)-, hydrochloride (1:1)',
#  '2-[3-(18F)Fluoranylpropyl(methyl)amino]ethanol',
#  '2-[Ethyl(2-(18F)fluoranylethyl)amino]ethanol',
#  '2-[2-(18F)Fluoranylethyl(methyl)amino]ethanol',
#  '2-[Ethyl((18F)fluoranylmethyl)amino]ethanol',
#  '2-[(18F)Fluoranylmethyl(methyl)amino]ethanol',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium',
#  'Sodium;2-[bis(2-hydroxyethyl)amino]ethanol;chloride',
#  'N-Methyl-N-2-hydroxyethyl-2-aminoethanol-N-oxide',
#  '2-Hydroxyethyl-methanidyl-methylazanium',
#  '1-Hydroxyethyl-methyl-methylideneazanium',
#  '2-[Ethyl(methyl)amino]ethanol;yttrium',
#  'N,N-Dimethylethanamine;methanol',
#  '2-Hydroperoxy-N,N-dimethylethanamine',
#  '2-Hydroxyethyl(dimethyl)azanium;chloride',
#  'Diethyl-bis(2-hydroxyethyl)azanium;hydroxide',
#  'Diethyl-(2-hydroxyethyl)-methylazanium;hydroxide',
#  '2-[Cyanomethyl(2-hydroxyethyl)amino]acetonitrile',
#  '2-[2-Hydroxyethyl(1-methoxyethyl)amino]ethanol',
#  '1-[2-Hydroxyethyl(propyl)amino]ethanol',
#  '1-[Hydroxymethyl(methyl)amino]propan-2-ol',
#  '1-[2-Hydroxyethyl(methyl)amino]ethanol',
#  '1-[1-Hydroxyethyl(2-hydroxyethyl)amino]ethanol',
#  '2-[Hydroxymethyl(propyl)amino]ethanol',
#  '2-[Bis(2-hydroxyethyl)amino]ethane-1,1,1-triol',
#  '2-Chlorooxyethyl(trimethyl)azanium;bromide',
#  '1-Hydroxyethyl(trimethyl)azanium;hydroxide',
#  'Azanium;2-[bis(2-hydroxyethyl)amino]ethanol;chloride',
#  'Bis(1-hydroxyethyl)-dimethylazanium;chloride',
#  'N,N-Dimethylethanamine;ethanol',
#  '2-(Ethyl-isopropyl-amino)-ethanol',
#  'Cyanomethyl-(2-hydroxyethyl)-dimethylazanium',
#  'Cyanomethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;carbonate',
#  '2-Hydroxyethyl(trimethyl)azanium;oxygen(2-)',
#  'Bis(1-hydroxyethyl)-dimethylazanium;hydroxide',
#  'Tris(2-hydroxyethyl)-(hydroxymethyl)azanium',
#  '2-[2-Hydroxyethyl(methoxymethyl)amino]ethanol',
#  '1-[Bis(methoxymethyl)amino]ethanol',
#  '2-Hydroxyethyl(trimethyl)azanium;carbonochloridate',
#  '2-Hydroxyethyl(trimethyl)azanium;methanol',
#  '2-((2-Methoxyethyl)(methyl)amino)ethanol',
#  '2-(N-(Hydroxymethyl)-N-methylamino)ethanol',
#  'O-[2-(Dimethylamino)ethyl]hydroxylamine;hydrochloride',
#  '1-Hydroxyethyl(trimethyl)azanium;chloride',
#  'CID 21884707',
#  'Chloromethyl-tris(2-hydroxyethyl)azanium',
#  '2-Hydroxyethyl-dimethyl-propylazanium;chloride',
#  'N,N-Diethylethanamine;2-(dimethylamino)ethanol',
#  'Bis(2-hydroxyethyl)azanide',
#  'Bis(2-hydroxyethyl)-dimethylazanium;fluoride',
#  'Tris(2-hydroxyethyl)-methylazanium;fluoride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;butane',
#  '2-Hydroxyethyl(trimethyl)azanium;methanolate',
#  'Trimethyl(2-oxonioethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;dichloride',
#  'Ethoxyethane;2-hydroxyethyl(trimethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;methane',
#  '[Ethyl(methyl)amino]methanol',
#  '2-[Ethyl(methyl)amino]ethane-1,1-diol',
#  '2-[Ethyl(2-methoxyethyl)amino]ethanol',
#  'Carbanide;1-[methanidyl(methyl)amino]propan-2-ol;tungsten(2+)',
#  '1-[Bis(hydroxymethyl)amino]ethanol',
#  '2-[Chloromethyl(2-hydroxyethyl)amino]ethanol',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;N,N-diethylethanamine',
#  '2-Hydroxyethyl(trimethyl)azanium;hydrate',
#  '2-[Dimethylamino(methyl)amino]ethanol',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;hydrochloride',
#  '1-Hydroxypropyl(trimethyl)azanium;hydrochloride',
#  '2-Chlorooxyethyl(trimethyl)azanium;hydrochloride',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium',
#  '2-[Bis(hydroxymethyl)amino]ethanol;hydrochloride',
#  '2-(Diethylamino)ethanol;2-(dimethylamino)ethanol',
#  'Ethane-1,2-diol;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '1-[Bis(2-hydroxyethyl)amino]ethanol',
#  '1-[1-Methoxyethyl(methyl)amino]ethanol',
#  '(2-Chloro-2-hydroxyethyl)-trimethylazanium;bromide',
#  '2-(Diethylamino)ethane-1,1-diol',
#  'Ethyl-(hydroxymethyl)-dimethylazanium',
#  '[(2S)-2-Hydroxypropyl]-trimethylazanium;chloride',
#  '[(2R)-2-Hydroxypropyl]-trimethylazanium;chloride',
#  'CID 18620316',
#  'Triethyl(1-hydroxyethyl)azanium',
#  'CID 18475202',
#  '2-Hydroxyethyl(trimethyl)azanium;tetramethylazanium;hydroxide',
#  '1-Hydroxyethyl(trimethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;tetrafluoroborate',
#  'Trimethyl-(1,1,2,2-tetradeuterio-2-hydroxyethyl)azanium',
#  '2-Hydroxyethyl-dimethyl-(113C)methylazanium',
#  'Aziridinium, 1-(2-hydroxyethyl)-1-methyl-, chloride',
#  '1-[Ethyl(methyl)amino]ethanol',
#  'Ethyl-(2-hydroxyethyl)-dimethylazanium;hydroxide',
#  '2-(Diethylamino)propan-1-ol;hydrochloride',
#  'Chloromethyl-(2-hydroxypropyl)-dimethylazanium',
#  '2-Hydroxyethyl-(iodomethyl)-dimethylazanium',
#  'Bromomethyl-(2-hydroxyethyl)-dimethylazanium',
#  'Chloromethyl-(2-hydroxyethyl)-dimethylazanium',
#  'Ethyl-tris(2-hydroxyethyl)azanium;hydroxide',
#  'Ethyl-tris(2-hydroxyethyl)azanium;chloride',
#  '2-Hydroxy-N,N-bis(2-hydroxyethyl)-N-methylethan-1-aminium iodide',
#  '1,2-Bis(dimethylamino)ethanol',
#  '(2-Chloro-2-hydroxyethyl)-trimethylazanium;chloride',
#  '2-(Dimethylamino)ethanolate',
#  'Fluoroethylcholine bromide',
#  '2-(Dimethylamino)ethyloxidanium',
#  'Diethyl-bis(2-hydroxyethyl)azanium',
#  '(2-Hydroxyethyl)(1-hydroxy-1-methylethyl)dimethylammonium chloride',
#  '2-(Diethylnitroryl)ethanol',
#  'Ethyl-((18F)fluoranylmethyl)-(2-hydroxyethyl)-methylazanium',
#  'Fluorocholine F-18 bromide',
#  '2-Bromoethyl-(2-hydroxyethyl)-dimethylazanium',
#  'Chloromethane;2-(dimethylamino)ethanol',
#  '2-[Methyl(propyl)amino]ethanol',
#  'Ethyl-tris(2-hydroxyethyl)azanium',
#  '(2-Hydroxyethyl)tripropylaminium',
#  'Ethyl-bis(2-hydroxyethyl)-methylazanium',
#  'Bis(2-hydroxyethyl)-dimethylazanium;trichloroiron;chloride',
#  '2-(Diethylamino)ethanol;ethane',
#  '2-(Diethylamino)ethanol;ethane',
#  '2-(Dimethylamino)ethanol;ethane',
#  'Potassium;ethyl(2-hydroxyethyl)azanide',
#  'Potassium;bis(2-hydroxyethyl)azanide',
#  '2-[2-Hydroperoxyethyl(methyl)amino]ethanol',
#  'Ethane;2-[ethyl(sulfanyl)amino]ethanol',
#  '2-[2-Hydroxyethyl(hydroxymethyl)amino]propan-2-ol',
#  'Methanol;2-methoxy-N,N-dimethylethanamine',
#  '2-[Ethyl(methyl)amino]ethyl hypochlorite',
#  '2-(Dimethylamino)ethanol;propane',
#  'Chloromethane;2-hydroxyethyl(trimethyl)azanium',
#  'Ethane;2-[2-hydroxyethyl(methyl)amino]ethanol',
#  'N,N-Dimethylethanamine;ethane;ethanol',
#  '2-(Dimethylamino)ethanol;2-methylpropane',
#  'Ethane;2-[ethyl(methyl)amino]ethanol',
#  'Ethane;2-[methyl(propyl)amino]ethanol',
#  '1-[Ethyl(2-methoxyethyl)amino]ethanol',
#  '2-(Diethylamino)ethanol;propane',
#  'N-Ethyl-2-methoxy-N-methylethanamine;methanol',
#  '2-[2-Hydroxyethyl(methyl)amino]ethanol;propane',
#  '2-(Diethylamino)ethanol;N,N-dimethylmethanamine',
#  '2-(Dimethylamino)ethanol;vanadium',
#  '2-(Diethylamino)ethyl chlorate',
#  '1-(Dimethylamino)propan-2-ol;ethane',
#  '2-(Dipropylamino)ethanol;ethane',
#  'Ethane;2-[ethyl(propyl)amino]ethanol',
#  '2-[Ethyl(methyl)amino]ethanol;methanol',
#  'Ethane;2-[ethyl(methyl)amino]ethanol',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;ethane',
#  'Bis(2-hydroxyethyl)-dimethylazanium;hydroxide;hydrate',
#  '2-[Fluoromethyl(propyl)amino]ethanol',
#  '2-Hydroxyethyl-dimethyl-sulfanylazanium;perchlorate',
#  '1-[Bis(deuteriomethyl)amino]propan-1-ol',
#  'Sodium;2-hydroxyethyl(trimethyl)azanium;chloride;hydroxide',
#  'Sodium;hydrogen sulfite;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '2-[Bis(2-hydroxyethyl)amino]-2-fluoroethanol',
#  'Ethyl-(1-hydroxyethyl)-dimethylazanium;chloride',
#  'Azanium;ethanolate;2-hydroxyethyl(trimethyl)azanium',
#  'Deuteride;2-hydroxyethyl(trimethyl)azanium',
#  'Deuteride;2-hydroxyethyl(trimethyl)azanium',
#  'Hydroxymethyl-(2-hydroxypropyl)-dimethylazanium;chloride',
#  '2-Hydroxyethyl(dimethyl)azanium;chloride;hydrate',
#  '2-[Ethyl(1-fluoroethyl)amino]ethanol',
#  '1-Hydroxyethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '(1R)-1-(Dimethylamino)propan-1-ol;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;hydroxide;hydrate',
#  '1-(Diethylamino)ethanol;hydrate',
#  '(2S)-2-[Bis(deuteriomethyl)amino]propan-1-ol',
#  '2-[2-Hydroxyethyl(2-oxidoethyl)amino]ethanolate',
#  'N-(2-Hydroxyethyl)-N-methylcarbamodithioate',
#  '(18F)Fluoranylmethyl-methanidyl-methyl-(1,1,2,2-tetradeuterio-2-hydroxyethyl)azanium',
#  '1,1-Dideuterio-2-(dimethylamino)ethanol',
#  '(2,2-Dideuterio-2-hydroxyethyl)-((18F)fluoranylmethyl)-methanidyl-methylazanium',
#  '2-Hydroxyethyl(trimethyl)azanium;hexafluorophosphate',
#  '2-Hydroxyethyl(trimethyl)azanium;iodide;hydrate',
#  '[2-Ethoxyethyl(hydroxymethyl)amino]methanol',
#  '[Hydroxymethyl(2-methoxyethyl)amino]methanol',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;hexahydrate',
#  'Azanium;2-hydroxyethyl(trimethyl)azanium;dichloride',
#  '2-Hydroxy-N,N-dimethylethanamine oxide;hydrate',
#  'Bis(2-hydroxyethyl)-methyl-propylazanium;chloride',
#  'Hydride;tris(2-hydroxyethyl)-methylazanium',
#  '1-Hydroxyethyl(methyl)cyanamide',
#  'Hydride;2-hydroxyethyl(trimethyl)azanium',
#  '2,2-Dihydroxyethyl(trimethyl)azanium;hydroxide',
#  '2-Chloro-2-(diethylamino)ethanol',
#  'Triethyl(2-hydroxyethyl)azanium;hydroxide;hydrate',
#  'Diethyl-bis(2-hydroxyethyl)azanium;bromide',
#  '2-(Dimethylamino)ethyl hypochlorite',
#  '2-(Dimethylamino)ethyl hypochlorite;hydrochloride',
#  '2-[Ethyl(2-hydroxyethyl)amino]ethanol;hydrate',
#  '2-Fluoroethyl-(2-hydroxyethyl)-dimethylazanium;hydroxide',
#  '3-Fluoropropyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-[Fluoro(methyl)amino]ethanol',
#  'Butyl-ethyl-(2-hydroxyethyl)-methylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;propane',
#  '2-Hydroxyethyl(dimethyl)azanium;chlorite',
#  'N,N-Dimethylmethanamine;2-hydroxyethyl(trimethyl)azanium',
#  '2-(Dimethylamino)ethanol;palladium',
#  'Ethyl-(2-hydroxyethyl)-dimethylazanium;fluoride',
#  'Ethanol;tetraethylazanium',
#  '2-Hydroxyethyl(trimethyl)azanium;trimethyl(propyl)azanium',
#  '2,2-Dihydroxyethyl(trimethyl)azanium;chloride',
#  'Chlorcholinhydroxid',
#  'Dideuteriomethyl-methyl-(1,1,2,2-tetradeuterio-2-hydroxyethyl)-(trideuteriomethyl)azanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;hydrate;hydrochloride',
#  '1-Hydroxyethenyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;tetramethylazanium;diiodide',
#  '4-Hydroxybut-2-ynyl(trimethyl)azanium;chloride',
#  'Sodium;2-hydroxyethyl(trimethyl)azanium;bromide;chloride',
#  'Lithium;2-hydroxyethyl(trimethyl)azanium;dichloride',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;iodide',
#  'Cholinquecksilberreaktion',
#  '2-(Dimethylamino)ethanol;hydrate',
#  'Hydroxy-bis(2-hydroxyethyl)-methylazanium',
#  '[2-Hydroxyethyl(dimethyl)azaniumyl]-methylboron',
#  'Chloroethane;2-hydroxyethyl(trimethyl)azanium',
#  '1-(Dimethylamino)ethanol;ethanol',
#  '2-(Dimethylamino)ethoxyboronic acid',
#  '2-[Chloromethyl(methyl)amino]ethanol',
#  '2-[Iodomethyl(propyl)amino]ethanol',
#  'Cholingold',
#  '2-(Dimethylamino)ethanol;ethane-1,2-diol',
#  '2-[Ethyl(2-iodoethyl)amino]ethanol',
#  '2-[2-Hydroxyethyl(2-hydroxyethyl)amino]ethanol',
#  '1,1,2,2-Tetradeuterio-2-deuteriooxy-N,N-bis(1,1,2,2-tetradeuterio-2-deuteriooxyethyl)ethanamine',
#  '[2-Hydroxyethyl(methyl)amino]methyl-methylidynephosphanium',
#  'Ethane;2-hydroxyethyl(trimethyl)azanium',
#  '2-[2-Hydroxyethyl(methyl)amino]ethylboron',
#  '(2,2-Dideuterio-2-hydroxyethyl)-((18F)fluoranylmethyl)-dimethylazanium',
#  '2-[2-Iodoethyl(methyl)amino]ethanol',
#  '1-[Ethyl(methyl)amino]ethane-1,2-diol',
#  '[Ethyl(2-methoxyethyl)amino]methanol',
#  'Copper;2-hydroxyethyl(trimethyl)azanium',
#  'Copper;2-hydroxyethyl(trimethyl)azanium',
#  '2-[Iodomethyl(methyl)amino]ethanol',
#  '2-[Bis(phosphanylmethyl)amino]ethanol',
#  'N,N-Dimethyl-2-sulfanyloxyethanamine',
#  '2-[Ethoxymethyl(methyl)amino]ethanol',
#  'Lithium;1-[bis(1-hydroxyethyl)amino]ethanol',
#  'Bis(2-hydroxyethyl)-dimethylazanium;dihydroxide',
#  'Tris(2-hydroxyethyl)-methylazanium;dihydroxide',
#  'Butane;2-hydroxyethyl(trimethyl)azanium',
#  '2-[Ethyl(iodo)amino]ethanol',
#  '2-Hydroxyethyl(trimethyl)azanium;methanol;chloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;ethanol',
#  '2-(Diethylamino)ethanol;1-(dimethylamino)ethanol',
#  'CID 88236306',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;magnesium;sodium',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;calcium',
#  '2-Hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Hydroxy-(2-hydroxyethyl)-dimethylazanium',
#  '2-(Dimethylamino)ethanol;ethoxyperoxyethane',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethan(16O)ol',
#  '(1R)-1-(Dimethylamino)propan-1-ol',
#  '(1S)-1-(Dimethylamino)propan-1-ol',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;zinc',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;zinc',
#  '2-[Bis(hydroxymethyl)amino]propan-1-ol',
#  '1-(Dimethylamino)propan-2-ol;dihydrochloride',
#  '1-Hydroxyethyl(trimethyl)azanium;bromide',
#  '1-Hydroxyethyl-dimethyl-propylazanium;chloride',
#  'Sodium;2-[bis(2-hydroxyethyl)amino]ethanol;perchlorate',
#  '2-(Dimethylamino)ethyl hypoiodite',
#  'Hydrogen selenate;2-hydroxyethyl(trimethyl)azanium',
#  '2-[2-Hydroxyethyl(methyl)amino]ethanol;hydrofluoride',
#  'Fluoromethyl-(2-hydroxyethyl)-dimethylazanium;bromide',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;hydron;chloride',
#  'Ethyl-(fluoromethyl)-(2-hydroxyethyl)-methylazanium',
#  '2-Hydroxy-N,N-dimethyl-N-(propoxymethyl)ethan-1-aminium chloride',
#  'N-(2-Hydroxyethyl)-N,N-dimethylpropan-1-aminium iodide',
#  '2-{[2-(Dimethylamino)ethyl]selanyl}ethan-1-ol',
#  'N-Ethyl-2-hydroxy-N,N-bis(2-hydroxyethyl)ethan-1-aminium iodide',
#  'Ethyl-bis(2-hydroxyethyl)-methylazanium;bromide',
#  'Ethyl-(2-hydroxyethyl)-methyl-methylazanium',
#  'N-Ethyl-2-hydroxy-N-methylethanamine oxide',
#  'Dimethyl-(111C)methyl-(1,1,2,2-tetradeuterio-2-hydroxyethyl)azanium',
#  '1,1,2,2-Tetradeuterio-2-(dimethylamino)ethanol',
#  'Deuteriomethyl-methyl-(1,1,2,2-tetradeuterio-2-deuteriooxyethyl)-(trideuteriomethyl)azanium',
#  'Amino-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-Deuteriooxyethyl(trimethyl)azanium',
#  'CID 53431124',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;hydron;iodide',
#  '(2-Hydroxy-1-methylethyl)trimethylammonium chloride',
#  '2-(1-Methylaziridin-1-ium-1-yl)ethanol;iodide',
#  '4-(Dimethylamino)but-2-yn-1-ol;hydrochloride',
#  'Potassium;2-(dimethylamino)ethanolate',
#  '(2-Bromo-2-hydroxyethyl)-trimethylazanium',
#  '(2-Fluoro-2-hydroxyethyl)-trimethylazanium',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Hydron;2-hydroxyethyl(trimethyl)azanium;carbonate',
#  '2-[Ethyl(hydroxymethyl)amino]ethanol',
#  'Boron(1-);2-hydroxyethyl(trimethyl)azanium',
#  '2-[Ethyl(fluoro)amino]ethanol',
#  'Trimethyl(2-sulfanyloxyethyl)azanium',
#  'Sodium;2-[bis(2-hydroxyethyl)amino]ethanol;hydroxide;hydrochloride',
#  '2,2-Dihydroxyethyl(trimethyl)azanium;iodide',
#  '3-(Dimethylamino)propan-1-ol;hydrochloride',
#  '2-[Methyl(sulfanylmethyl)amino]ethanol',
#  'Ethyl-(2-hydroxyethyl)-methylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;dihydroxide',
#  '2-Hydroxyethyl-methoxy-dimethylazanium',
#  'N,N,N-Trimethyloxiran-2-aminium chloride',
#  '1-(Dimethylamino)ethane-1,2-diol',
#  '2-Propanol, 1-(dimethylamino)-, hydrobromide',
#  '2-(Diethylamino)ethanol;hydrate',
#  '2-(Diethylamino)ethanol;hydrobromide',
#  'Dichlorozinc;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '2-(Dimethylamino)-2-tritioethanol',
#  '2-(Dimethylamino)(114C)ethanol',
#  'Hydrogen selenite;2-hydroxyethyl(trimethyl)azanium',
#  '[Bis(2-hydroxyethyl)amino]methanetriol',
#  '2-Hydroxyethyl(trimethyl)azanium;bromide',
#  '2-lambda1-Oxidanylethyl(trimethyl)azanium',
#  'CID 522265',
#  '(2-Chloroethyl)(2-hydroxyethyl)dimethylaminium',
#  '1-Chlorosulfinyloxy-2-(dimethylamino)ethane',
#  '2-Hydroxyethyl(trimethyl)azanium;hydrobromide',
#  '2-Hydroxyethyl(trimethyl)azanium;hydroiodide',
#  '2-(Diethylamino)ethyloxidanium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;boron(1-)',
#  '(4-Hydroxy-2-butynyl)trimethylaminium',
#  '(1R)-1-(Diethylamino)ethanol',
#  '(1S)-1-(Diethylamino)ethanol',
#  '(19F)Fluoranylmethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '(19F)Fluoranylmethyl-(2-hydroxyethyl)-dimethylazanium',
#  '1-(Dimethylamino)propan-2-ol;chloride',
#  '2-[2-Hydroxyethyl(methyl)amino]acetonitrile',
#  '[(2R)-1-Hydroxypropan-2-yl]-trimethylazanium',
#  'Platinum(2+);2-(trimethylazaniumyl)ethanolate;dichloride',
#  '[(2S)-1-Hydroxypropan-2-yl]-trimethylazanium',
#  '(1,1,2,2-Tetradeuterio-2-hydroxyethyl)-tris(trideuteriomethyl)azanium',
#  '2-Hydroxyethyl-dimethyl-(111C)methylazanium;iodide',
#  '2-(Dimethylamino)ethanol;dimethylindium',
#  '2-Hydroxyethyl(trimethyl)azanium;sulfite',
#  '2-[Dimethyl((111C)methyl)azaniumyl]ethanolate',
#  '2-[Bis(trideuteriomethyl)amino]ethanol',
#  'Diethyl-(2-hydroxyethyl)-(methoxymethyl)azanium',
#  '2-[Methyl(trimethylsilylmethyl)amino]ethanol',
#  '2-Hydroxy(1,2-14C2)ethyl(trimethyl)azanium;chloride',
#  '2-Hydroxy(1,2-14C2)ethyl(trimethyl)azanium',
#  '2-Hydroxyethyl-dimethyl-(114C)methylazanium;chloride',
#  '2-Hydroxyethyl-dimethyl-(114C)methylazanium',
#  '2-(2-Hydroxyethyl-lambda2-azanyl)ethanol',
#  '2-Hydroxyethyl-dimethyl-(113C)methylazanium;bromide',
#  'Chlorozinc(1+);hydrogen phosphite;2-hydroxyethyl(trimethyl)azanium',
#  '2-(Dimethylamino)ethanol;N,N-dimethylethanamine',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;triiodide',
#  '[Bis(2-hydroxyethyl)amino]germanium',
#  '2-[2-Hydroxyethyl(iodo)amino]ethanol',
#  'Calcium;2-[bis(2-hydroxyethyl)amino]ethanol;chloride',
#  'Azanium;2-hydroxyethyl(trimethyl)azanium;hydroxide',
#  'Copper;2-[bis(2-hydroxyethyl)amino]ethanol',
#  '2-Hydroxypropyl(trimethyl)azanium;dichloride',
#  'Boron;2-(dimethylamino)ethanol',
#  'Azane;2-[2-hydroxyethyl(methyl)amino]ethanol',
#  '2-Bromooxyethyl(trimethyl)azanium;chloride',
#  'Lithium;2-(diethylamino)ethanol',
#  'Hydron;2-hydroxyethyl(trimethyl)azanium',
#  'Cadmium(2+);2-hydroxyethyl(trimethyl)azanium;chloride',
#  '2-Chloro-2-(dimethylamino)ethanol',
#  'N,N-Diethylethanamine;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'CID 20294357',
#  'CID 20294360',
#  'Azane;2-hydroxyethyl(trimethyl)azanium',
#  '1-Ethylaziridin-2-ol',
#  'Magnesium;2-[bis(2-hydroxyethyl)amino]ethanol',
#  'Sodium;1-(dimethylamino)ethanol',
#  'Hydron;2-hydroxyethyl(trimethyl)azanium',
#  'Ethanol;tetramethylazanium;chloride',
#  'Azane;2-(dimethylamino)ethanol',
#  '2-Hydroxyethyl(trimethyl)azanium;methoxymethane;iodide',
#  'Trimethyl(2-sulfanyloxyethyl)azanium;chloride',
#  'Bis(2-hydroxyethyl)azanide;yttrium(3+)',
#  'Ethoxyethane;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;methoxymethane',
#  '2-Hydroxyethyl(trimethyl)azanium;methoxymethane;hydrochloride',
#  'Phosphanium;2-hydroxyethyl(trimethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;selenium(1+)',
#  'Antimony(3+);2-hydroxyethyl(trimethyl)azanium',
#  'Aluminum;2-[bis(2-hydroxyethyl)amino]ethanol',
#  'Potassium;sodium;azane;2-hydroxyethyl(trimethyl)azanium',
#  '(2-Deuterio-2-deuteriooxy-2-fluoroethyl)-trimethylazanium',
#  '2-Hydroxyethyl(methyl)azanide;yttrium(3+)',
#  'Zinc;2-[bis(2-hydroxyethyl)amino]ethanol',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;titanium(2+)',
#  'Sodium;2-hydroxyethyl(trimethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;sulfate',
#  '2-Hydroxyethyl(trimethyl)azanium;phosphane',
#  'Sodium;2-[bis(2-hydroxyethyl)amino]ethanol',
#  '2-(Diethylamino)ethanolate',
#  'Magnesium;2-hydroxyethyl(trimethyl)azanium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;iron(3+)',
#  '1-[Bis(hydroxymethyl)amino]propan-2-ol',
#  'Potassium;2-[bis(2-hydroxyethyl)amino]ethanol',
#  'CID 22688893',
#  '3-(Dimethylamino)propan-1-ol;chloride',
#  'Bis(2-hydroxyethyl)-dipropylazanium;chloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;hydroxide',
#  '1-Hydroxyethyl(trimethyl)azanium;oxido(oxo)borane',
#  'Boron(1-);1-hydroxyethyl(trimethyl)azanium',
#  'Lithium;2-hydroxyethyl(trimethyl)azanium',
#  '2-[Methanidyl(methyl)amino]ethanol',
#  '2-[2-Hydroxyethyl(methanidyl)amino]ethanol',
#  '(2-Bromo-2-hydroxyethyl)-trimethylazanium;bromide',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;silicon(4+)',
#  'Diethyl-(2-hydroxyethyl)-propylazanium',
#  'Ethoxymethyl-(2-hydroxyethyl)-dimethylazanium',
#  '2-(Trimethylazaniumyl)ethanolate;hydrochloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;copper(1+)',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;iodide',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;bromide',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;fluoride',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;hydroxide',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;chloride',
#  '(2S)-2-[Ethyl(methyl)amino]propan-1-ol',
#  '(2R)-2-[Ethyl(methyl)amino]propan-1-ol',
#  '2-[Methyl((111C)methyl)amino]ethanol',
#  '2-[2-Fluoropropyl(methyl)amino]ethanol',
#  '2-Hydroxyethyl-methyl-dipropylazanium',
#  "2,2',2''-Nitrilotriethanol-oxovanadium(1:1)",
#  'Trimethyl-(1,1,2,2-tetradeuterio-2-hydroxy(113C)ethyl)azanium;chloride',
#  'Trimethyl-(1,1,2,2-tetradeuterio-2-hydroxy(113C)ethyl)azanium',
#  '1,1,2,2-Tetradeuterio-2-(trimethylazaniumyl)(113C)ethanolate',
#  'Trimethyl-(1,1,2,2-tetradeuterio-2-hydroxy(213C)ethyl)azanium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;bismuth',
#  'Germanium;2-[2-hydroxyethyl(methyl)amino]ethanol;dihydrate',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;germanium',
#  'Germanium;2-[methyl(2-oxonioethyl)amino]ethyloxidanium;dihydroxide',
#  'Aluminum;2-[bis(2-hydroxyethyl)amino]ethanol',
#  '1,2-Dideuterio-2-[tris(trideuteriomethyl)azaniumyl](113C)ethanolate',
#  '(1,2-Dideuterio-2-hydroxy(213C)ethyl)-tris(trideuteriomethyl)azanium',
#  '1,2-Dideuterio-2-[tris(trideuteriomethyl)azaniumyl](213C)ethanolate',
#  '(1,2-Dideuterio-2-hydroxy(113C)ethyl)-tris(trideuteriomethyl)azanium',
#  '1,1,2,2-Tetradeuterio-2-(trimethylazaniumyl)(213C)ethanolate',
#  '2,2-Dideuterio-2-(trimethylazaniumyl)(213C)ethanolate',
#  '(1,1-Dideuterio-2-hydroxy(113C)ethyl)-trimethylazanium',
#  '2,2-Dideuterio-2-(trimethylazaniumyl)(113C)ethanolate',
#  '(1,1-Dideuterio-2-hydroxy(213C)ethyl)-trimethylazanium',
#  '2,2-Dideuterio-2-[tris(trideuteriomethyl)azaniumyl](213C)ethanolate',
#  '(1,1-Dideuterio-2-hydroxy(113C)ethyl)-tris(trideuteriomethyl)azanium',
#  '2,2-Dideuterio-2-[tris(trideuteriomethyl)azaniumyl](113C)ethanolate',
#  '(1,1-Dideuterio-2-hydroxy(213C)ethyl)-tris(trideuteriomethyl)azanium',
#  '(18F)Fluoranylmethyl-dimethyl-(1,1,2,2-tetradeuterio-2-hydroxyethyl)azanium;chloride',
#  '1-[Ethyl(hydroxymethyl)amino]ethane-1,2-diol hydrochloride',
#  '1-[Ethyl(hydroxymethyl)amino]ethane-1,2-diol',
#  '[Hydroxymethyl(1-methoxyethyl)amino]methanol',
#  '2-Hydroxypropyl(methyl)azanide',
#  '1,1,2,2-Tetradeuterio-2-[dimethyl((111C)methyl)azaniumyl]ethanolate',
#  '[Tris(2-hydroxyethyl)azaniumyl]silicon',
#  'Selenonium,(2-hydroxyethyl)dimethyl-',
#  '2-Hydroxyethyl-dimethyl-prop-2-ynylazanium;chloride',
#  'Cobalt;2-hydroxyethyl(trimethyl)azanium',
#  'Azanium;2-hydroxyethyl(trimethyl)azanium',
#  '1-Hydroxy-2-(trimethylazaniumyl)ethanolate',
#  'Antimony;2-hydroxyethyl(trimethyl)azanium',
#  'Trimethyl(2-selanyliumyloxyethyl)azanium',
#  '2-Hydroxy-1-(trimethylazaniumyl)ethanolate',
#  '2-[Methanidyl(propan-2-yl)amino]ethanol',
#  '2-Hydroxyethyl(methyl)azanide',
#  '1-Hydroxypropan-2-yl(methyl)azanide',
#  '2-[2-Hydroxy(1,2-13C2)ethyl(methyl)amino](1,2-13C2)ethanol;hydrochloride',
#  '2-[2-Hydroxy(1,2-13C2)ethyl(methyl)amino](1,2-13C2)ethanol',
#  '2-[Bis(2-hydroxy(1,2-13C2)ethyl)amino](1,2-13C2)ethanol;hydrochloride',
#  '2-[Bis(2-hydroxy(1,2-13C2)ethyl)amino](1,2-13C2)ethanol',
#  '2-[Ethyl(2-hydroxy(1,2-13C2)ethyl)amino](1,2-13C2)ethanol;hydrochloride',
#  '2-[Ethyl(2-hydroxy(1,2-13C2)ethyl)amino](1,2-13C2)ethanol',
#  'Technetium-99;2-(trimethylazaniumyl)ethanolate',
#  '2-Hydroxyethyl(trimethyl)azanium;technetium-99;chloride',
#  '2-[2-Bromoethyl(ethyl)amino]ethanol',
#  '2-[2-Bromoethyl(methyl)amino]ethanol',
#  '2-[2,2-Difluoroethyl(methyl)amino]ethanol',
#  '2-[2,2-Difluoroethyl(ethyl)amino]ethanol',
#  '2-[But-2-ynyl(methyl)amino]ethanol',
#  'Trifluoro-[[2-hydroxyethyl(methyl)amino]methyl]boranuide',
#  '2-Hydroxyethyl-dimethyl-[(oxo-lambda5-phosphanylidyne)methyl]azanium',
#  'Choline-1,1,2,2-D4 chloride',
#  '2-Hydroxy(213C)ethyl(trimethyl)azanium',
#  '2-[2-Hydroxyethyl(methyl)(15N)amino]ethanol',
#  '1,1-Dideuterio-2-[(2,2-dideuterio-2-hydroxyethyl)-methylamino]ethanol',
#  '2-[2-Hydroxyethyl(1,1,2,2,2-pentadeuterioethyl)amino]ethanol',
#  '1,1-Dideuterio-2-[(2,2-dideuterio-2-hydroxyethyl)-ethylamino]ethanol',
#  '2-[2-Hydroxyethyl((113C)methyl)amino]ethanol',
#  '2-Hydroxyethyl(trimethyl)(15N)azanium',
#  'Bis(2-hydroxyethyl)-methyl-(1,1,2,2,2-pentadeuterioethyl)azanium;bromide',
#  'Bis(2-hydroxyethyl)-methyl-(1,1,2,2,2-pentadeuterioethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;selenium(1+) dihydride',
#  '2-Chlorooxyethyl(trimethyl)azanium;iodide',
#  '1-[1,1-Dihydroxyethyl(2-hydroxyethyl)amino]ethane-1,1-diol',
#  'Copper;2-(dimethylamino)ethanol',
#  'Dichlorozinc;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '2,2-Dihydroxyethyl(trimethyl)azanium;bromide',
#  '2-(Dimethylamino)ethanol;sulfurous acid',
#  '2-[Bis(trideuteriomethyl)amino]ethanol;hydrochloride',
#  '2-[2-Fluoroethyl(2-hydroxyethyl)amino]ethanol',
#  'Ethoxymethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-(Dimethylamino)ethanol;hydrobromide;hydrochloride',
#  'Cyano(2-hydroxyethyl)cyanamide',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;iron',
#  'Zinc;2-hydroxyethyl(trimethyl)azanium;trichloride',
#  '1-Hydroxyethyl(trimethyl)azanium;fluoride',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;titanium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;titanium',
#  '2-Hydroxyethyl(trimethyl)azanium;magnesium',
#  '(2-Hydroxy-2-phosphanylethyl)-trimethylazanium',
#  '[1-Hydroxy-2-(trimethylazaniumyl)ethyl]phosphanide',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;zirconium',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;zirconium',
#  '2-Hydroxyethyl(trimethyl)azanium;phosphite',
#  '2-Hydroxyethyl(trimethyl)azanium;borate',
#  'Aluminum;2-hydroxyethyl(trimethyl)azanium',
#  'Aluminum;2-hydroxyethyl(trimethyl)azanium',
#  '2-[Bis(hydroxymethyl)amino]ethanol;hydrate',
#  'Hydrogen peroxide;2-hydroxyethyl(trimethyl)azanium',
#  'Deuterium monohydride;2-hydroxyethyl(trimethyl)azanium',
#  '1-(Dimethylamino)ethanol;hydrobromide;hydrochloride',
#  '2-(Dimethylamino)ethanol;hydroxy(oxo)titanium',
#  '1-Bromo-2-(diethylamino)ethanol',
#  '1-Hydroxyethyl(trimethyl)azanium;iodide',
#  '1-[Hydroxymethyl(methyl)amino]ethanol',
#  '1-[Ethyl(hydroxymethyl)amino]ethanol',
#  '[Bis(1-hydroxyethyl)amino]-chloro-methyltin',
#  'Dichlorotin(1+);1-[1-hydroxyethyl(methyl)amino]ethanol',
#  '2-Hydroxyethyl(trimethyl)azanium;sodium',
#  '2-Hydroxyethyl(trimethyl)azanium;selenium',
#  'Calcium;(2-hydroxy-2-phosphanylethyl)-trimethylazanium;chloride',
#  'Bis(2-hydroxyethyl)azanide;titanium',
#  '2-Hydroxyethyl(trimethyl)azanium;silicate',
#  '1-Hydroxy-2-(trimethylazaniumyl)ethanethiolate',
#  'Trimethyl(2-sulfidooxyethyl)azanium',
#  'Azane;2-hydroxyethyl(trimethyl)azanium;hydroxide',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;iron',
#  '2-[Ethyl(2-hydroxyethyl)amino]ethanol;sodium',
#  '2-Hydroxyethyl(trimethyl)azanium;molybdenum;chloride',
#  'Gold;2-hydroxyethyl(trimethyl)azanium',
#  'Hydron;2-hydroxyethyl(trimethyl)azanium;phosphite',
#  'Hydrogen phosphite;2-hydroxyethyl(trimethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;oxophosphane',
#  '2-Hydroxyethyl(trimethyl)azanium;sulfur monoxide',
#  '2-Hydroxyethyl(trimethyl)azanium;bromate',
#  '2-Hydroxyethyl(trimethyl)azanium;nitroxyl',
#  '2-Hydroxyethyl(trimethyl)azanium;oxoboron',
#  '2-Hydroxyethyl(trimethyl)azanium;periodate',
#  '2-Hydroxyethyl(trimethyl)azanium;iodate',
#  '2-Hydroxyethyl(trimethyl)azanium;oxido(dioxo)vanadium',
#  'Hydron;2-hydroxyethyl(trimethyl)azanium;sulfate',
#  '2-(Dimethylamino)ethanol;sodium',
#  'Cobalt(2+);2-hydroxyethyl(trimethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;molecular oxygen',
#  'CID 87859015',
#  'Aluminum;1-[bis(1-hydroxyethyl)amino]ethanol',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;chloronickel',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;dichloronickel',
#  '1-[Methoxymethyl(methyl)amino]ethanol',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;silicon',
#  '2-Chlorooxyethyl(trimethyl)azanium;chloride;hydrochloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;nickel',
#  '1-Hydroxyethyl(trimethyl)azanium;perchlorate',
#  '1-(Dimethylamino)ethanol;strontium',
#  '2-(Dimethylamino)ethanol;strontium',
#  'Azane;1-(dimethylamino)ethanol',
#  'Boric acid;2-hydroxyethyl(trimethyl)azanium',
#  '2-Hydroxyethyl(trimethyl)azanium;selenium;chloride',
#  '2-lambda1-Selanyloxyethyl(trimethyl)azanium;chloride',
#  '2-lambda1-Selanyloxyethyl(trimethyl)azanium',
#  'Trimethyl(2-selanyliumyloxyethyl)azanium;hydrochloride',
#  '1-Hydroxyethyl(trimethyl)azanium;hydrochloride',
#  '(1,2-Dideuterio-2-fluoro-2-hydroxyethyl)-trimethylazanium',
#  'Azane;2-hydroxyethyl(trimethyl)azanium;hydrofluoride',
#  'CID 88243170',
#  '(2-Bromo-2-hydroxyethyl)-trimethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;iron(2+)',
#  '2-Hydroxyethyl(trimethyl)azanium;iron',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;boron',
#  'Azane;2-hydroxyethyl(trimethyl)azanium;hydrate',
#  '1-[Bis(sulfanylidene)-lambda5-phosphanyl]-2-(dimethylamino)ethanol',
#  'Bis(2-hydroxyethyl)-dimethylazanium;tetrachloroiron(1-)',
#  '2-Hydroxyethyl(trimethyl)azanium;lithium',
#  'Lithium;2-(trimethylazaniumyl)ethanolate',
#  'Cadmium;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Phosphane;trimethyl(2-oxonioethyl)azanium',
#  '1-(Dimethylamino)ethanol;sodium',
#  'Dioxido(oxo)silane;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Boron;2-hydroxyethyl(trimethyl)azanium',
#  '2-[2-Hydroxyethyl(methyl)amino]ethane-1,1-diol',
#  'Boron;2-(dimethylamino)ethane-1,1-diol',
#  'Bis(2-hydroxyethyl)-dimethylazanium;boron(1-)',
#  'Bis(2-hydroxyethyl)-dimethylazanium;boron',
#  'Boron(1-);tris(2-hydroxyethyl)-methylazanium',
#  'Boron;tris(2-hydroxyethyl)-methylazanium',
#  'Barium;2-hydroxyethyl(trimethyl)azanium',
#  'Barium(2+);2-hydroxyethyl(trimethyl)azanium',
#  '2-(Diethylamino)-1-iodoethanol',
#  'Tetrakis(2-hydroxyethyl)azanium;hydrochloride',
#  'Sodium;2-(dimethylamino)ethanol',
#  'Sodium;1-(dimethylamino)ethanol',
#  'Potassium;2-(dimethylamino)ethanol',
#  'Carbonic acid;2-(dimethylamino)ethanol',
#  '2-Hydroxyethyl(trimethyl)azanium;dibromide',
#  '2-Hydroxyethyl(trimethyl)azanium;bromide;hydrobromide',
#  ...]

# %% [markdown]
# Scrolling through the list, we can see some compounds that look very interesting for our application as hydrogen bond acceptors (HBA) for deep eutectic solvents. Others seem not as useful, such as the radioactive compounds I mentioned earlier, or some are just the parent compounds of the halide salts. Not sure of a great way to further screen and reduce this list, but a start would be removing results that are not halide salts, since that is our criteria for a HBA.

# %%
sorted_names = []

for i in name_list:
    
    if "chloride" in i:
        sorted_names.append(i)
        
    elif "bromide" in i:
        sorted_names.append(i)
        
    elif "fluoride" in i:
        sorted_names.append(i)
        
    elif "iodide" in i:
        sorted_names.append(i)
        
    else:
        pass

# %% [markdown]
# Keeping only the results that contain a halide seems to be the most straightforward to screen these results. The only downside is we may miss compounds that go by a common name, but may indeed by halide salts. I think there shouldn't be too many of those cases to worry about significantly.

# %%
sorted_names
# Out:
# ['Choline chloride',
#  '(2-Hydroxyethyl)triethylammonium iodide',
#  'Choline chloride C-11',
#  'Triethylcholine chloride',
#  'Bis(2-hydroxyethyl)dimethylammonium chloride',
#  'Triethanolamine hydrochloride',
#  'Choline iodide',
#  '2-(Diethylamino)ethanol hydrochloride',
#  '1-Ethyl-1-(2-hydroxyethyl)aziridinium chloride',
#  'Ethanaminium, N,N,N-triethyl-2-hydroxy-, bromide',
#  '2-Hydroxyethyl-(iodomethyl)-dimethylazanium;iodide',
#  'Ethanol, 2-dimethylamino-, hydrochloride',
#  '1-Propanaminium, 2-hydroxy-N,N,N-trimethyl-, chloride',
#  '2-(Dimethylamino)ethanol hydrochloride',
#  'Triethanolamine hydriodide',
#  'Tetrakis(2-hydroxyethyl)ammonium chloride',
#  'Dimethylethylcholine iodide',
#  'Ethanaminium, 2-hydroxy-N,N-bis(2-hydroxyethyl)-N-methyl-, chloride',
#  'Choline chloride-15N',
#  '2-Methoxyethyl(trimethyl)azanium;chloride',
#  'N,N-Diethyl-2-hydroxy-N-methylethan-1-aminium bromide',
#  'Choline-1,1,2,2-d4 bromide',
#  'Methyl-D9-choline chloride',
#  'N-Ethyl-2-hydroxy-N,N-dimethylethan-1-aminium bromide',
#  'Bromomethyl-(2-hydroxyethyl)-dimethylazanium;bromide',
#  'Chloromethyl-(2-hydroxyethyl)-dimethylazanium;iodide',
#  'N-(2-Hydroxyethyl)-N,N-dimethylpropan-1-aminium bromide',
#  "2,2',2''-Nitrilotrisethanol hydrobromide",
#  '2-(Dibutylamino)ethanol hydrochloride',
#  'Diethyl(2-hydroxyethyl)methylammonium iodide',
#  '2-Chloropropyl(diethyl)amine hydrochloride',
#  'Ethyl(2-hydroxyethyl)dimethylammonium chloride',
#  '(2-Hydroxyethyl)tripropylammonium chloride',
#  'Ammonium, ethylbis(2-hydroxyethyl)methyl-, chloride',
#  'Ethyl-(hydroxymethyl)-dimethylazanium;chloride',
#  '2-Hydroxyethyl-dimethyl-[(oxo-lambda5-phosphanylidyne)methyl]azanium;chloride',
#  '2-Hydroxy-N,N-bis(2-hydroxyethyl)-N-methylethan-1-aminium bromide',
#  '(1,1,2,2-Tetradeuterio-2-hydroxyethyl)-tris(trideuteriomethyl)azanium;bromide',
#  '2-Hydroxy(213C)ethyl(trimethyl)azanium;chloride',
#  'Choline bromide-trimethyl-d9',
#  'Bis(2-hydroxyethyl)-dimethylazanium;bromide',
#  'Fluoroethylcholine chloride',
#  '1-Propanol, 2-(dimethylamino)-, hydrochloride',
#  'N,N-Diethyl-2-hydroxy-N-(2-hydroxyethyl)ethan-1-aminium chloride',
#  '2-Chlorooxyethyl(trimethyl)azanium;chloride',
#  'Choline fluoride',
#  '1-Hydroxypropyl(trimethyl)azanium;chloride',
#  'Dibutyl(2-hydroxyethyl)methylammonium chloride',
#  'Diethyl(2-hydroxyethyl)methylammonium chloride',
#  '1-(Diethylamino)ethanol;hydrochloride',
#  '2-(Diisopropylamino)ethanol hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;dichloride',
#  'Ethanol, 2-(butylmethylamino)-, hydrochloride',
#  '2-Hydroxy-N-(2-hydroxyethyl)-N,N-dimethylethan-1-aminium iodide',
#  "2,2'-(Methylimino)bisethanol hydrochloride",
#  '2-(Dipropylamino)ethanol hydrochloride',
#  'N,N-Bis(2-hydroxyethyl)aziridinium chloride',
#  '2-Hydroxyethyl-dimethyl-propan-2-ylazanium;chloride',
#  '1-(Dimethylamino)ethanol;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;trichloride',
#  '(2-Hydroxyethyl)-triethylammonium iodide',
#  'Ethyl-tris(2-hydroxyethyl)azanium;bromide',
#  'Triethyl(1-hydroxyethyl)azanium;chloride',
#  'Ethyl-tris(hydroxymethyl)azanium;chloride',
#  'Diethyl-bis(1-hydroxyethyl)azanium;chloride',
#  '(2R)-2-(Dimethylamino)propan-1-ol;hydrochloride',
#  '(2S)-2-(Dimethylamino)propan-1-ol;hydrochloride',
#  'Azanium;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Azane;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Calcium;[1-hydroxy-2-(trimethylazaniumyl)ethyl]phosphanide;chloride',
#  'Tris(2-hydroxyethyl)-propylazanium;chloride',
#  '1-[1-Hydroxyethyl(methyl)amino]ethanol;hydrochloride',
#  '2-[Bis(hydroxymethyl)amino]propan-1-ol;hydrochloride',
#  'Chloromethyl-(1-hydroxyethyl)-dimethylazanium;chloride',
#  '2-[Butyl(methyl)amino]ethanol;dihydrochloride',
#  '(2-Chloro-2-hydroxyethyl)-trimethylazanium;hydrochloride',
#  'Diethyl-(2-hydroxyethyl)-propylazanium;chloride',
#  'Sodium;1-[bis(1-hydroxyethyl)amino]ethanol;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;phosphoryl trichloride',
#  '2-Hydroxyethyl-tri(propan-2-yl)azanium;chloride',
#  'Azanium;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Azane;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;calcium;hydrochloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;calcium;hydrochloride',
#  '(2R)-1-(Dimethylamino)propan-2-ol;hydrochloride',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium;phosphoryl trichloride',
#  '1-(Diethylamino)ethane-1,2-diol;hydrochloride',
#  '2-(Diethylamino)ethane-1,1-diol;hydrochloride',
#  '1-[Ethyl(1-hydroxyethyl)amino]ethanol;hydrochloride',
#  '2-Hydroxy(113C)ethyl(trimethyl)azanium;chloride',
#  'Tris(1-hydroxyethyl)-methylazanium;chloride',
#  '(3-Fluoro-2-hydroxypropyl)-trimethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;dihydrochloride',
#  '2-[2-(Dimethylamino)ethyl-methylamino]ethanol;dihydrochloride',
#  '(2S)-2-(Diethylamino)propan-1-ol;hydrochloride',
#  'Chromium(3+);2-hydroxyethyl(trimethyl)azanium;tetrachloride;hexahydrate',
#  'Butyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;dihydrate',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;hydrofluoride',
#  'Chloromethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  'Triethyl(2-hydroxyethyl)azanium;fluoride',
#  'Calcium;2-hydroxyethyl-dimethyl-[(oxo-lambda5-phosphanylidyne)methyl]azanium;chloride',
#  '2-[Ethyl(2-hydroxyethyl)amino]ethanol;hydrochloride',
#  '1-[Bis(1-hydroxyethyl)amino]ethanol;hydrochloride',
#  '2-(Trimethylazaniumyl)ethyl hypofluorite chloride',
#  '2-Propanol,1-(dimethylamino)-, hydrochloride (1:1)',
#  'Sodium;2-[bis(2-hydroxyethyl)amino]ethanol;chloride',
#  '2-Hydroxyethyl(dimethyl)azanium;chloride',
#  '2-Chlorooxyethyl(trimethyl)azanium;bromide',
#  'Azanium;2-[bis(2-hydroxyethyl)amino]ethanol;chloride',
#  'Bis(1-hydroxyethyl)-dimethylazanium;chloride',
#  'Cyanomethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  'O-[2-(Dimethylamino)ethyl]hydroxylamine;hydrochloride',
#  '1-Hydroxyethyl(trimethyl)azanium;chloride',
#  '2-Hydroxyethyl-dimethyl-propylazanium;chloride',
#  'Bis(2-hydroxyethyl)-dimethylazanium;fluoride',
#  'Tris(2-hydroxyethyl)-methylazanium;fluoride',
#  '2-Hydroxyethyl(trimethyl)azanium;dichloride',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;hydrochloride',
#  '1-Hydroxypropyl(trimethyl)azanium;hydrochloride',
#  '2-Chlorooxyethyl(trimethyl)azanium;hydrochloride',
#  '2-[Bis(hydroxymethyl)amino]ethanol;hydrochloride',
#  'Ethane-1,2-diol;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '(2-Chloro-2-hydroxyethyl)-trimethylazanium;bromide',
#  '[(2S)-2-Hydroxypropyl]-trimethylazanium;chloride',
#  '[(2R)-2-Hydroxypropyl]-trimethylazanium;chloride',
#  'Aziridinium, 1-(2-hydroxyethyl)-1-methyl-, chloride',
#  '2-(Diethylamino)propan-1-ol;hydrochloride',
#  'Ethyl-tris(2-hydroxyethyl)azanium;chloride',
#  '2-Hydroxy-N,N-bis(2-hydroxyethyl)-N-methylethan-1-aminium iodide',
#  '(2-Chloro-2-hydroxyethyl)-trimethylazanium;chloride',
#  'Fluoroethylcholine bromide',
#  '(2-Hydroxyethyl)(1-hydroxy-1-methylethyl)dimethylammonium chloride',
#  'Fluorocholine F-18 bromide',
#  'Bis(2-hydroxyethyl)-dimethylazanium;trichloroiron;chloride',
#  'Sodium;2-hydroxyethyl(trimethyl)azanium;chloride;hydroxide',
#  'Sodium;hydrogen sulfite;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Ethyl-(1-hydroxyethyl)-dimethylazanium;chloride',
#  'Hydroxymethyl-(2-hydroxypropyl)-dimethylazanium;chloride',
#  '2-Hydroxyethyl(dimethyl)azanium;chloride;hydrate',
#  '1-Hydroxyethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '(1R)-1-(Dimethylamino)propan-1-ol;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;iodide;hydrate',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;hexahydrate',
#  'Azanium;2-hydroxyethyl(trimethyl)azanium;dichloride',
#  'Bis(2-hydroxyethyl)-methyl-propylazanium;chloride',
#  'Diethyl-bis(2-hydroxyethyl)azanium;bromide',
#  '2-(Dimethylamino)ethyl hypochlorite;hydrochloride',
#  '3-Fluoropropyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  'Butyl-ethyl-(2-hydroxyethyl)-methylazanium;chloride',
#  'Ethyl-(2-hydroxyethyl)-dimethylazanium;fluoride',
#  '2,2-Dihydroxyethyl(trimethyl)azanium;chloride',
#  'Dideuteriomethyl-methyl-(1,1,2,2-tetradeuterio-2-hydroxyethyl)-(trideuteriomethyl)azanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;hydrate;hydrochloride',
#  '1-Hydroxyethenyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;tetramethylazanium;diiodide',
#  '4-Hydroxybut-2-ynyl(trimethyl)azanium;chloride',
#  'Sodium;2-hydroxyethyl(trimethyl)azanium;bromide;chloride',
#  'Lithium;2-hydroxyethyl(trimethyl)azanium;dichloride',
#  '2-Hydroxyethyl(trimethyl)azanium;chloride;iodide',
#  '2-Hydroxyethyl(trimethyl)azanium;methanol;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  '1-(Dimethylamino)propan-2-ol;dihydrochloride',
#  '1-Hydroxyethyl(trimethyl)azanium;bromide',
#  '1-Hydroxyethyl-dimethyl-propylazanium;chloride',
#  '2-[2-Hydroxyethyl(methyl)amino]ethanol;hydrofluoride',
#  'Fluoromethyl-(2-hydroxyethyl)-dimethylazanium;bromide',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;hydron;chloride',
#  '2-Hydroxy-N,N-dimethyl-N-(propoxymethyl)ethan-1-aminium chloride',
#  'N-(2-Hydroxyethyl)-N,N-dimethylpropan-1-aminium iodide',
#  'N-Ethyl-2-hydroxy-N,N-bis(2-hydroxyethyl)ethan-1-aminium iodide',
#  'Ethyl-bis(2-hydroxyethyl)-methylazanium;bromide',
#  'Amino-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;hydron;iodide',
#  '(2-Hydroxy-1-methylethyl)trimethylammonium chloride',
#  '2-(1-Methylaziridin-1-ium-1-yl)ethanol;iodide',
#  '4-(Dimethylamino)but-2-yn-1-ol;hydrochloride',
#  'Calcium;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Sodium;2-[bis(2-hydroxyethyl)amino]ethanol;hydroxide;hydrochloride',
#  '2,2-Dihydroxyethyl(trimethyl)azanium;iodide',
#  '3-(Dimethylamino)propan-1-ol;hydrochloride',
#  'Ethyl-(2-hydroxyethyl)-methylazanium;chloride',
#  'N,N,N-Trimethyloxiran-2-aminium chloride',
#  '2-Propanol, 1-(dimethylamino)-, hydrobromide',
#  '2-(Diethylamino)ethanol;hydrobromide',
#  'Dichlorozinc;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;bromide',
#  '2-Hydroxyethyl(trimethyl)azanium;hydrobromide',
#  '2-Hydroxyethyl(trimethyl)azanium;hydroiodide',
#  '(19F)Fluoranylmethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '1-(Dimethylamino)propan-2-ol;chloride',
#  'Platinum(2+);2-(trimethylazaniumyl)ethanolate;dichloride',
#  '2-Hydroxyethyl-dimethyl-(111C)methylazanium;iodide',
#  '2-Hydroxy(1,2-14C2)ethyl(trimethyl)azanium;chloride',
#  '2-Hydroxyethyl-dimethyl-(114C)methylazanium;chloride',
#  '2-Hydroxyethyl-dimethyl-(113C)methylazanium;bromide',
#  '2-[Bis(2-hydroxyethyl)amino]ethanol;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;triiodide',
#  'Calcium;2-[bis(2-hydroxyethyl)amino]ethanol;chloride',
#  '2-Hydroxypropyl(trimethyl)azanium;dichloride',
#  '2-Bromooxyethyl(trimethyl)azanium;chloride',
#  'Cadmium(2+);2-hydroxyethyl(trimethyl)azanium;chloride',
#  'N,N-Diethylethanamine;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Ethanol;tetramethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;methoxymethane;iodide',
#  'Trimethyl(2-sulfanyloxyethyl)azanium;chloride',
#  'Ethoxyethane;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;methoxymethane;hydrochloride',
#  '3-(Dimethylamino)propan-1-ol;chloride',
#  'Bis(2-hydroxyethyl)-dipropylazanium;chloride',
#  '(2-Bromo-2-hydroxyethyl)-trimethylazanium;bromide',
#  '2-(Trimethylazaniumyl)ethanolate;hydrochloride',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;iodide',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;bromide',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;fluoride',
#  '2-Hydroxyethyl-tri((113C)methyl)(15N)azanium;chloride',
#  'Trimethyl-(1,1,2,2-tetradeuterio-2-hydroxy(113C)ethyl)azanium;chloride',
#  '(18F)Fluoranylmethyl-dimethyl-(1,1,2,2-tetradeuterio-2-hydroxyethyl)azanium;chloride',
#  '1-[Ethyl(hydroxymethyl)amino]ethane-1,2-diol hydrochloride',
#  '2-Hydroxyethyl-dimethyl-prop-2-ynylazanium;chloride',
#  '2-[2-Hydroxy(1,2-13C2)ethyl(methyl)amino](1,2-13C2)ethanol;hydrochloride',
#  '2-[Bis(2-hydroxy(1,2-13C2)ethyl)amino](1,2-13C2)ethanol;hydrochloride',
#  '2-[Ethyl(2-hydroxy(1,2-13C2)ethyl)amino](1,2-13C2)ethanol;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;technetium-99;chloride',
#  'Choline-1,1,2,2-D4 chloride',
#  'Bis(2-hydroxyethyl)-methyl-(1,1,2,2,2-pentadeuterioethyl)azanium;bromide',
#  '2-Chlorooxyethyl(trimethyl)azanium;iodide',
#  'Dichlorozinc;2-hydroxyethyl(trimethyl)azanium;chloride',
#  '2,2-Dihydroxyethyl(trimethyl)azanium;bromide',
#  '2-[Bis(trideuteriomethyl)amino]ethanol;hydrochloride',
#  'Ethoxymethyl-(2-hydroxyethyl)-dimethylazanium;chloride',
#  '2-(Dimethylamino)ethanol;hydrobromide;hydrochloride',
#  'Zinc;2-hydroxyethyl(trimethyl)azanium;trichloride',
#  '1-Hydroxyethyl(trimethyl)azanium;fluoride',
#  '1-(Dimethylamino)ethanol;hydrobromide;hydrochloride',
#  '1-Hydroxyethyl(trimethyl)azanium;iodide',
#  'Calcium;(2-hydroxy-2-phosphanylethyl)-trimethylazanium;chloride',
#  '2-Hydroxyethyl(trimethyl)azanium;molybdenum;chloride',
#  '2-Chlorooxyethyl(trimethyl)azanium;chloride;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;selenium;chloride',
#  '2-lambda1-Selanyloxyethyl(trimethyl)azanium;chloride',
#  'Trimethyl(2-selanyliumyloxyethyl)azanium;hydrochloride',
#  '1-Hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Azane;2-hydroxyethyl(trimethyl)azanium;hydrofluoride',
#  '(2-Bromo-2-hydroxyethyl)-trimethylazanium;chloride',
#  'Cadmium;2-hydroxyethyl(trimethyl)azanium;chloride',
#  'Dioxido(oxo)silane;2-hydroxyethyl(trimethyl)azanium;hydrochloride',
#  'Tetrakis(2-hydroxyethyl)azanium;hydrochloride',
#  '2-Hydroxyethyl(trimethyl)azanium;dibromide',
#  '2-Hydroxyethyl(trimethyl)azanium;bromide;hydrobromide',
#  '2-Hydroxyethyl(trimethyl)azanium;iron;chloride',
#  'Choline-D13 chloride',
#  'Ethyl-tris(1-hydroxyethyl)azanium;chloride',
#  '2-Hydroxy(1,2-13C2)ethyl(trimethyl)azanium;chloride',
#  '2-Hydroxyethyl-dimethyl-(113C)methylazanium;hydrobromide',
#  '2-Hydroxyethyl-dimethyl-(methylsulfanylmethyl)azanium;chloride',
#  '2-[Bis(1,1,2,2,2-pentadeuterioethyl)amino]ethanol;hydrochloride']

# %%
len(sorted_names)
# Out:
# 260

# %% [markdown]
# We have reduced the number of results from 1072 to 260, now most of these should be decent candiates to begin the screening process. Interestingly some of these results are also complexed with metals. I'm not sure about these and whether or not to include them.

# %% [markdown]
# Let's start writing this as a function so that we can test this on a larger dataset.

# %% [markdown]
# Another better way to approach this is to check the smiles strings of the compounds and eliminate based on not containing the halide and the ammonium group

# %%
smiles_list = []
for cid in similarity_list:
    smiles_list.append(pcp.get_properties('canonical_smiles', cid))

# %%
smiles_list
# Out:
# [[{'CID': 6209, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 7618, 'CanonicalSMILES': 'C(CO)N(CCO)CCO'}],
#  [{'CID': 7902, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 7497, 'CanonicalSMILES': 'CCN(CC)CCO'}],
#  [{'CID': 305, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 7767, 'CanonicalSMILES': 'CN(CCO)CCO'}],
#  [{'CID': 37511, 'CanonicalSMILES': 'CC(CN(C)C)O'}],
#  [{'CID': 14074, 'CanonicalSMILES': 'C1CN1CCO'}],
#  [{'CID': 8769, 'CanonicalSMILES': 'CCN(CCO)CCO'}],
#  [{'CID': 31255, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[OH-]'}],
#  [{'CID': 74724, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 80057, 'CanonicalSMILES': 'CC[N+](CC)(CC)CCO.[I-]'}],
#  [{'CID': 75171, 'CanonicalSMILES': 'CN(C)CCN(C)CCO'}],
#  [{'CID': 14989482, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 449688, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 198804, 'CanonicalSMILES': 'CC[N+](CC)(CC)CCO.[Cl-]'}],
#  [{'CID': 162303, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO.[Cl-]'}],
#  [{'CID': 118525, 'CanonicalSMILES': 'C[N+](CCO)(CCO)CCO.[OH-]'}],
#  [{'CID': 101814, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.Cl'}],
#  [{'CID': 87300, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[I-]'}],
#  [{'CID': 85865, 'CanonicalSMILES': 'CC(CO)N(C)C'}],
#  [{'CID': 84429, 'CanonicalSMILES': 'CCN(CC)CCO.Cl'}],
#  [{'CID': 76721, 'CanonicalSMILES': 'CCCN(CCC)CCO'}],
#  [{'CID': 62288, 'CanonicalSMILES': 'C(CO)N(CC[O-])CC[O-].[Cu+2]'}],
#  [{'CID': 60232, 'CanonicalSMILES': 'CC[N+]1(CC1)CCO.[Cl-]'}],
#  [{'CID': 42848, 'CanonicalSMILES': 'CCCN(CCO)CCO'}],
#  [{'CID': 16942, 'CanonicalSMILES': 'CC(C[N+](C)(C)C)O'}],
#  [{'CID': 6552, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C(=O)(O)[O-]'}],
#  [{'CID': 18772452, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Cu]'}],
#  [{'CID': 15419000, 'CanonicalSMILES': 'CC[N+](CC)(CC)CCO.[Br-]'}],
#  [{'CID': 14859573, 'CanonicalSMILES': 'C[N+](C)(CCO)CI.[I-]'}],
#  [{'CID': 449689, 'CanonicalSMILES': 'C[N+](C)(CCO)CCF'}],
#  [{'CID': 449673, 'CanonicalSMILES': 'C[N+](C)(CCO)CF'}],
#  [{'CID': 404592, 'CanonicalSMILES': 'C[N+](C)(CCO)CF'}],
#  [{'CID': 404591, 'CanonicalSMILES': 'C[N+](C)(CCO)CF.[Cl-]'}],
#  [{'CID': 287929, 'CanonicalSMILES': 'CN(CCO)CC#C'}],
#  [{'CID': 200674, 'CanonicalSMILES': 'CN(C)CCO.Cl'}],
#  [{'CID': 45414, 'CanonicalSMILES': 'CC[N+]1(CC1)CCO'}],
#  [{'CID': 17916, 'CanonicalSMILES': 'CCN(C)CCO'}],
#  [{'CID': 16941, 'CanonicalSMILES': 'CC(C[N+](C)(C)C)O.[Cl-]'}],
#  [{'CID': 24799587, 'CanonicalSMILES': 'C[NH+](C)CCO.[Cl-]'}],
#  [{'CID': 6950248, 'CanonicalSMILES': 'CC(CN(C)C)O'}],
#  [{'CID': 6395359, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)O'}],
#  [{'CID': 6328237, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Cu+]'}],
#  [{'CID': 5249138, 'CanonicalSMILES': 'C[NH+](C)CCO'}],
#  [{'CID': 2723762, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.I'}],
#  [{'CID': 357051, 'CanonicalSMILES': 'C(CO)N(CO)CO'}],
#  [{'CID': 199656, 'CanonicalSMILES': 'CCN(CCO)CCCl'}],
#  [{'CID': 172277, 'CanonicalSMILES': 'CCl.C(CO)N(CCO)CCO'}],
#  [{'CID': 152431, 'CanonicalSMILES': 'CC(CO)[N+](C)(C)C'}],
#  [{'CID': 83283, 'CanonicalSMILES': 'C(CO)[N+](CCO)(CCO)CCO.[Cl-]'}],
#  [{'CID': 80058, 'CanonicalSMILES': 'CC[N+](CC)(CC)CCO'}],
#  [{'CID': 70682, 'CanonicalSMILES': 'CC[N+](C)(C)CCO.[I-]'}],
#  [{'CID': 25781, 'CanonicalSMILES': 'CC[N+](C)(C)CCO'}],
#  [{'CID': 23437, 'CanonicalSMILES': 'C[N+](CCO)(CCO)CCO.[Cl-]'}],
#  [{'CID': 71310335, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 23352174, 'CanonicalSMILES': 'C[N+](C)(C)CCOC.[Cl-]'}],
#  [{'CID': 23066982, 'CanonicalSMILES': 'CC[N+](C)(CC)CCO.[Br-]'}],
#  [{'CID': 16217619, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 16213540, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 16213539, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 15029190, 'CanonicalSMILES': 'C[N+](C)(CCO)CC#C'}],
#  [{'CID': 15029175, 'CanonicalSMILES': 'CC[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 14943907, 'CanonicalSMILES': 'CC[N+](CC)(CC)CCO.[OH-]'}],
#  [{'CID': 14859571, 'CanonicalSMILES': 'C[N+](C)(CCO)CBr.[Br-]'}],
#  [{'CID': 14859569, 'CanonicalSMILES': 'C[N+](C)(CCO)CCl.[I-]'}],
#  [{'CID': 13778189, 'CanonicalSMILES': 'CCC[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 12249371, 'CanonicalSMILES': 'C(CO)N(CCO)Cl'}],
#  [{'CID': 12239068, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.Br'}],
#  [{'CID': 3063123, 'CanonicalSMILES': 'CCCCN(CCCC)CCO.Cl'}],
#  [{'CID': 3017041, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO.[OH-]'}],
#  [{'CID': 413857, 'CanonicalSMILES': 'CN(C)CC#CCO'}],
#  [{'CID': 342520, 'CanonicalSMILES': 'C(CO)N(CCO)CO'}],
#  [{'CID': 293482, 'CanonicalSMILES': 'CN(CCO)OC'}],
#  [{'CID': 249874, 'CanonicalSMILES': 'CCN(CCO)CC#C'}],
#  [{'CID': 239819, 'CanonicalSMILES': 'CC(C)N(C)CCO'}],
#  [{'CID': 237041, 'CanonicalSMILES': 'CCCCN(C)CCO'}],
#  [{'CID': 200221, 'CanonicalSMILES': 'CC[N+](C)(CC)CCO.[I-]'}],
#  [{'CID': 170746, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 162304, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO'}],
#  [{'CID': 120823, 'CanonicalSMILES': 'CCN(CC)CC(C)O.Cl'}],
#  [{'CID': 117618, 'CanonicalSMILES': 'C[N+](C)(C)CCOC.Cl'}],
#  [{'CID': 116739, 'CanonicalSMILES': 'CCC(N(C)C)O'}],
#  [{'CID': 103983, 'CanonicalSMILES': 'CN(CCO)CCCl'}],
#  [{'CID': 87940, 'CanonicalSMILES': 'CC[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 83239, 'CanonicalSMILES': 'CC[N+](C)(CC)CCO'}],
#  [{'CID': 57052, 'CanonicalSMILES': 'CCC[N+](CCC)(CCC)CCO.[Cl-]'}],
#  [{'CID': 46081, 'CanonicalSMILES': 'CC[N+](C)(CCO)CCO.[Cl-]'}],
#  [{'CID': 23438, 'CanonicalSMILES': 'C[N+](CCO)(CCO)CCO'}],
#  [{'CID': 88729402, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.O.O'}],
#  [{'CID': 87876898, 'CanonicalSMILES': 'CC[N+](C)(C)CO.[Cl-]'}],
#  [{'CID': 87573822, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-]Cl(=O)(=O)=O'}],
#  [{'CID': 87389474, 'CanonicalSMILES': 'CCN(CC)CCOCl'}],
#  [{'CID': 86759356, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.O'}],
#  [{'CID': 86752887, 'CanonicalSMILES': 'C[N+](C)(CCO)C#P=O.[Cl-]'}],
#  [{'CID': 86106984, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O.[Cl-]'}],
#  [{'CID': 71360639, 'CanonicalSMILES': 'C[N+](CCO)(CCO)CCO.[Br-]'}],
#  [{'CID': 71309220, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 71309123, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 71308987, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 57483587, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO.[Br-]'}],
#  [{'CID': 57266120, 'CanonicalSMILES': 'C[N+](C)(C)CCOOCCO'}],
#  [{'CID': 55252930, 'CanonicalSMILES': 'C[N+](C)(CCO)CCF.[Cl-]'}],
#  [{'CID': 46209411, 'CanonicalSMILES': 'CN(CCO)CCF'}],
#  [{'CID': 45791167, 'CanonicalSMILES': 'CCN(C)C(C)CO'}],
#  [{'CID': 23680072, 'CanonicalSMILES': 'CN(C)CC[O-].[Na+]'}],
#  [{'CID': 23675624, 'CanonicalSMILES': '[Li+].CN(C)CC[O-]'}],
#  [{'CID': 23459462, 'CanonicalSMILES': 'CC(CO)N(C)C.Cl'}],
#  [{'CID': 22763438, 'CanonicalSMILES': 'CC[N+](CC)(CCO)CCO.[Cl-]'}],
#  [{'CID': 22663003, 'CanonicalSMILES': 'CCN(CC)CC.CCO'}],
#  [{'CID': 22495101, 'CanonicalSMILES': 'C[N+](C)(C)CCOCl.[Cl-]'}],
#  [{'CID': 22218551, 'CanonicalSMILES': 'CCCN(CC)CCO'}],
#  [{'CID': 22160862, 'CanonicalSMILES': 'CC([N+](C)(C)C(C)O)O'}],
#  [{'CID': 22134097, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[F-]'}],
#  [{'CID': 21988085, 'CanonicalSMILES': 'CCC([N+](C)(C)C)O.[Cl-]'}],
#  [{'CID': 21149523, 'CanonicalSMILES': 'CCCC[N+](C)(CCCC)CCO.[Cl-]'}],
#  [{'CID': 21149385, 'CanonicalSMILES': 'CC[N+](C)(CC)CCO.[Cl-]'}],
#  [{'CID': 21116013, 'CanonicalSMILES': 'CCN(CC)C(C)O.Cl'}],
#  [{'CID': 20547070, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[C-]#N'}],
#  [{'CID': 20480851, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C(#N)[S-]'}],
#  [{'CID': 20326578, 'CanonicalSMILES': 'CC(C)N(CCO)C(C)C.Cl'}],
#  [{'CID': 20056506,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.[Cl-].[Cl-]'}],
#  [{'CID': 19607192, 'CanonicalSMILES': 'C[N+](C)(C)CCOBr'}],
#  [{'CID': 19030402, 'CanonicalSMILES': 'CCCCN(C)CCO.Cl'}],
#  [{'CID': 18786766, 'CanonicalSMILES': 'CC([N+](C)(C(C)O)C(C)O)O'}],
#  [{'CID': 18520755, 'CanonicalSMILES': 'C[N+](C)(C)CCOCl'}],
#  [{'CID': 18323499, 'CanonicalSMILES': 'C[N+](C)(C)CCOO'}],
#  [{'CID': 18004298, 'CanonicalSMILES': 'CCN(C(C)O)C(C)O'}],
#  [{'CID': 18003851, 'CanonicalSMILES': 'CC(N(C)C(C)O)O'}],
#  [{'CID': 17885833, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-]Cl(=O)=O'}],
#  [{'CID': 15894840, 'CanonicalSMILES': 'CCN(CC)C(C)O'}],
#  [{'CID': 15029177, 'CanonicalSMILES': 'CC(C)[N+](C)(C)CCO'}],
#  [{'CID': 14818435, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO.[I-]'}],
#  [{'CID': 13778190, 'CanonicalSMILES': 'CCC[N+](C)(C)CCO'}],
#  [{'CID': 13650816, 'CanonicalSMILES': 'C[N+](C)(C)CCO.OS(=O)[O-]'}],
#  [{'CID': 13635719, 'CanonicalSMILES': 'COCCN(CCO)CCO'}],
#  [{'CID': 13076199, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)Cl'}],
#  [{'CID': 12388301, 'CanonicalSMILES': 'CC(CO)N(C)C'}],
#  [{'CID': 12388300, 'CanonicalSMILES': 'CC(CO)N(C)C'}],
#  [{'CID': 11743787, 'CanonicalSMILES': 'CC(C[N+](C)(C)C)O'}],
#  [{'CID': 11715488, 'CanonicalSMILES': 'C[N+](C)(CCO)CCF'}],
#  [{'CID': 10410806, 'CanonicalSMILES': 'CC(C[N+](C)(C)C)O'}],
#  [{'CID': 10313070, 'CanonicalSMILES': 'CC(N(C)C)O'}],
#  [{'CID': 7057913, 'CanonicalSMILES': 'CC(CN(C)C)O'}],
#  [{'CID': 6452936, 'CanonicalSMILES': 'CN(CCO)CCO.Cl'}],
#  [{'CID': 5102550, 'CanonicalSMILES': 'C[N+](C)(C)CCOF'}],
#  [{'CID': 3083623, 'CanonicalSMILES': 'B(O)(O)OCC[N+](C)(C)C'}],
#  [{'CID': 231181, 'CanonicalSMILES': 'CCN(C)CC(C)O'}],
#  [{'CID': 199607, 'CanonicalSMILES': 'CCCN(CCC)CCO.Cl'}],
#  [{'CID': 185204, 'CanonicalSMILES': 'CN(CCO)Br'}],
#  [{'CID': 172363, 'CanonicalSMILES': 'CN(C)CC(O)O'}],
#  [{'CID': 139167, 'CanonicalSMILES': 'C[N+](C)(CCO)[O-]'}],
#  [{'CID': 124318, 'CanonicalSMILES': 'C[N+]1(CC1)CCO'}],
#  [{'CID': 47153, 'CanonicalSMILES': 'C1C[N+]1(CCO)CCO.[Cl-]'}],
#  [{'CID': 17383, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O'}],
#  [{'CID': 134694270, 'CanonicalSMILES': 'C[N+](C)(CCO)CF.[Cl-]'}],
#  [{'CID': 134530558, 'CanonicalSMILES': 'CCC[N+](CC)(CCC)CCO'}],
#  [{'CID': 134519098, 'CanonicalSMILES': 'CC(C)[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 131729809, 'CanonicalSMILES': 'CN(C)CCO.[AlH3]'}],
#  [{'CID': 130126311, 'CanonicalSMILES': 'CCN(CCO)C(C)O'}],
#  [{'CID': 129856292, 'CanonicalSMILES': '[H-].C[N+](C)(C)CCO'}],
#  [{'CID': 129810301, 'CanonicalSMILES': 'CC(N(C)C)O.Cl'}],
#  [{'CID': 129704045, 'CanonicalSMILES': 'CC(N(C)C)O.O'}],
#  [{'CID': 129676557,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.C[N+](C)(C)CCO.[Cl-].[Cl-].[Cl-]'}],
#  [{'CID': 129673118, 'CanonicalSMILES': 'CN(CCO)C#P=O'}],
#  [{'CID': 126959875, 'CanonicalSMILES': 'CC[N+](CC)(CC)CCO.I'}],
#  [{'CID': 123877633, 'CanonicalSMILES': 'C[N+](CCO)(CCO)CO'}],
#  [{'CID': 123607238, 'CanonicalSMILES': 'C[N+]([CH2-])(CCO)CF'}],
#  [{'CID': 123549545, 'CanonicalSMILES': 'C[N+](C)(C)C[CH-]O'}],
#  [{'CID': 122674908, 'CanonicalSMILES': 'C[N+](C)(CCO)CCOC'}],
#  [{'CID': 122421178, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.OCl'}],
#  [{'CID': 121418932, 'CanonicalSMILES': 'CCN(C)CCO.CN(C)CCO'}],
#  [{'CID': 121349010, 'CanonicalSMILES': 'C[N+](C)(C)C(CO)Cl'}],
#  [{'CID': 118588468, 'CanonicalSMILES': 'CC#N.CN(C)CCO'}],
#  [{'CID': 118511692, 'CanonicalSMILES': 'CC[N+](C)(CC)C(C)O'}],
#  [{'CID': 118511685, 'CanonicalSMILES': 'CC[N+](C)(C(C)O)C(C)O'}],
#  [{'CID': 118377787, 'CanonicalSMILES': 'CCN(CCO)CCO.N'}],
#  [{'CID': 117810189, 'CanonicalSMILES': 'CC(N(C)CCOC)O'}],
#  [{'CID': 117779754, 'CanonicalSMILES': 'CC(C)(N(C)CCO)O'}],
#  [{'CID': 91148178, 'CanonicalSMILES': 'CC[N+](C)(C)CCO.CO'}],
#  [{'CID': 91019404, 'CanonicalSMILES': 'CC.CN(C)CCO'}],
#  [{'CID': 90302214, 'CanonicalSMILES': 'CN(CCO)CCO.C=O'}],
#  [{'CID': 90073837, 'CanonicalSMILES': 'CC[N+](C)(CC)CC.CCO'}],
#  [{'CID': 89571979, 'CanonicalSMILES': 'CCN(C)CC.CCO'}],
#  [{'CID': 89522529, 'CanonicalSMILES': 'CC[N+](CCO)(CCO)CCO.[Br-]'}],
#  [{'CID': 89206203, 'CanonicalSMILES': 'CC([N+](C)(CCO)C(C)O)O'}],
#  [{'CID': 88840783, 'CanonicalSMILES': 'C[N+](C)(C)CCO.OOCl'}],
#  [{'CID': 88811916, 'CanonicalSMILES': 'CCOCC.CN(C)CCO'}],
#  [{'CID': 88801749, 'CanonicalSMILES': 'CC[N+](CC)(CC)C(C)O.[Cl-]'}],
#  [{'CID': 88801725, 'CanonicalSMILES': 'CC[N+](CO)(CO)CO.[Cl-]'}],
#  [{'CID': 88801661, 'CanonicalSMILES': 'CC[N+](CC)(C(C)O)C(C)O.[Cl-]'}],
#  [{'CID': 88790435, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Au]'}],
#  [{'CID': 88790431, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Au]'}],
#  [{'CID': 88758365, 'CanonicalSMILES': 'CCN(CC)C[CH-]O.[Na+]'}],
#  [{'CID': 88758024, 'CanonicalSMILES': 'CC(CO)N(C)C.Cl'}],
#  [{'CID': 88757693, 'CanonicalSMILES': 'CC(CO)N(C)C.Cl'}],
#  [{'CID': 88746345, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[NH4+].Cl'}],
#  [{'CID': 88746344, 'CanonicalSMILES': 'C[N+](C)(C)CCO.N.Cl'}],
#  [{'CID': 88745191, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)[PH-].[Cl-].[Ca+2]'}],
#  [{'CID': 88731463, 'CanonicalSMILES': 'C(CO)[N+](CCO)(CCO)[S-]'}],
#  [{'CID': 88728525, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C(#N)S'}],
#  [{'CID': 88709400, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C(CO)O'}],
#  [{'CID': 88690620, 'CanonicalSMILES': 'CCN(CC)CC.CN(CCO)CCO'}],
#  [{'CID': 88689369, 'CanonicalSMILES': 'CC(N(C)C(Cl)(Cl)Cl)O'}],
#  [{'CID': 88665746, 'CanonicalSMILES': 'CCC.CCN(C)C.CCO'}],
#  [{'CID': 88641531, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[ClH2+]'}],
#  [{'CID': 88637628, 'CanonicalSMILES': 'CN(C)CCO.CN(CCO)CCO'}],
#  [{'CID': 88620328, 'CanonicalSMILES': '[Li].CC(N(C(C)O)C(C)O)O'}],
#  [{'CID': 88605277, 'CanonicalSMILES': '[Li].CCN(CC)C(C)O'}],
#  [{'CID': 88603424, 'CanonicalSMILES': 'CO.C(CO)N(CCO)CCO'}],
#  [{'CID': 88510998, 'CanonicalSMILES': 'CCC[N+](CCO)(CCO)CCO.[Cl-]'}],
#  [{'CID': 88510586, 'CanonicalSMILES': 'CC(N(CCl)C(C)O)O'}],
#  [{'CID': 88467480, 'CanonicalSMILES': 'CC(N(C)C(C)O)O.Cl'}],
#  [{'CID': 88461318, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Ca]'}],
#  [{'CID': 88449429, 'CanonicalSMILES': 'CCOCl.CN(CCO)CCO'}],
#  [{'CID': 88449427, 'CanonicalSMILES': 'CCOCl.CC(N(C)C(C)O)O'}],
#  [{'CID': 88431239, 'CanonicalSMILES': 'CC(CO)N(CO)CO.Cl'}],
#  [{'CID': 88431111, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O[O-]'}],
#  [{'CID': 88418050, 'CanonicalSMILES': 'CC([N+](C)(C)CCl)O.[Cl-]'}],
#  [{'CID': 88416182, 'CanonicalSMILES': 'C.C(CO)N(CCO)CCO'}],
#  [{'CID': 88404928, 'CanonicalSMILES': 'CCCCN(C)CCO.Cl.Cl'}],
#  [{'CID': 88401727,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.C(=O)([O-])[O-].C(=O)([O-])[O-]'}],
#  [{'CID': 88396688, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)Cl.Cl'}],
#  [{'CID': 88389476, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Na].[K]'}],
#  [{'CID': 88387731, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cu]'}],
#  [{'CID': 88365386, 'CanonicalSMILES': '[Li].CCN(CC)CCO'}],
#  [{'CID': 88348581, 'CanonicalSMILES': 'CCC[N+](CC)(CC)CCO.[Cl-]'}],
#  [{'CID': 88339649, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Na+].[Cl-]'}],
#  [{'CID': 88317620, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)[P-]C'}],
#  [{'CID': 88290170, 'CanonicalSMILES': 'CCO.C[N+](C)(C)CCO.[OH-]'}],
#  [{'CID': 88243883, 'CanonicalSMILES': 'C[N+](C)(C)CCO.ClCl'}],
#  [{'CID': 88223497, 'CanonicalSMILES': 'CN(C)C.CN(C)CCO'}],
#  [{'CID': 88218666, 'CanonicalSMILES': 'CCN(C)C(CN(C)C)O'}],
#  [{'CID': 88205214, 'CanonicalSMILES': 'CC(CO)[N+](C)(C)CCl'}],
#  [{'CID': 88110721, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O=P(Cl)(Cl)Cl'}],
#  [{'CID': 88104617, 'CanonicalSMILES': 'CC(C)[N+](CCO)(C(C)C)C(C)C.[Cl-]'}],
#  [{'CID': 88087318, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Ca]'}],
#  [{'CID': 88084031, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 87948380, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Ag]'}],
#  [{'CID': 87948379, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Ag]'}],
#  [{'CID': 87910475, 'CanonicalSMILES': 'CN(C)C.C(CO)N(CCO)CCO'}],
#  [{'CID': 87906549, 'CanonicalSMILES': 'COCN(CCO)COC'}],
#  [{'CID': 87906535, 'CanonicalSMILES': 'CC(N(COC)C(C)O)O'}],
#  [{'CID': 87906532, 'CanonicalSMILES': 'CN(CCO)COC'}],
#  [{'CID': 87878564, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[NH4+].[Cl-]'}],
#  [{'CID': 87878560, 'CanonicalSMILES': 'C[N+](C)(C)CCO.N.[Cl-]'}],
#  [{'CID': 87827883, 'CanonicalSMILES': 'CN.C[N+](C)(C)CCO'}],
#  [{'CID': 87633730, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.OCl(=O)(=O)=O.[Ca]'}],
#  [{'CID': 87584963, 'CanonicalSMILES': 'CCN(CC)CCO.N'}],
#  [{'CID': 87574825, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C=O'}],
#  [{'CID': 87574742, 'CanonicalSMILES': 'C[N+](C)(C)CCOCl(=O)=O'}],
#  [{'CID': 87573823, 'CanonicalSMILES': 'C[N+](C)(C)CCOCl(=O)(=O)=O'}],
#  [{'CID': 87559075, 'CanonicalSMILES': 'C[N+](C)(CCO)CCI'}],
#  [{'CID': 87522763, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.Cl.[Ca]'}],
#  [{'CID': 87522762, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.Cl.[Ca]'}],
#  [{'CID': 87507505, 'CanonicalSMILES': 'CC[N+](C)(CCO)CCO.[OH-]'}],
#  [{'CID': 87506840, 'CanonicalSMILES': '[H].CCN(CC)CCO'}],
#  [{'CID': 87506839, 'CanonicalSMILES': '[H+].CCN(CC)CCO'}],
#  [{'CID': 87504301, 'CanonicalSMILES': 'CC[N+](C)(C)C(C)O'}],
#  [{'CID': 87478587, 'CanonicalSMILES': 'CC(CN(C)C)O.Cl'}],
#  [{'CID': 87457088, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O=P(Cl)(Cl)Cl.[Ca+2]'}],
#  [{'CID': 87442202, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[K]'}],
#  [{'CID': 87442201, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[K]'}],
#  [{'CID': 87440432, 'CanonicalSMILES': 'CCN(CC)C(CO)(Cl)Cl'}],
#  [{'CID': 87410002, 'CanonicalSMILES': 'CCO.CN(C)CCO'}],
#  [{'CID': 87359600, 'CanonicalSMILES': 'CCN(CC)C(CO)O.Cl'}],
#  [{'CID': 87359599, 'CanonicalSMILES': 'CCN(CC)CC(O)O.Cl'}],
#  [{'CID': 87349193, 'CanonicalSMILES': 'C.C[N+](C)(C)CCO'}],
#  [{'CID': 87344258, 'CanonicalSMILES': 'CC([N+](C)(C)C)O.OCl(=O)(=O)=O'}],
#  [{'CID': 87344256, 'CanonicalSMILES': 'C[N+](C)(C)CCO.OCl(=O)(=O)=O'}],
#  [{'CID': 87342832, 'CanonicalSMILES': 'CCN(C(C)O)C(C)O.Cl'}],
#  [{'CID': 87328771, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Mg]'}],
#  [{'CID': 87313723, 'CanonicalSMILES': 'C[N+](C)(C)CCOOCO'}],
#  [{'CID': 87313722, 'CanonicalSMILES': 'C[N+](C)(C)CCO.CO.[OH-]'}],
#  [{'CID': 87276333, 'CanonicalSMILES': 'CCN(C)CC(N(C)C)O'}],
#  [{'CID': 87243796, 'CanonicalSMILES': 'CN(CCO)C#N'}],
#  [{'CID': 87229148, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 87229147, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 87222642, 'CanonicalSMILES': 'CN(CCO)CCO.O'}],
#  [{'CID': 87220219, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Na]'}],
#  [{'CID': 87220218, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Na]'}],
#  [{'CID': 87201804, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.OCl(=O)(=O)=O'}],
#  [{'CID': 87191000, 'CanonicalSMILES': 'CC([N+](C)(C(C)O)C(C)O)O.[Cl-]'}],
#  [{'CID': 87185778, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[C-](=O)O'}],
#  [{'CID': 87169779, 'CanonicalSMILES': 'C[N+](C)(C)CC(CF)O.[Cl-]'}],
#  [{'CID': 87151491, 'CanonicalSMILES': 'CCO.C(CO)N(CCO)CCO'}],
#  [{'CID': 87139315, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[N-]=[N+]=[N-]'}],
#  [{'CID': 87134424, 'CanonicalSMILES': 'CC[P-]C(C[N+](C)(C)C)O'}],
#  [{'CID': 87101438, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.[OH-]'}],
#  [{'CID': 87091787, 'CanonicalSMILES': 'C[N+](C)(C)CCO.Cl.Cl'}],
#  [{'CID': 87076506, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO[O-]'}],
#  [{'CID': 87074423, 'CanonicalSMILES': 'CN(C)C(CO)OC'}],
#  [{'CID': 87063851, 'CanonicalSMILES': 'CN(CCO)CC#[N+]C#N'}],
#  [{'CID': 86747029, 'CanonicalSMILES': 'CN(C)CCN(C)CCO.Cl.Cl'}],
#  [{'CID': 86742466, 'CanonicalSMILES': 'CCN(CC)C(C)CO.Cl'}],
#  [{'CID': 86630381, 'CanonicalSMILES': '[H-].CN(C)CCO.[Na+]'}],
#  [{'CID': 86628599, 'CanonicalSMILES': 'C[N+](C)(C)CCO.NO'}],
#  [{'CID': 86591463,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.O.O.O.O.O.O.[Cl-].[Cl-].[Cl-].[Cl-].[Cr+3]'}],
#  [{'CID': 86589564, 'CanonicalSMILES': 'CCO.CN(C)C'}],
#  [{'CID': 86150008, 'CanonicalSMILES': 'CCCC[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 86107154, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O.O.[Cl-]'}],
#  [{'CID': 85990283, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.F'}],
#  [{'CID': 85682556, 'CanonicalSMILES': 'C[N+](C)(CCO)CCl.[Cl-]'}],
#  [{'CID': 85544516, 'CanonicalSMILES': 'CC[N+](CC)(CC)CCO.[F-]'}],
#  [{'CID': 77519168, 'CanonicalSMILES': 'C[N+](C)(CCO)C#P=O.[Cl-].[Ca]'}],
#  [{'CID': 72666542, 'CanonicalSMILES': 'CCN(CCO)CCO.Cl'}],
#  [{'CID': 60128857, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 60113876, 'CanonicalSMILES': 'C[N+](C)(CC[OH2+])CC[OH2+]'}],
#  [{'CID': 60113875, 'CanonicalSMILES': 'C[N+](C)(CC[OH2+])CCO'}],
#  [{'CID': 60098746, 'CanonicalSMILES': 'CCN(C)[CH]C(O)O'}],
#  [{'CID': 60076646, 'CanonicalSMILES': 'C#CN(CCO)CCO'}],
#  [{'CID': 60059701, 'CanonicalSMILES': 'CCN(CCO)CCO.[Ac].[Ac]'}],
#  [{'CID': 60059700, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Ac].[Ac].[Ac]'}],
#  [{'CID': 60059691, 'CanonicalSMILES': 'CN(CCO)CCO.[Ac].[Ac]'}],
#  [{'CID': 60059690, 'CanonicalSMILES': 'CCCN(CCC)CCO.[Ac]'}],
#  [{'CID': 60059689, 'CanonicalSMILES': 'CCCN(CCO)CCO.[Ac].[Ac]'}],
#  [{'CID': 59897350, 'CanonicalSMILES': 'CN([CH])[CH]C(O)O'}],
#  [{'CID': 59824600, 'CanonicalSMILES': 'CC[N+](C)(CC)C(CO)O'}],
#  [{'CID': 59736176, 'CanonicalSMILES': 'CN(CCO)C[CH]O'}],
#  [{'CID': 59736175, 'CanonicalSMILES': 'C(CO)N(CCO)C[CH]O'}],
#  [{'CID': 59502008, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 59502007, 'CanonicalSMILES': 'C[NH+](C)CCO'}],
#  [{'CID': 59301712, 'CanonicalSMILES': 'CC(CN(C)C)O.[Hf]'}],
#  [{'CID': 59270461, 'CanonicalSMILES': 'CN(C[CH])CCO'}],
#  [{'CID': 59266770, 'CanonicalSMILES': 'C[N+](C)(C)CC([CH2-])O'}],
#  [{'CID': 59143868, 'CanonicalSMILES': 'CCN(C)CC(C)O'}],
#  [{'CID': 59143861, 'CanonicalSMILES': 'CCN(C)CC(C)O'}],
#  [{'CID': 59099898, 'CanonicalSMILES': 'C[N-]CCO.[Y]'}],
#  [{'CID': 59095200, 'CanonicalSMILES': 'CCC[N+](C)(CC)CCO'}],
#  [{'CID': 59087635, 'CanonicalSMILES': 'CN(CCO)C#C'}],
#  [{'CID': 59058074, 'CanonicalSMILES': 'CN(CCO)C[N+]#[C-]'}],
#  [{'CID': 59057980, 'CanonicalSMILES': 'CN(C)CC([CH2-])O.[Y]'}],
#  [{'CID': 59037477, 'CanonicalSMILES': 'CC[N+](CCO)(CCO)[O-]'}],
#  [{'CID': 58943013, 'CanonicalSMILES': 'CCO.CN(C)CCO.[Nb]'}],
#  [{'CID': 58943008, 'CanonicalSMILES': 'CN(C)CCO.[Ti]'}],
#  [{'CID': 58942973, 'CanonicalSMILES': 'CCO.CN(C)CCO.[Ta]'}],
#  [{'CID': 58904293, 'CanonicalSMILES': 'CN(C)CCO.CN(C)CCO.[Cu]'}],
#  [{'CID': 58881669, 'CanonicalSMILES': 'CC(CN(C)C)O.[Ti]'}],
#  [{'CID': 58881662, 'CanonicalSMILES': 'CC(CN(C)C)O.[Zr]'}],
#  [{'CID': 58807577, 'CanonicalSMILES': 'CC(C[N+](C)(C)C)[OH2+]'}],
#  [{'CID': 58731643, 'CanonicalSMILES': 'CN([CH])CCO'}],
#  [{'CID': 58636020, 'CanonicalSMILES': 'C[N+](C)(C)CC([CH2+])O'}],
#  [{'CID': 58624109, 'CanonicalSMILES': 'CN(C)CCOOO'}],
#  [{'CID': 58623528, 'CanonicalSMILES': 'CCC[N+](C)([CH])CCO'}],
#  [{'CID': 58619806, 'CanonicalSMILES': 'C(CO)[N-]CCO.[Y]'}],
#  [{'CID': 58612468, 'CanonicalSMILES': 'C[NH+](C)CCO'}],
#  [{'CID': 58602918, 'CanonicalSMILES': 'CN(CCC[CH2-])CCO'}],
#  [{'CID': 58490988, 'CanonicalSMILES': 'CN(C(CO)O)C(CO)O'}],
#  [{'CID': 58104770, 'CanonicalSMILES': 'C(CO)N(C(O)O)C(O)O'}],
#  [{'CID': 57880219, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 57880218, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 57775462, 'CanonicalSMILES': 'CN(CCO)CCO'}],
#  [{'CID': 57694920, 'CanonicalSMILES': 'CCN(CCO)CF'}],
#  [{'CID': 57694919, 'CanonicalSMILES': 'CCN(CCO)CCF'}],
#  [{'CID': 57694918, 'CanonicalSMILES': 'CN(CCCF)CCO'}],
#  [{'CID': 57694916, 'CanonicalSMILES': 'CN(CCO)CF'}],
#  [{'CID': 57589366, 'CanonicalSMILES': 'CCN(C)CCO.[Fe]'}],
#  [{'CID': 57589365, 'CanonicalSMILES': 'CN(C)CCO.[Fe]'}],
#  [{'CID': 57589364, 'CanonicalSMILES': 'CC(CN(C)C)O.[Fe]'}],
#  [{'CID': 57589358, 'CanonicalSMILES': 'CCN(CC)CCO.[Fe]'}],
#  [{'CID': 57585372, 'CanonicalSMILES': 'CCN(C[CH])CCO'}],
#  [{'CID': 57585182, 'CanonicalSMILES': '[CH]CN(CCO)CCO'}],
#  [{'CID': 57568725, 'CanonicalSMILES': 'CN(C)CCO.[Hf]'}],
#  [{'CID': 57541007, 'CanonicalSMILES': '[CH]N(CCO)CCO'}],
#  [{'CID': 57507875, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Cu]'}],
#  [{'CID': 57464381, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Mg]'}],
#  [{'CID': 57449728, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.Cl'}],
#  [{'CID': 57300934, 'CanonicalSMILES': 'CC(N(C1CO1)C(C)O)O'}],
#  [{'CID': 57284186, 'CanonicalSMILES': 'CC(N(CCOC)C(C)O)O'}],
#  [{'CID': 57250236, 'CanonicalSMILES': 'CCN(CC)CC(O)Cl'}],
#  [{'CID': 57235008, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)OO'}],
#  [{'CID': 57200048, 'CanonicalSMILES': 'C[N+](C)(C)CCOI'}],
#  [{'CID': 57187374, 'CanonicalSMILES': 'C[N+](C)(C)CCOOO'}],
#  [{'CID': 57084703, 'CanonicalSMILES': 'CCN(CC)C(CO)O'}],
#  [{'CID': 57081400, 'CanonicalSMILES': 'CC(N(C(C)O)Cl)O'}],
#  [{'CID': 57031094, 'CanonicalSMILES': 'CN(C)C(CO)N(C)C'}],
#  [{'CID': 57027492, 'CanonicalSMILES': 'C[N+](C)(C)CC([N+](C)(C)C)O'}],
#  [{'CID': 54759110, 'CanonicalSMILES': 'C[N+](C)(C)CCOF.[Cl-]'}],
#  [{'CID': 54594038, 'CanonicalSMILES': 'CN(CCO)CC(F)(F)F'}],
#  [{'CID': 54540363, 'CanonicalSMILES': 'CC(N(CO)C(C)O)O'}],
#  [{'CID': 54512402, 'CanonicalSMILES': 'CCN(CCO)CC#CC'}],
#  [{'CID': 54503316, 'CanonicalSMILES': 'CCCN(C)C(C)O'}],
#  [{'CID': 54438112, 'CanonicalSMILES': '[B]C(CN(C)C)O'}],
#  [{'CID': 54342003, 'CanonicalSMILES': 'CC([N+](C)(C)CCl)O'}],
#  [{'CID': 54303922, 'CanonicalSMILES': 'C(CO)[N+](CCO)(CCO)F'}],
#  [{'CID': 54268619, 'CanonicalSMILES': 'CN(C)CC(O)Cl'}],
#  [{'CID': 54253422, 'CanonicalSMILES': 'CCO.C[N+](C)(C)CCO'}],
#  [{'CID': 54167145, 'CanonicalSMILES': 'CN(CCO)C=S'}],
#  [{'CID': 54146804, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 54130009, 'CanonicalSMILES': 'C[N+](C)(CCO)CO'}],
#  [{'CID': 54024516, 'CanonicalSMILES': 'C(CO)[N+](CO)(CO)CO'}],
#  [{'CID': 53906442, 'CanonicalSMILES': 'CC(N1CC1O)O'}],
#  [{'CID': 53789197, 'CanonicalSMILES': 'C[N+](C)(C)C(CO)O'}],
#  [{'CID': 53704975, 'CanonicalSMILES': 'CCOC.CN(CCO)CCO'}],
#  [{'CID': 53652043, 'CanonicalSMILES': 'CN1CC1O'}],
#  [{'CID': 52918392, 'CanonicalSMILES': 'C[N+](C)(CCO)CF'}],
#  [{'CID': 45087581, 'CanonicalSMILES': 'CN(CCO)CCON'}],
#  [{'CID': 44151198, 'CanonicalSMILES': 'C(CO)N(CCO)CC[O-].[Na+]'}],
#  [{'CID': 44147997, 'CanonicalSMILES': 'CC(CN(C)C)O.Cl'}],
#  [{'CID': 25217750, 'CanonicalSMILES': 'CN(CCCF)CCO'}],
#  [{'CID': 25217749, 'CanonicalSMILES': 'CCN(CCO)CCF'}],
#  [{'CID': 25217748, 'CanonicalSMILES': 'CN(CCO)CCF'}],
#  [{'CID': 25217746, 'CanonicalSMILES': 'CCN(CCO)CF'}],
#  [{'CID': 25217745, 'CanonicalSMILES': 'CN(CCO)CF'}],
#  [{'CID': 25217431, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 23700456, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Na+].[Cl-]'}],
#  [{'CID': 23591815, 'CanonicalSMILES': 'C[N+](CCO)(CCO)[O-]'}],
#  [{'CID': 23378680, 'CanonicalSMILES': 'C[NH+]([CH2-])CCO'}],
#  [{'CID': 22975403, 'CanonicalSMILES': 'CC([N+](=C)C)O'}],
#  [{'CID': 22947117,
#    'CanonicalSMILES': 'CN(C[CH2-])CCO.[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y].[Y]'}],
#  [{'CID': 22928238, 'CanonicalSMILES': 'CCN(C)C.CO'}],
#  [{'CID': 22898481, 'CanonicalSMILES': 'CN(C)CCOO'}],
#  [{'CID': 22894427, 'CanonicalSMILES': 'C[NH+](C)CCO.[Cl-]'}],
#  [{'CID': 22731883, 'CanonicalSMILES': 'CC[N+](CC)(CCO)CCO.[OH-]'}],
#  [{'CID': 22731847, 'CanonicalSMILES': 'CC[N+](C)(CC)CCO.[OH-]'}],
#  [{'CID': 22713030, 'CanonicalSMILES': 'C(CO)N(CC#N)CC#N'}],
#  [{'CID': 22675985, 'CanonicalSMILES': 'CC(N(CCO)CCO)OC'}],
#  [{'CID': 22642448, 'CanonicalSMILES': 'CCCN(CCO)C(C)O'}],
#  [{'CID': 22642445, 'CanonicalSMILES': 'CC(CN(C)CO)O'}],
#  [{'CID': 22642442, 'CanonicalSMILES': 'CC(N(C)CCO)O'}],
#  [{'CID': 22642438, 'CanonicalSMILES': 'CC(N(CCO)C(C)O)O'}],
#  [{'CID': 22642431, 'CanonicalSMILES': 'CCCN(CCO)CO'}],
#  [{'CID': 22610626, 'CanonicalSMILES': 'C(CO)N(CCO)CC(O)(O)O'}],
#  [{'CID': 22495100, 'CanonicalSMILES': 'C[N+](C)(C)CCOCl.[Br-]'}],
#  [{'CID': 22476691, 'CanonicalSMILES': 'CC([N+](C)(C)C)O.[OH-]'}],
#  [{'CID': 22436573, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[NH4+].[Cl-]'}],
#  [{'CID': 22326192, 'CanonicalSMILES': 'CC([N+](C)(C)C(C)O)O.[Cl-]'}],
#  [{'CID': 22319922, 'CanonicalSMILES': 'CCN(C)C.CCO'}],
#  [{'CID': 22218487, 'CanonicalSMILES': 'CCN(CCO)C(C)C'}],
#  [{'CID': 22179222, 'CanonicalSMILES': 'C[N+](C)(CCO)CC#N'}],
#  [{'CID': 22179221, 'CanonicalSMILES': 'C[N+](C)(CCO)CC#N.[Cl-]'}],
#  [{'CID': 22179170, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C(=O)([O-])[O-]'}],
#  [{'CID': 22162397, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.[O-2]'}],
#  [{'CID': 22160861, 'CanonicalSMILES': 'CC([N+](C)(C)C(C)O)O.[OH-]'}],
#  [{'CID': 22153990, 'CanonicalSMILES': 'C(CO)[N+](CCO)(CCO)CO'}],
#  [{'CID': 22138611, 'CanonicalSMILES': 'COCN(CCO)CCO'}],
#  [{'CID': 22138602, 'CanonicalSMILES': 'CC(N(COC)COC)O'}],
#  [{'CID': 22104972, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C(=O)([O-])Cl'}],
#  [{'CID': 22035081, 'CanonicalSMILES': 'C[N+](C)(C)CCO.CO'}],
#  [{'CID': 22030569, 'CanonicalSMILES': 'CN(CCO)CCOC'}],
#  [{'CID': 22024138, 'CanonicalSMILES': 'CN(CCO)CO'}],
#  [{'CID': 21928691, 'CanonicalSMILES': 'CN(C)CCON.Cl'}],
#  [{'CID': 21895766, 'CanonicalSMILES': 'CC([N+](C)(C)C)O.[Cl-]'}],
#  [{'CID': 21884707, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO'}],
#  [{'CID': 21831782, 'CanonicalSMILES': 'C(CO)[N+](CCO)(CCO)CCl'}],
#  [{'CID': 21733975, 'CanonicalSMILES': 'CCC[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 21651684, 'CanonicalSMILES': 'CCN(CC)CC.CN(C)CCO'}],
#  [{'CID': 21584112, 'CanonicalSMILES': 'C(CO)[N-]CCO'}],
#  [{'CID': 21559489, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO.[F-]'}],
#  [{'CID': 21559488, 'CanonicalSMILES': 'C[N+](CCO)(CCO)CCO.[F-]'}],
#  [{'CID': 21540773, 'CanonicalSMILES': 'CCCC.C(CO)N(CCO)CCO'}],
#  [{'CID': 21431001, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C[O-]'}],
#  [{'CID': 21257979, 'CanonicalSMILES': 'C[N+](C)(C)CC[OH2+]'}],
#  [{'CID': 21192048, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Cl-]'}],
#  [{'CID': 21116090, 'CanonicalSMILES': 'CCOCC.C[N+](C)(C)CCO'}],
#  [{'CID': 20977727, 'CanonicalSMILES': 'C.C[N+](C)(C)CCO'}],
#  [{'CID': 20750796, 'CanonicalSMILES': 'CCN(C)CO'}],
#  [{'CID': 20741933, 'CanonicalSMILES': 'CCN(C)CC(O)O'}],
#  [{'CID': 20696631, 'CanonicalSMILES': 'CCN(CCO)CCOC'}],
#  [{'CID': 20593616, 'CanonicalSMILES': '[CH3-].CC(CN(C)[CH2-])O.[W+2]'}],
#  [{'CID': 20536855, 'CanonicalSMILES': 'CC(N(CO)CO)O'}],
#  [{'CID': 20480699, 'CanonicalSMILES': 'C(CO)N(CCO)CCl'}],
#  [{'CID': 20278489, 'CanonicalSMILES': 'CCN(CC)CC.C(CO)N(CCO)CCO'}],
#  [{'CID': 20195019, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O'}],
#  [{'CID': 20063188, 'CanonicalSMILES': 'CN(C)N(C)CCO'}],
#  [{'CID': 19934175, 'CanonicalSMILES': 'C[N+](C)(C)CCO.Cl.[Cl-]'}],
#  [{'CID': 19844489, 'CanonicalSMILES': 'C[N+](C)(C)CCO.Cl'}],
#  [{'CID': 19844483, 'CanonicalSMILES': 'CCC([N+](C)(C)C)O.Cl'}],
#  [{'CID': 19817460, 'CanonicalSMILES': 'C[N+](C)(C)CCOCl.Cl'}],
#  [{'CID': 19708476, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Ca+2]'}],
#  [{'CID': 19429958, 'CanonicalSMILES': 'C(CO)N(CO)CO.Cl'}],
#  [{'CID': 19076065, 'CanonicalSMILES': 'CCN(CC)CCO.CN(C)CCO'}],
#  [{'CID': 19044127, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C(CO)O.[Cl-]'}],
#  [{'CID': 19031249, 'CanonicalSMILES': 'CC(N(CCO)CCO)O'}],
#  [{'CID': 18990765, 'CanonicalSMILES': 'CC(N(C)C(C)OC)O'}],
#  [{'CID': 18941644, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)Cl.[Br-]'}],
#  [{'CID': 18786263, 'CanonicalSMILES': 'CCN(CC)CC(O)O'}],
#  [{'CID': 18715985, 'CanonicalSMILES': 'CC[N+](C)(C)CO'}],
#  [{'CID': 18637976, 'CanonicalSMILES': 'CC(C[N+](C)(C)C)O.[Cl-]'}],
#  [{'CID': 18637975, 'CanonicalSMILES': 'CC(C[N+](C)(C)C)O.[Cl-]'}],
#  [{'CID': 18620316, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-](Br)Br'}],
#  [{'CID': 18515395, 'CanonicalSMILES': 'CC[N+](CC)(CC)C(C)O'}],
#  [{'CID': 18475202, 'CanonicalSMILES': 'CN(C)CCO.CN(C)CCO'}],
#  [{'CID': 18469782, 'CanonicalSMILES': 'C[N+](C)(C)C.C[N+](C)(C)CCO.[OH-]'}],
#  [{'CID': 18415679, 'CanonicalSMILES': 'CC([N+](C)(C)C)O'}],
#  [{'CID': 17983236, 'CanonicalSMILES': '[B-](F)(F)(F)F.C[N+](C)(C)CCO'}],
#  [{'CID': 16217620, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 16213402, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 16206407, 'CanonicalSMILES': 'C[N+]1(CC1)CCO.[Cl-]'}],
#  [{'CID': 15894841, 'CanonicalSMILES': 'CCN(C)C(C)O'}],
#  [{'CID': 15594924, 'CanonicalSMILES': 'CC[N+](C)(C)CCO.[OH-]'}],
#  [{'CID': 15560809, 'CanonicalSMILES': 'CCN(CC)C(C)CO.Cl'}],
#  [{'CID': 14859576, 'CanonicalSMILES': 'CC(C[N+](C)(C)CCl)O'}],
#  [{'CID': 14859574, 'CanonicalSMILES': 'C[N+](C)(CCO)CI'}],
#  [{'CID': 14859572, 'CanonicalSMILES': 'C[N+](C)(CCO)CBr'}],
#  [{'CID': 14859570, 'CanonicalSMILES': 'C[N+](C)(CCO)CCl'}],
#  [{'CID': 14767686, 'CanonicalSMILES': 'CC[N+](CCO)(CCO)CCO.[OH-]'}],
#  [{'CID': 14767683, 'CanonicalSMILES': 'CC[N+](CCO)(CCO)CCO.[Cl-]'}],
#  [{'CID': 14068066, 'CanonicalSMILES': 'C[N+](CCO)(CCO)CCO.[I-]'}],
#  [{'CID': 13561414, 'CanonicalSMILES': 'CN(C)CC(N(C)C)O'}],
#  [{'CID': 13076198, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)Cl.[Cl-]'}],
#  [{'CID': 12935600, 'CanonicalSMILES': 'CN(C)CC[O-]'}],
#  [{'CID': 11715487, 'CanonicalSMILES': 'C[N+](C)(CCO)CCF.[Br-]'}],
#  [{'CID': 3495049, 'CanonicalSMILES': 'CN(C)CC[OH2+]'}],
#  [{'CID': 3024029, 'CanonicalSMILES': 'CC[N+](CC)(CCO)CCO'}],
#  [{'CID': 3021050, 'CanonicalSMILES': 'CC(C)([N+](C)(C)CCO)O.[Cl-]'}],
#  [{'CID': 533458, 'CanonicalSMILES': 'CC[N+](CC)(CCO)[O-]'}],
#  [{'CID': 449690, 'CanonicalSMILES': 'CC[N+](C)(CCO)CF'}],
#  [{'CID': 449672, 'CanonicalSMILES': 'C[N+](C)(CCO)CF.[Br-]'}],
#  [{'CID': 437079, 'CanonicalSMILES': 'C[N+](C)(CCO)CCBr'}],
#  [{'CID': 341625, 'CanonicalSMILES': 'CN(C)CCO.CCl'}],
#  [{'CID': 231183, 'CanonicalSMILES': 'CCCN(C)CCO'}],
#  [{'CID': 169358, 'CanonicalSMILES': 'CC[N+](CCO)(CCO)CCO'}],
#  [{'CID': 57053, 'CanonicalSMILES': 'CCC[N+](CCC)(CCC)CCO'}],
#  [{'CID': 46082, 'CanonicalSMILES': 'CC[N+](C)(CCO)CCO'}],
#  [{'CID': 145827108,
#    'CanonicalSMILES': 'C[N+](C)(CCO)CCO.[Cl-].Cl[Fe](Cl)Cl'}],
#  [{'CID': 145704499, 'CanonicalSMILES': 'CC.CCN(CC)CCO'}],
#  [{'CID': 145343686, 'CanonicalSMILES': 'CC.CC.CCN(CC)CCO'}],
#  [{'CID': 144952838, 'CanonicalSMILES': 'CC.CC.CN(C)CCO'}],
#  [{'CID': 144712467, 'CanonicalSMILES': 'CC[N-]CCO.[K+]'}],
#  [{'CID': 144712465, 'CanonicalSMILES': 'C(CO)[N-]CCO.[K+]'}],
#  [{'CID': 144422886, 'CanonicalSMILES': 'CN(CCO)CCOO'}],
#  [{'CID': 144420319, 'CanonicalSMILES': 'CC.CCN(CCO)S'}],
#  [{'CID': 144264435, 'CanonicalSMILES': 'CC(C)(N(CCO)CO)O'}],
#  [{'CID': 144164719, 'CanonicalSMILES': 'CN(C)CCOC.CO'}],
#  [{'CID': 143984626, 'CanonicalSMILES': 'CCN(C)CCOCl'}],
#  [{'CID': 143928144, 'CanonicalSMILES': 'CCC.CN(C)CCO'}],
#  [{'CID': 143920238, 'CanonicalSMILES': 'C[N+](C)(C)CCO.CCl'}],
#  [{'CID': 143831413, 'CanonicalSMILES': 'CC.CN(CCO)CCO'}],
#  [{'CID': 143817148, 'CanonicalSMILES': 'CC.CCN(C)C.CCO'}],
#  [{'CID': 143745355, 'CanonicalSMILES': 'CC(C)C.CN(C)CCO'}],
#  [{'CID': 143627570, 'CanonicalSMILES': 'CC.CC.CCN(C)CCO'}],
#  [{'CID': 143545939, 'CanonicalSMILES': 'CC.CCCN(C)CCO'}],
#  [{'CID': 143284641, 'CanonicalSMILES': 'CCN(CCOC)C(C)O'}],
#  [{'CID': 142906870, 'CanonicalSMILES': 'CCC.CCN(CC)CCO'}],
#  [{'CID': 142878322, 'CanonicalSMILES': 'CCN(C)CCOC.CO'}],
#  [{'CID': 142839761, 'CanonicalSMILES': 'CCC.CN(CCO)CCO'}],
#  [{'CID': 142832552, 'CanonicalSMILES': 'CCN(CC)CCO.CN(C)C'}],
#  [{'CID': 142808892, 'CanonicalSMILES': 'CN(C)CCO.[V]'}],
#  [{'CID': 142657647, 'CanonicalSMILES': 'CCN(CC)CCOCl(=O)=O'}],
#  [{'CID': 142330277, 'CanonicalSMILES': 'CC.CC(CN(C)C)O'}],
#  [{'CID': 142227112, 'CanonicalSMILES': 'CC.CCCN(CCC)CCO'}],
#  [{'CID': 142187241, 'CanonicalSMILES': 'CC.CCCN(CC)CCO'}],
#  [{'CID': 142083676, 'CanonicalSMILES': 'CCN(C)CCO.CO'}],
#  [{'CID': 141921051, 'CanonicalSMILES': 'CC.CCN(C)CCO'}],
#  [{'CID': 141909879, 'CanonicalSMILES': 'CC.C(CO)N(CCO)CCO'}],
#  [{'CID': 141710393, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO.O.[OH-]'}],
#  [{'CID': 141653220, 'CanonicalSMILES': 'CCCN(CCO)CF'}],
#  [{'CID': 141557823, 'CanonicalSMILES': 'C[N+](C)(CCO)S.[O-]Cl(=O)(=O)=O'}],
#  [{'CID': 141518389, 'CanonicalSMILES': 'CCC(N(C)C)O'}],
#  [{'CID': 141513232, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[OH-].[Na+].[Cl-]'}],
#  [{'CID': 141475901,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.OS(=O)[O-].[Na+].[Cl-]'}],
#  [{'CID': 141438503, 'CanonicalSMILES': 'C(CO)N(CCO)C(CO)F'}],
#  [{'CID': 141421006, 'CanonicalSMILES': 'CC[N+](C)(C)C(C)O.[Cl-]'}],
#  [{'CID': 141408715,
#    'CanonicalSMILES': 'CC[O-].CC[O-].C[N+](C)(C)CCO.[NH4+]'}],
#  [{'CID': 141334456,
#    'CanonicalSMILES': '[H-].[H-].C[N+](C)(C)CCO.C[N+](C)(C)CCO'}],
#  [{'CID': 141334454, 'CanonicalSMILES': '[H-].C[N+](C)(C)CCO'}],
#  [{'CID': 141324998, 'CanonicalSMILES': 'CC(C[N+](C)(C)CO)O.[Cl-]'}],
#  [{'CID': 141306718, 'CanonicalSMILES': 'C[NH+](C)CCO.O.[Cl-]'}],
#  [{'CID': 141219477, 'CanonicalSMILES': 'CCN(CCO)C(C)F'}],
#  [{'CID': 141147544, 'CanonicalSMILES': 'CC([N+](C)(C)CCO)O.[Cl-]'}],
#  [{'CID': 141128723, 'CanonicalSMILES': 'CCC(N(C)C)O.Cl'}],
#  [{'CID': 141111618, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O.[OH-]'}],
#  [{'CID': 141018119, 'CanonicalSMILES': 'CCN(CC)C(C)O.O'}],
#  [{'CID': 140891773, 'CanonicalSMILES': 'CC(CO)N(C)C'}],
#  [{'CID': 140889054, 'CanonicalSMILES': 'C(CO)N(CC[O-])CC[O-]'}],
#  [{'CID': 140791758, 'CanonicalSMILES': 'CN(CCO)C(=S)[S-]'}],
#  [{'CID': 140611654, 'CanonicalSMILES': 'C[N+]([CH2-])(CCO)CF'}],
#  [{'CID': 140611653, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 140611652, 'CanonicalSMILES': 'C[N+]([CH2-])(CCO)CF'}],
#  [{'CID': 140608904, 'CanonicalSMILES': 'C[N+](C)(C)CCO.F[P-](F)(F)(F)(F)F'}],
#  [{'CID': 140568452, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O.[I-]'}],
#  [{'CID': 140534492, 'CanonicalSMILES': 'CCOCCN(CO)CO'}],
#  [{'CID': 140534486, 'CanonicalSMILES': 'COCCN(CO)CO'}],
#  [{'CID': 140471399, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O.O.O.O.O.O.[Cl-]'}],
#  [{'CID': 140448732, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[NH4+].[Cl-].[Cl-]'}],
#  [{'CID': 140326669, 'CanonicalSMILES': 'C[N+](C)(CCO)[O-].O'}],
#  [{'CID': 140309563, 'CanonicalSMILES': 'CCC[N+](C)(CCO)CCO.[Cl-]'}],
#  [{'CID': 140301634, 'CanonicalSMILES': '[H-].C[N+](CCO)(CCO)CCO'}],
#  [{'CID': 140156275, 'CanonicalSMILES': 'CC(N(C)C#N)O'}],
#  [{'CID': 140091824,
#    'CanonicalSMILES': '[H-].[H-].C[N+](C)(C)CCO.C[N+](C)(C)CCO'}],
#  [{'CID': 140031939, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)O.[OH-]'}],
#  [{'CID': 139833234, 'CanonicalSMILES': 'CCN(CC)C(CO)Cl'}],
#  [{'CID': 139791198, 'CanonicalSMILES': 'CC[N+](CC)(CC)CCO.O.[OH-]'}],
#  [{'CID': 139790503, 'CanonicalSMILES': 'CC[N+](CC)(CCO)CCO.[Br-]'}],
#  [{'CID': 139783383, 'CanonicalSMILES': 'CN(C)CCOCl'}],
#  [{'CID': 139783382, 'CanonicalSMILES': 'CN(C)CCOCl.Cl'}],
#  [{'CID': 139760971, 'CanonicalSMILES': 'CCN(CCO)CCO.O'}],
#  [{'CID': 139712768, 'CanonicalSMILES': 'C[N+](C)(CCO)CCF.[OH-]'}],
#  [{'CID': 139712767, 'CanonicalSMILES': 'C[N+](C)(CCCF)CCO.[Cl-]'}],
#  [{'CID': 139611281, 'CanonicalSMILES': 'CN(CCO)F'}],
#  [{'CID': 139610701, 'CanonicalSMILES': 'CCCC[N+](C)(CC)CCO.[Cl-]'}],
#  [{'CID': 139509280, 'CanonicalSMILES': 'CCC.C[N+](C)(C)CCO'}],
#  [{'CID': 139267709, 'CanonicalSMILES': 'C[NH+](C)CCO.[O-]Cl=O'}],
#  [{'CID': 137501721, 'CanonicalSMILES': 'CN(C)C.C[N+](C)(C)CCO'}],
#  [{'CID': 135019738, 'CanonicalSMILES': 'CN(C)CCO.CN(C)CCO.[Pd]'}],
#  [{'CID': 134564081, 'CanonicalSMILES': 'CC[N+](C)(C)CCO.[F-]'}],
#  [{'CID': 134211469, 'CanonicalSMILES': 'CC[N+](CC)(CC)CC.CCO'}],
#  [{'CID': 132168405, 'CanonicalSMILES': 'CCC[N+](C)(C)C.C[N+](C)(C)CCO'}],
#  [{'CID': 130122212, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)O.[Cl-]'}],
#  [{'CID': 129891280, 'CanonicalSMILES': 'C[N+](C)(C)C(CO)Cl.[OH-]'}],
#  [{'CID': 129887588, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 129801692, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O.Cl.[Cl-]'}],
#  [{'CID': 129774845, 'CanonicalSMILES': 'C[N+](C)(CCO)C(=C)O.[Cl-]'}],
#  [{'CID': 129762915,
#    'CanonicalSMILES': 'C[N+](C)(C)C.C[N+](C)(C)CCO.[I-].[I-]'}],
#  [{'CID': 129718487, 'CanonicalSMILES': 'C[N+](C)(C)CC#CCO.[Cl-]'}],
#  [{'CID': 129715221, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Na+].[Cl-].[Br-]'}],
#  [{'CID': 129671161, 'CanonicalSMILES': '[Li+].C[N+](C)(C)CCO.[Cl-].[Cl-]'}],
#  [{'CID': 129655466,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.[Cl-].[I-]'}],
#  [{'CID': 129646313, 'CanonicalSMILES': 'CN(C)CCO.[Hg]'}],
#  [{'CID': 129216226, 'CanonicalSMILES': 'CN(C)CCO.O'}],
#  [{'CID': 123530291, 'CanonicalSMILES': 'C[N+](CCO)(CCO)O'}],
#  [{'CID': 123228641, 'CanonicalSMILES': '[B](C)[N+](C)(C)CCO'}],
#  [{'CID': 122590168, 'CanonicalSMILES': 'CCCl.C[N+](C)(C)CCO'}],
#  [{'CID': 122583488, 'CanonicalSMILES': 'CCO.CC(N(C)C)O'}],
#  [{'CID': 122378022, 'CanonicalSMILES': 'B(O)(O)OCCN(C)C'}],
#  [{'CID': 118882126, 'CanonicalSMILES': 'CN(CCO)CCl'}],
#  [{'CID': 118399074, 'CanonicalSMILES': 'CCCN(CCO)CI'}],
#  [{'CID': 118174731, 'CanonicalSMILES': 'CN(C)CCO.[Au]'}],
#  [{'CID': 118050406, 'CanonicalSMILES': 'CN(C)CCO.C(CO)O'}],
#  [{'CID': 117951351, 'CanonicalSMILES': 'CCN(CCO)CCI'}],
#  [{'CID': 101259933, 'CanonicalSMILES': 'C(CO)N(CCO)[CH]CO'}],
#  [{'CID': 92043528, 'CanonicalSMILES': 'C(CO)N(CCO)CCO'}],
#  [{'CID': 91257082, 'CanonicalSMILES': 'CN(CCO)C[P+]#C'}],
#  [{'CID': 90713801, 'CanonicalSMILES': 'CC.C[N+](C)(C)CCO'}],
#  [{'CID': 90707867, 'CanonicalSMILES': '[B]CCN(C)CCO'}],
#  [{'CID': 89678544, 'CanonicalSMILES': 'C[N+](C)(CCO)CF'}],
#  [{'CID': 89467522, 'CanonicalSMILES': 'CN(CCO)CCI'}],
#  [{'CID': 89354013, 'CanonicalSMILES': 'CCN(C)C(CO)O'}],
#  [{'CID': 89240754, 'CanonicalSMILES': 'CCN(CCOC)CO'}],
#  [{'CID': 89239746, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cu]'}],
#  [{'CID': 89239745, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cu+2]'}],
#  [{'CID': 89078151, 'CanonicalSMILES': 'CN(CCO)CI'}],
#  [{'CID': 89050114, 'CanonicalSMILES': 'C(CO)N(CP)CP'}],
#  [{'CID': 89024702, 'CanonicalSMILES': 'CN(C)CCOS'}],
#  [{'CID': 89001860, 'CanonicalSMILES': 'CCOCN(C)CCO'}],
#  [{'CID': 88786193, 'CanonicalSMILES': '[Li+].CC(N(C(C)O)C(C)O)O'}],
#  [{'CID': 88712059, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO.[OH-].[OH-]'}],
#  [{'CID': 88711389, 'CanonicalSMILES': 'C[N+](CCO)(CCO)CCO.[OH-].[OH-]'}],
#  [{'CID': 88634860, 'CanonicalSMILES': 'CCCC.C[N+](C)(C)CCO'}],
#  [{'CID': 88363626, 'CanonicalSMILES': 'CCN(CCO)I'}],
#  [{'CID': 88314424, 'CanonicalSMILES': 'C[N+](C)(C)CCO.CO.[Cl-]'}],
#  [{'CID': 88314322, 'CanonicalSMILES': 'CCO.CCO.C(CO)N(CCO)CCO'}],
#  [{'CID': 88256137, 'CanonicalSMILES': 'CCN(CC)CCO.CC(N(C)C)O'}],
#  [{'CID': 88236306,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.C[N+](C)(C)CCO'}],
#  [{'CID': 88164568, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Na].[Mg]'}],
#  [{'CID': 88087316, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Ca]'}],
#  [{'CID': 88084032, 'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.Cl'}],
#  [{'CID': 87853997, 'CanonicalSMILES': 'C[N+](C)(CCO)O'}],
#  [{'CID': 87796396, 'CanonicalSMILES': 'CCOOOCC.CN(C)CCO'}],
#  [{'CID': 87755574, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Ca]'}],
#  [{'CID': 87755573, 'CanonicalSMILES': 'C[N+](C)(C)CCO.Cl.[Ca]'}],
#  [{'CID': 87722408, 'CanonicalSMILES': 'C(CO)N(CCO)CCO'}],
#  [{'CID': 87696212, 'CanonicalSMILES': 'CCC(N(C)C)O'}],
#  [{'CID': 87696105, 'CanonicalSMILES': 'CCC(N(C)C)O'}],
#  [{'CID': 87550070, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Zn]'}],
#  [{'CID': 87550069, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Zn]'}],
#  [{'CID': 87375844, 'CanonicalSMILES': 'CC(CO)N(CO)CO'}],
#  [{'CID': 87261656, 'CanonicalSMILES': 'CC(CN(C)C)O.Cl.Cl'}],
#  [{'CID': 87252024, 'CanonicalSMILES': 'CC([N+](C)(C)C)O.[Br-]'}],
#  [{'CID': 87251728, 'CanonicalSMILES': 'CCC[N+](C)(C)C(C)O.[Cl-]'}],
#  [{'CID': 87195970,
#    'CanonicalSMILES': 'C(CO)N(CCO)CCO.[O-]Cl(=O)(=O)=O.[Na+]'}],
#  [{'CID': 87171077, 'CanonicalSMILES': 'CN(C)CCOI'}],
#  [{'CID': 86567707, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O[Se](=O)(=O)[O-]'}],
#  [{'CID': 85808914, 'CanonicalSMILES': 'CN(CCO)CCO.F'}],
#  [{'CID': 78184571, 'CanonicalSMILES': 'C[N+](C)(CCO)CF.[Br-]'}],
#  [{'CID': 74764746, 'CanonicalSMILES': '[H+].C(CO)N(CCO)CCO.[Cl-]'}],
#  [{'CID': 73049788, 'CanonicalSMILES': 'CC[N+](C)(CCO)CF'}],
#  [{'CID': 71379425, 'CanonicalSMILES': 'CCCOC[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 71361175, 'CanonicalSMILES': 'CCC[N+](C)(C)CCO.[I-]'}],
#  [{'CID': 71348402, 'CanonicalSMILES': 'CN(C)CC[Se]CCO'}],
#  [{'CID': 71337751, 'CanonicalSMILES': 'CC[N+](CCO)(CCO)CCO.[I-]'}],
#  [{'CID': 71316603, 'CanonicalSMILES': 'CC[N+](C)(CCO)CCO.[Br-]'}],
#  [{'CID': 59112422, 'CanonicalSMILES': 'CC[N+](C)([CH])CCO'}],
#  [{'CID': 59092796, 'CanonicalSMILES': 'CC[N+](C)(CCO)[O-]'}],
#  [{'CID': 56953094, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 56947341, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 56625880, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 55221478, 'CanonicalSMILES': 'C[N+](C)(CCO)N.[Cl-]'}],
#  [{'CID': 54146806, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 53431124, 'CanonicalSMILES': 'C(CO)[N+](CCO)CCO'}],
#  [{'CID': 50987136, 'CanonicalSMILES': '[H+].C(CO)N(CCO)CCO.[I-]'}],
#  [{'CID': 24833432, 'CanonicalSMILES': 'CC(CO)[N+](C)(C)C.[Cl-]'}],
#  [{'CID': 24195977, 'CanonicalSMILES': 'C[N+]1(CC1)CCO.[I-]'}],
#  [{'CID': 24186631, 'CanonicalSMILES': 'CN(C)CC#CCO.Cl'}],
#  [{'CID': 23711245, 'CanonicalSMILES': 'CN(C)CC[O-].[K+]'}],
#  [{'CID': 23617865, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)Br'}],
#  [{'CID': 22987540, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)F'}],
#  [{'CID': 22340839, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Ca+2]'}],
#  [{'CID': 22116670, 'CanonicalSMILES': '[H+].C[N+](C)(C)CCO.C(=O)([O-])[O-]'}],
#  [{'CID': 22024137, 'CanonicalSMILES': 'CCN(CCO)CO'}],
#  [{'CID': 21864254, 'CanonicalSMILES': '[B-].C[N+](C)(C)CCO'}],
#  [{'CID': 21617572, 'CanonicalSMILES': 'CCN(CCO)F'}],
#  [{'CID': 20976112, 'CanonicalSMILES': 'C[N+](C)(C)CCOS'}],
#  [{'CID': 19086655, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[OH-].[Na+].Cl'}],
#  [{'CID': 19009862, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)O.[I-]'}],
#  [{'CID': 18784220, 'CanonicalSMILES': 'CN(C)CCCO.Cl'}],
#  [{'CID': 18000428, 'CanonicalSMILES': 'CN(CCO)CS'}],
#  [{'CID': 17914440, 'CanonicalSMILES': 'CC[NH+](C)CCO.[Cl-]'}],
#  [{'CID': 17866995,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.C[N+](C)(C)CCO.[OH-].[OH-]'}],
#  [{'CID': 16736294, 'CanonicalSMILES': 'C[N+](C)(CCO)OC'}],
#  [{'CID': 15646780, 'CanonicalSMILES': 'C[N+](C)(C)C1CO1.[Cl-]'}],
#  [{'CID': 14842936, 'CanonicalSMILES': 'CN(C)C(CO)O'}],
#  [{'CID': 12388299, 'CanonicalSMILES': 'CC(CN(C)C)O.Br'}],
#  [{'CID': 12234297, 'CanonicalSMILES': 'CCN(CC)CCO.O'}],
#  [{'CID': 12234295, 'CanonicalSMILES': 'CCN(CC)CCO.Br'}],
#  [{'CID': 11953667,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].Cl[Zn]Cl.Cl[Zn]Cl'}],
#  [{'CID': 11521067, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 10654172, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 10331483, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O[Se](=O)[O-]'}],
#  [{'CID': 10130138, 'CanonicalSMILES': 'C(CO)N(CCO)C(O)(O)O'}],
#  [{'CID': 6420899, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 5490260, 'CanonicalSMILES': 'C[N+](C)(C)CC[O]'}],
#  [{'CID': 522265, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 31675, 'CanonicalSMILES': 'C[N+](C)(CCO)CCCl'}],
#  [{'CID': 103176, 'CanonicalSMILES': 'CN(C)CCOS(=O)Cl'}],
#  [{'CID': 546871, 'CanonicalSMILES': 'C[N+](C)(C)CCO.Br'}],
#  [{'CID': 588330, 'CanonicalSMILES': 'C[N+](C)(C)CCO.I'}],
#  [{'CID': 3795141, 'CanonicalSMILES': 'CCN(CC)CC[OH2+]'}],
#  [{'CID': 6365652, 'CanonicalSMILES': '[B-].C(CO)N(CCO)CCO'}],
#  [{'CID': 6918501, 'CanonicalSMILES': 'C[N+](C)(C)CC#CCO'}],
#  [{'CID': 7568412, 'CanonicalSMILES': 'CCN(CC)C(C)O'}],
#  [{'CID': 7568414, 'CanonicalSMILES': 'CCN(CC)C(C)O'}],
#  [{'CID': 9877448, 'CanonicalSMILES': 'C[N+](C)(CCO)CF.[Cl-]'}],
#  [{'CID': 9877449, 'CanonicalSMILES': 'C[N+](C)(CCO)CF'}],
#  [{'CID': 9920403, 'CanonicalSMILES': 'CC(CN(C)C)O.[Cl-]'}],
#  [{'CID': 10011870, 'CanonicalSMILES': 'CN(CCO)CC#N'}],
#  [{'CID': 10388357, 'CanonicalSMILES': 'CC(CO)[N+](C)(C)C'}],
#  [{'CID': 10406765,
#    'CanonicalSMILES': 'C[N+](C)(C)CC[O-].[Cl-].[Cl-].[Pt+2]'}],
#  [{'CID': 10410808, 'CanonicalSMILES': 'CC(CO)[N+](C)(C)C'}],
#  [{'CID': 10884620, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 10889710, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[I-]'}],
#  [{'CID': 11276335, 'CanonicalSMILES': 'CN(C)CCO.C[In]C'}],
#  [{'CID': 11535688, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-]S(=O)[O-]'}],
#  [{'CID': 11672661, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 12234286, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 12600551, 'CanonicalSMILES': 'CC[N+](CC)(CCO)COC'}],
#  [{'CID': 12845641, 'CanonicalSMILES': 'CN(CCO)C[Si](C)(C)C'}],
#  [{'CID': 13335704, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 13335705, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 13335706, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 13335707, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 14693726, 'CanonicalSMILES': 'C(CO)[N]CCO'}],
#  [{'CID': 16213401, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 16747911, 'CanonicalSMILES': 'C[N+](C)(C)CCO.OP([O-])[O-].Cl[Zn+]'}],
#  [{'CID': 17799412, 'CanonicalSMILES': 'CCN(C)C.CN(C)CCO'}],
#  [{'CID': 18006679, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Cl-]'}],
#  [{'CID': 18406425, 'CanonicalSMILES': 'C[N+](C)(C)CCO.I[I-]I'}],
#  [{'CID': 18503025, 'CanonicalSMILES': 'C(CO)N(CCO)[Ge]'}],
#  [{'CID': 18620284, 'CanonicalSMILES': 'C(CO)N(CCO)I'}],
#  [{'CID': 18764596, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Cl-].[Ca+2]'}],
#  [{'CID': 18913885, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[NH4+].[OH-]'}],
#  [{'CID': 18952570, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Cu+2]'}],
#  [{'CID': 19021209, 'CanonicalSMILES': 'CC(C[N+](C)(C)C)O.[Cl-].[Cl-]'}],
#  [{'CID': 19024390, 'CanonicalSMILES': '[B].CN(C)CCO'}],
#  [{'CID': 19429914, 'CanonicalSMILES': 'CN(CCO)CCO.N'}],
#  [{'CID': 19607191, 'CanonicalSMILES': 'C[N+](C)(C)CCOBr.[Cl-]'}],
#  [{'CID': 19747446, 'CanonicalSMILES': '[Li+].CCN(CC)CCO'}],
#  [{'CID': 20077284, 'CanonicalSMILES': '[H+].C[N+](C)(C)CCO'}],
#  [{'CID': 20078828, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Cd+2]'}],
#  [{'CID': 20083758, 'CanonicalSMILES': 'CN(C)C(CO)Cl'}],
#  [{'CID': 20227568, 'CanonicalSMILES': 'CCN(CC)CC.C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 20294357, 'CanonicalSMILES': 'CN(C)C[CH-]O'}],
#  [{'CID': 20294360, 'CanonicalSMILES': 'CCN(CC)C[CH-]O'}],
#  [{'CID': 20322675, 'CanonicalSMILES': 'C[N+](C)(C)CCO.N'}],
#  [{'CID': 20325397, 'CanonicalSMILES': 'CCN1CC1O'}],
#  [{'CID': 20371883, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Mg+2]'}],
#  [{'CID': 20496398, 'CanonicalSMILES': 'CC(N(C)C)O.[Na+]'}],
#  [{'CID': 20523476, 'CanonicalSMILES': '[H+].[H+].C[N+](C)(C)CCO'}],
#  [{'CID': 20562421, 'CanonicalSMILES': 'CCO.C[N+](C)(C)C.[Cl-]'}],
#  [{'CID': 20567980, 'CanonicalSMILES': 'CN(C)CCO.N'}],
#  [{'CID': 20975785, 'CanonicalSMILES': 'C[N+](C)(C)CCO.COC.[I-]'}],
#  [{'CID': 20976111, 'CanonicalSMILES': 'C[N+](C)(C)CCOS.[Cl-]'}],
#  [{'CID': 21026562, 'CanonicalSMILES': 'C(CO)[N-]CCO.[Y+3]'}],
#  [{'CID': 21115702, 'CanonicalSMILES': 'CCOCC.C[N+](C)(C)CCO.Cl'}],
#  [{'CID': 21119700, 'CanonicalSMILES': 'C[N+](C)(C)CCO.COC'}],
#  [{'CID': 21119701, 'CanonicalSMILES': 'C[N+](C)(C)CCO.COC.Cl'}],
#  [{'CID': 21120357, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[PH4+]'}],
#  [{'CID': 21120667, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Se+]'}],
#  [{'CID': 21126478, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Sb+3]'}],
#  [{'CID': 21245438, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Al+3]'}],
#  [{'CID': 21321798, 'CanonicalSMILES': 'C[N+](C)(C)CCO.N.[Na+].[K+]'}],
#  [{'CID': 21363168, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)F'}],
#  [{'CID': 21363169, 'CanonicalSMILES': 'C[N-]CCO.[Y+3]'}],
#  [{'CID': 21422585, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Zn+2]'}],
#  [{'CID': 21977382, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Ti+2]'}],
#  [{'CID': 21997723, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Na+]'}],
#  [{'CID': 22179171, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-]S(=O)(=O)[O-]'}],
#  [{'CID': 22257321, 'CanonicalSMILES': 'C[N+](C)(C)CCO.P'}],
#  [{'CID': 22447444, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Na+]'}],
#  [{'CID': 22590735, 'CanonicalSMILES': 'CCN(CC)CC[O-]'}],
#  [{'CID': 22595215, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Mg+2]'}],
#  [{'CID': 22634755, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Fe+3]'}],
#  [{'CID': 22642428, 'CanonicalSMILES': 'CC(CN(CO)CO)O'}],
#  [{'CID': 22662522, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[K+]'}],
#  [{'CID': 22688893, 'CanonicalSMILES': 'CCN(CCO)CC#N'}],
#  [{'CID': 22711551, 'CanonicalSMILES': 'CN(C)CCCO.[Cl-]'}],
#  [{'CID': 22763439, 'CanonicalSMILES': 'CCC[N+](CCC)(CCO)CCO.[Cl-]'}],
#  [{'CID': 23036016, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[OH-]'}],
#  [{'CID': 23048546, 'CanonicalSMILES': 'B(=O)[O-].CC([N+](C)(C)C)O'}],
#  [{'CID': 23048564, 'CanonicalSMILES': '[B-].CC([N+](C)(C)C)O'}],
#  [{'CID': 23363476, 'CanonicalSMILES': '[Li+].C[N+](C)(C)CCO'}],
#  [{'CID': 23378681, 'CanonicalSMILES': 'CN([CH2-])CCO'}],
#  [{'CID': 23545685, 'CanonicalSMILES': '[CH2-]N(CCO)CCO'}],
#  [{'CID': 23617866, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)Br.[Br-]'}],
#  [{'CID': 23620729, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Si+4]'}],
#  [{'CID': 23623489, 'CanonicalSMILES': 'CCC[N+](CC)(CC)CCO'}],
#  [{'CID': 23629126, 'CanonicalSMILES': 'CCOC[N+](C)(C)CCO'}],
#  [{'CID': 23652544, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-].Cl'}],
#  [{'CID': 25199851, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Cu+]'}],
#  [{'CID': 25217430, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[I-]'}],
#  [{'CID': 25217432, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Br-]'}],
#  [{'CID': 25217434, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[F-]'}],
#  [{'CID': 25217545, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[OH-]'}],
#  [{'CID': 25217549, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 28064844, 'CanonicalSMILES': 'CCN(C)C(C)CO'}],
#  [{'CID': 28064846, 'CanonicalSMILES': 'CCN(C)C(C)CO'}],
#  [{'CID': 44179529, 'CanonicalSMILES': 'CN(C)CCO'}],
#  [{'CID': 44521768, 'CanonicalSMILES': 'CC(CN(C)CCO)F'}],
#  [{'CID': 44614719, 'CanonicalSMILES': 'CCC[N+](C)(CCC)CCO'}],
#  [{'CID': 49791626, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.O=[V]'}],
#  [{'CID': 50908614, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 50908615, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 50915166, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 50915167, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 50931303, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Bi]'}],
#  [{'CID': 50931392, 'CanonicalSMILES': 'CN(CCO)CCO.O.O.[Ge]'}],
#  [{'CID': 50932298, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Ge]'}],
#  [{'CID': 50932380,
#    'CanonicalSMILES': 'CN(CC[OH2+])CC[OH2+].[OH-].[OH-].[Ge]'}],
#  [{'CID': 50932455, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Al]'}],
#  [{'CID': 51035564, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 51035565, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 51035566, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 51035567, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 51037634, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 51037635, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 51037636, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 51037637, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 51037638, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 51038291, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 51038292, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 51038293, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 51038294, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 52921248, 'CanonicalSMILES': 'C[N+](C)(CCO)CF.[Cl-]'}],
#  [{'CID': 53434843, 'CanonicalSMILES': 'CCN(CO)C(CO)O.Cl'}],
#  [{'CID': 53434844, 'CanonicalSMILES': 'CCN(CO)C(CO)O'}],
#  [{'CID': 53642932, 'CanonicalSMILES': 'CC(N(CO)CO)OC'}],
#  [{'CID': 54694413, 'CanonicalSMILES': 'CC(C[N-]C)O'}],
#  [{'CID': 56953093, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-]'}],
#  [{'CID': 57171685, 'CanonicalSMILES': 'C(CO)[N+](CCO)(CCO)[Si]'}],
#  [{'CID': 57348093, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[SeH3+]'}],
#  [{'CID': 57408300, 'CanonicalSMILES': 'C[N+](C)(CCO)CC#C.[Cl-]'}],
#  [{'CID': 57443989, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Co]'}],
#  [{'CID': 57454172, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[NH4+]'}],
#  [{'CID': 57464204, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)[O-]'}],
#  [{'CID': 57494422, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Sb]'}],
#  [{'CID': 57494438, 'CanonicalSMILES': 'C[N+](C)(C)CCO[Se+]'}],
#  [{'CID': 57511413, 'CanonicalSMILES': 'C[N+](C)(C)C(CO)[O-]'}],
#  [{'CID': 59626620, 'CanonicalSMILES': 'CC(C)N([CH2-])CCO'}],
#  [{'CID': 59910041, 'CanonicalSMILES': 'C[N-]CCO'}],
#  [{'CID': 59910045, 'CanonicalSMILES': 'CC(CO)[N-]C'}],
#  [{'CID': 60153252, 'CanonicalSMILES': 'CN(CCO)CCO.Cl'}],
#  [{'CID': 60153253, 'CanonicalSMILES': 'CN(CCO)CCO'}],
#  [{'CID': 60155597, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.Cl'}],
#  [{'CID': 60155598, 'CanonicalSMILES': 'C(CO)N(CCO)CCO'}],
#  [{'CID': 60155857, 'CanonicalSMILES': 'CCN(CCO)CCO.Cl'}],
#  [{'CID': 60155858, 'CanonicalSMILES': 'CCN(CCO)CCO'}],
#  [{'CID': 60162688, 'CanonicalSMILES': 'C[N+](C)(C)CC[O-].[Tc]'}],
#  [{'CID': 60162689, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Tc]'}],
#  [{'CID': 61287134, 'CanonicalSMILES': 'CCN(CCO)CCBr'}],
#  [{'CID': 61287345, 'CanonicalSMILES': 'CN(CCO)CCBr'}],
#  [{'CID': 62020806, 'CanonicalSMILES': 'CN(CCO)CC(F)F'}],
#  [{'CID': 62021588, 'CanonicalSMILES': 'CCN(CCO)CC(F)F'}],
#  [{'CID': 62310400, 'CanonicalSMILES': 'CC#CCN(C)CCO'}],
#  [{'CID': 63701482, 'CanonicalSMILES': '[B-](CN(C)CCO)(F)(F)F'}],
#  [{'CID': 67723810, 'CanonicalSMILES': 'C[N+](C)(CCO)C#P=O'}],
#  [{'CID': 71309026, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 71309124, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 71309645, 'CanonicalSMILES': 'CN(CCO)CCO'}],
#  [{'CID': 71309716, 'CanonicalSMILES': 'CN(CCO)CCO'}],
#  [{'CID': 71309755, 'CanonicalSMILES': 'CCN(CCO)CCO'}],
#  [{'CID': 71309865, 'CanonicalSMILES': 'CCN(CCO)CCO'}],
#  [{'CID': 71309887, 'CanonicalSMILES': 'CN(CCO)CCO'}],
#  [{'CID': 71310336, 'CanonicalSMILES': 'C[N+](C)(C)CCO'}],
#  [{'CID': 71316604, 'CanonicalSMILES': 'CC[N+](C)(CCO)CCO.[Br-]'}],
#  [{'CID': 71316605, 'CanonicalSMILES': 'CC[N+](C)(CCO)CCO'}],
#  [{'CID': 71435019, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[SeH2+]'}],
#  [{'CID': 71438984, 'CanonicalSMILES': 'C[N+](C)(C)CCOCl.[I-]'}],
#  [{'CID': 71774904, 'CanonicalSMILES': 'CC(N(CCO)C(C)(O)O)(O)O'}],
#  [{'CID': 72458423, 'CanonicalSMILES': 'CN(C)CCO.CN(C)CCO.[Cu]'}],
#  [{'CID': 73053758, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].Cl[Zn]Cl'}],
#  [{'CID': 73334520, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)O.[Br-]'}],
#  [{'CID': 75202633, 'CanonicalSMILES': 'CN(C)CCO.OS(=O)O'}],
#  [{'CID': 76973406, 'CanonicalSMILES': 'CN(C)CCO.Cl'}],
#  [{'CID': 80695635, 'CanonicalSMILES': 'C(CO)N(CCO)CCF'}],
#  [{'CID': 86000886, 'CanonicalSMILES': 'CCOC[N+](C)(C)CCO.[Cl-]'}],
#  [{'CID': 86220062, 'CanonicalSMILES': 'CN(C)CCO.Cl.Br'}],
#  [{'CID': 86583183, 'CanonicalSMILES': 'C(CO)N(C#N)C#N'}],
#  [{'CID': 86643782, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Fe]'}],
#  [{'CID': 86758999,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Cl-].[Cl-].[Zn+2]'}],
#  [{'CID': 87076599, 'CanonicalSMILES': 'CC([N+](C)(C)C)O.[F-]'}],
#  [{'CID': 87079413, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Ti]'}],
#  [{'CID': 87079414, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Ti]'}],
#  [{'CID': 87080820, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Mg]'}],
#  [{'CID': 87082394, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)P'}],
#  [{'CID': 87084438, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)[PH-]'}],
#  [{'CID': 87092735, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Zr]'}],
#  [{'CID': 87092736, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Zr]'}],
#  [{'CID': 87093754, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-]P([O-])[O-]'}],
#  [{'CID': 87093884, 'CanonicalSMILES': 'B([O-])([O-])[O-].C[N+](C)(C)CCO'}],
#  [{'CID': 87120384, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Al]'}],
#  [{'CID': 87120385, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Al+3]'}],
#  [{'CID': 87141481, 'CanonicalSMILES': 'C(CO)N(CO)CO.O'}],
#  [{'CID': 87156266, 'CanonicalSMILES': 'C[N+](C)(C)CCO.OO'}],
#  [{'CID': 87169986, 'CanonicalSMILES': '[HH].[HH].C[N+](C)(C)CCO'}],
#  [{'CID': 87187013, 'CanonicalSMILES': 'CC(N(C)C)O.Cl.Br'}],
#  [{'CID': 87233591, 'CanonicalSMILES': 'CN(C)CCO.O[Ti]=O'}],
#  [{'CID': 87248056, 'CanonicalSMILES': 'CCN(CC)CC(O)Br'}],
#  [{'CID': 87252020, 'CanonicalSMILES': 'CC([N+](C)(C)C)O.[I-]'}],
#  [{'CID': 87282407, 'CanonicalSMILES': 'CC(N(C)CO)O'}],
#  [{'CID': 87282442, 'CanonicalSMILES': 'CCN(CO)C(C)O'}],
#  [{'CID': 87307990, 'CanonicalSMILES': 'CC(N(C(C)O)[Sn](C)Cl)O'}],
#  [{'CID': 87308142, 'CanonicalSMILES': 'CC(N(C)C(C)O)O.Cl[Sn+]Cl'}],
#  [{'CID': 87309705, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Na]'}],
#  [{'CID': 87318838, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Se]'}],
#  [{'CID': 87320595, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)P.[Cl-].[Ca+2]'}],
#  [{'CID': 87323940, 'CanonicalSMILES': 'C(CO)[N-]CCO.[Ti]'}],
#  [{'CID': 87327399,
#    'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-][Si]([O-])([O-])[O-]'}],
#  [{'CID': 87329039, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)[S-]'}],
#  [{'CID': 87329041, 'CanonicalSMILES': 'C[N+](C)(C)CCO[S-]'}],
#  [{'CID': 87421572, 'CanonicalSMILES': 'C[N+](C)(C)CCO.N.[OH-]'}],
#  [{'CID': 87467389, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Fe]'}],
#  [{'CID': 87478495, 'CanonicalSMILES': 'CCN(CCO)CCO.[Na]'}],
#  [{'CID': 87501947, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Mo]'}],
#  [{'CID': 87536434, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Au]'}],
#  [{'CID': 87574079, 'CanonicalSMILES': '[H+].C[N+](C)(C)CCO.[O-]P([O-])[O-]'}],
#  [{'CID': 87574081, 'CanonicalSMILES': 'C[N+](C)(C)CCO.OP([O-])[O-]'}],
#  [{'CID': 87574210, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O=P'}],
#  [{'CID': 87574336, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O=S'}],
#  [{'CID': 87574386, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-]Br(=O)=O'}],
#  [{'CID': 87574400, 'CanonicalSMILES': 'C[N+](C)(C)CCO.N=O'}],
#  [{'CID': 87574697, 'CanonicalSMILES': '[B]=O.C[N+](C)(C)CCO'}],
#  [{'CID': 87574738, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-]I(=O)(=O)=O'}],
#  [{'CID': 87574749, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-]I(=O)=O'}],
#  [{'CID': 87574913, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-][V](=O)=O'}],
#  [{'CID': 87575099,
#    'CanonicalSMILES': '[H+].C[N+](C)(C)CCO.[O-]S(=O)(=O)[O-]'}],
#  [{'CID': 87632946, 'CanonicalSMILES': 'CN(C)CCO.[Na]'}],
#  [{'CID': 87682064, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Co+2]'}],
#  [{'CID': 87859014, 'CanonicalSMILES': 'C[N+](C)(C)CCO.O=O'}],
#  [{'CID': 87859015, 'CanonicalSMILES': 'C[N+](C)(C)CCO.OOO'}],
#  [{'CID': 87861724, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.[Al]'}],
#  [{'CID': 87872683, 'CanonicalSMILES': 'CC(N(C(C)O)C(C)O)O.Cl[Ni]'}],
#  [{'CID': 87872684, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.Cl[Ni]Cl'}],
#  [{'CID': 87906533, 'CanonicalSMILES': 'CC(N(C)COC)O'}],
#  [{'CID': 87914410, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Si]'}],
#  [{'CID': 87961774, 'CanonicalSMILES': 'C[N+](C)(C)CCOCl.Cl.[Cl-]'}],
#  [{'CID': 88003098, 'CanonicalSMILES': 'C(CO)N(CCO)CCO.[Ni]'}],
#  [{'CID': 88011232, 'CanonicalSMILES': 'CC([N+](C)(C)C)O.[O-]Cl(=O)(=O)=O'}],
#  [{'CID': 88056016, 'CanonicalSMILES': 'CC(N(C)C)O.[Sr]'}],
#  [{'CID': 88056017, 'CanonicalSMILES': 'CN(C)CCO.[Sr]'}],
#  [{'CID': 88084415, 'CanonicalSMILES': 'CC(N(C)C)O.N'}],
#  [{'CID': 88091044, 'CanonicalSMILES': 'B(O)(O)O.C[N+](C)(C)CCO'}],
#  [{'CID': 88092209, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Se]'}],
#  [{'CID': 88092210, 'CanonicalSMILES': 'C[N+](C)(C)CCO[Se].[Cl-]'}],
#  [{'CID': 88092211, 'CanonicalSMILES': 'C[N+](C)(C)CCO[Se]'}],
#  [{'CID': 88092212, 'CanonicalSMILES': 'C[N+](C)(C)CCO[Se+].Cl'}],
#  [{'CID': 88115660, 'CanonicalSMILES': 'CC([N+](C)(C)C)O.Cl'}],
#  [{'CID': 88119601, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)F'}],
#  [{'CID': 88177378, 'CanonicalSMILES': 'C[N+](C)(C)CCO.N.F'}],
#  [{'CID': 88243170, 'CanonicalSMILES': 'C[N+](C)(C)CCO.ClBr'}],
#  [{'CID': 88243171, 'CanonicalSMILES': 'C[N+](C)(C)CC(O)Br.[Cl-]'}],
#  [{'CID': 88258321, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Fe+2]'}],
#  [{'CID': 88258322, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Fe]'}],
#  [{'CID': 88295520, 'CanonicalSMILES': '[B].C(CO)N(CCO)CCO'}],
#  [{'CID': 88327258, 'CanonicalSMILES': 'C[N+](C)(C)CCO.N.O'}],
#  [{'CID': 88337268, 'CanonicalSMILES': 'CN(C)CC(O)P(=S)=S'}],
#  [{'CID': 88407704, 'CanonicalSMILES': 'C[N+](C)(CCO)CCO.Cl[Fe-](Cl)(Cl)Cl'}],
#  [{'CID': 88409046, 'CanonicalSMILES': '[Li].C[N+](C)(C)CCO'}],
#  [{'CID': 88409047, 'CanonicalSMILES': '[Li+].C[N+](C)(C)CC[O-]'}],
#  [{'CID': 88419836, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Cl-].[Cd]'}],
#  [{'CID': 88449373, 'CanonicalSMILES': 'C[N+](C)(C)CC[OH2+].P'}],
#  [{'CID': 88454926, 'CanonicalSMILES': 'CC(N(C)C)O.[Na]'}],
#  [{'CID': 88471756, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[O-][Si](=O)[O-].Cl'}],
#  [{'CID': 88510277, 'CanonicalSMILES': '[B].C[N+](C)(C)CCO'}],
#  [{'CID': 88540465, 'CanonicalSMILES': 'CN(CCO)CC(O)O'}],
#  [{'CID': 88602728, 'CanonicalSMILES': '[B].CN(C)CC(O)O'}],
#  [{'CID': 88607318, 'CanonicalSMILES': '[B-].C[N+](C)(CCO)CCO'}],
#  [{'CID': 88607319, 'CanonicalSMILES': '[B].C[N+](C)(CCO)CCO'}],
#  [{'CID': 88607430, 'CanonicalSMILES': '[B-].C[N+](CCO)(CCO)CCO'}],
#  [{'CID': 88607431, 'CanonicalSMILES': '[B].C[N+](CCO)(CCO)CCO'}],
#  [{'CID': 88662936, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Ba]'}],
#  [{'CID': 88662937, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Ba+2]'}],
#  [{'CID': 88705093, 'CanonicalSMILES': 'CCN(CC)CC(O)I'}],
#  [{'CID': 88719753, 'CanonicalSMILES': 'C(CO)[N+](CCO)(CCO)CCO.Cl'}],
#  [{'CID': 88755741, 'CanonicalSMILES': 'CN(C)C[CH-]O.[Na+]'}],
#  [{'CID': 88757196, 'CanonicalSMILES': 'CN(C)C([CH2-])O.[Na+]'}],
#  [{'CID': 88757579, 'CanonicalSMILES': 'CN(C)C[CH-]O.[K+]'}],
#  [{'CID': 88794128, 'CanonicalSMILES': 'CN(C)CCO.C(=O)(O)O'}],
#  [{'CID': 88810941, 'CanonicalSMILES': 'C[N+](C)(C)CCO.[Br-].[Br-]'}],
#  [{'CID': 88810943, 'CanonicalSMILES': 'C[N+](C)(C)CCO.Br.[Br-]'}],
#  ...]

# %%
temp_list = []

for i in range(len(smiles_list)):
    
    if '[N+]' in smiles_list[i][0]['CanonicalSMILES']:
        
        temp_list.append(smiles_list[i][0])
        
#for j in range(len(temp_list)):
        
    #if '.[Cl-]' or '.[Br-]' or '.[I-]' or '.[F-]' in temp_list[j]['CanonicalSMILES']:
            
        #new_smiles_list.append(temp_list[j])

# %%
new_smiles_list = []

for i in range(len(temp_list)):
    if '.[Cl-]' in temp_list[i]['CanonicalSMILES']:
        new_smiles_list.append(temp_list[i]['CanonicalSMILES'])
        
    elif '.[Br-]' in temp_list[i]['CanonicalSMILES']:
        new_smiles_list.append(temp_list[i]['CanonicalSMILES'])
        
    elif '.[I-]' in temp_list[i]['CanonicalSMILES']:
        new_smiles_list.append(temp_list[i]['CanonicalSMILES'])
        
    elif '.[F-]' in temp_list[i]['CanonicalSMILES']:
        new_smiles_list.append(temp_list[i]['CanonicalSMILES'])
    
    else:
        pass

# %%
len(new_smiles_list)
# Out:
# 179

# %% [markdown]
# Sorting by smiles string narrowed down the results much better, only things I saw still were some are strange QAS that have metal complexes.

# %%
#function for finding the names of the results from their cid's

def get_names(cid_list):
    
    """This function will retrieve the chemical names from a list of cid's"""
    
    name_list = [] #empty list to append compound names too
    
    for cid in cid_list:
        #general pubchempy request to obtain a json of the entire compound data
        names_request = "https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/data/compound/%s/JSON" % str(cid) 
        names_request = requests.get(names_request)
        names_request_json = names_request.json()

        names = names_request_json['Record']['RecordTitle'] #the compound name is contained at the very top of the json, fairly easy.

        name_list.append(names)
        
    return name_list

# %%
#function for sorting halide salts

def keep_salts(name_list):
    
    """This function will remove non halide salts from a list of chemical names"""
    
    sorted_list = [] #empty list to append sorted names to.

    for i in name_list:

        if "chloride" in i:
            sorted_list.append(i)

        elif "bromide" in i:
            sorted_list.append(i)

        elif "fluoride" in i:
            sorted_list.append(i)

        elif "iodide" in i:
            sorted_list.append(i)

        else:
            pass
        
        return sorted_list

# %%
#wrapper function starting from a dataframe containing smiles strings

def get_similar_structures(dataframe, smiles_column,):
    
    cid_list = [] #contains cid's of similar chemcials from results
    
    for i, row in dataframe.iterrows():
        
        smiles = row[smiles_column]
        
        request_url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/fastsimilarity_2d/smiles/%s/cids/JSON?Threshold=80" % str(smiles)

        request = requests.get(request_url)
        request_json = request.json()
        
        cid_list.append(request_json['IdentifierList']['CID'])
        
    name_list = get_names(cid_list)
    
    sorted_list = keep_salts(name_list)
